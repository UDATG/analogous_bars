# %% [markdown]
# # Clustering
# * This notebook illustrates our method's application to clustering.
# * The analogous bars method is used to identify topological features that are preserved during clustering

# %%
using Revise
includet("../../../extension_method.jl")
includet("gen_points.jl")
# Out:
# HTML{String}("<script>\n// Immediately-invoked-function-expression to avoid global variables.\n(function() {\n    var warning_div = document.getElementById(\"webio-warning-3202100880460957082\");\n    var hide = function () {\n        var script = document.getElementById(\"webio-setup-15685514907090062345\");\n        var parent = script && script.parentElement;\n        var grandparent = parent && parent.parentElement;\n        if (grandparent) {\n            grandparent.style.display = \"none\";\n        }\n        warning_div.style.display = \"none\";\n    };\n    if (typeof Jupyter !== \"undefined\") {\n        console.log(\"WebIO detected Jupyter notebook environment.\");\n        // Jupyter notebook.\n        var extensions = (\n            Jupyter\n            && Jupyter.notebook.config.data\n            && Jupyter.notebook.config.data.load_extensions\n        );\n        if (extensions && extensions[\"webio-jupyter-notebook\"]) {\n            // Extension already loaded.\n            console.log(\"Jupyter WebIO nbextension detected; not loading ad-hoc.\");\n            hide();\n            return;\n        }\n    } else if (window.location.pathname.includes(\"/lab\")) {\n        // Guessing JupyterLa\n        console.log(\"Jupyter Lab detected; make sure the @webio/jupyter-lab-provider labextension is installed.\");\n        hide();\n        return;\n    }\n})();\n\n</script>\n<p\n    id=\"webio-warning-3202100880460957082\"\n    class=\"output_text output_stderr\"\n    style=\"padding: 1em; font-weight: bold;\"\n>\n    Unable to load WebIO. Please make sure WebIO works for your Jupyter client.\n    For troubleshooting, please see <a href=\"https://juliagizmos.github.io/WebIO.jl/latest/providers/ijulia/\">\n    the WebIO/IJulia documentation</a>.\n    <!-- TODO: link to installation docs. -->\n</p>\n")
# ┌ Warning: ORCA.jl has been deprecated and all savefig functionality
# │ has been implemented directly in PlotlyBase itself.
# │
# │ By implementing in PlotlyBase.jl, the savefig routines are automatically
# │ available to PlotlyJS.jl also.
# └ @ ORCA /opt/julia/packages/ORCA/U5XaN/src/ORCA.jl:8

# %%
using .ext
using .gen_points
using Distances
using Eirene
using Plots
using JLD

# %% [markdown]
# # 1. Load points
# * The points are generated from the `generate_points` function in `points.jl`
# * The clusters and centroids are generated from `get_centroids` function in `points.jl`.

# %%
# load points
data = load("points.jld")
P = collect(transpose(data["points"]))
Q = collect(transpose(data["centroids"]))
D = data["D"];

# prepare distances 
n_points = size(P)[1]
n_centroids = size(Q)[1]

# Define submatrices 
D_P = D[1:n_points, 1:n_points]
D_Q = D[n_points+1:end, n_points+1:end]
D_P_Q = D[1:n_points, n_points+1:end]
    # rows (landmarks): P
    # columns (witness) : Q
D_Q_P = D[n_points+1:end, 1:n_points];
    # rows (landmarks): Q
    # columns (witness) : P
# Out:
# ┌ Warning: JLD incorrectly extends FileIO functions (see FileIO documentation)
# └ @ FileIO /opt/julia/packages/FileIO/JA3Vl/src/loadsave.jl:215

# %%
# plot points
plot_P_Q(P,Q)
# Out:
#     <script type="text/javascript">
#         requirejs(["https://cdn.plot.ly/plotly-latest.min.js"], function(p) {
#             window.Plotly = p
#         });
#     </script>
# <!DOCTYPE html>
# <html>
#     <head>
#         <title>Plots.jl</title>
#         <meta http-equiv="content-type" content="text/html; charset=UTF-8">
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#     </head>
#     <body>
#             <div id="7117441f-41b4-4f5f-965c-e3915376a3c2" style="width:600px;height:400px;"></div>
#     <script>
#     PLOT = document.getElementById('7117441f-41b4-4f5f-965c-e3915376a3c2');
#     Plotly.plot(PLOT, [
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "x": [
#             1.7378376572670056,
#             1.530595031534535,
#             1.6399050793941585,
#             1.8482423435859128,
#             1.5876546695014675,
#             1.5950211747304337,
#             1.4173234754872155,
#             1.1919136754607564,
#             1.3309743912106873,
#             1.6044580828925452,
#             1.4218263776651918,
#             1.7305372925086955,
#             1.438958006233329,
#             1.27153898918799,
#             2.0232118391445333,
#             1.5844763071483745,
#             1.3488887974662611,
#             1.3671988510294675,
#             1.21546398783476,
#             1.5739109522450645,
#             -1.3360080334024425,
#             -1.3052600121589655,
#             -0.6785808121742256,
#             -1.2573017882131345,
#             -0.8550287688729126,
#             -1.1350087892906897,
#             -0.6231203286463911,
#             -0.8674968096694784,
#             -1.2877250840629404,
#             -1.195186822294217,
#             -2.113275122851991,
#             -1.7785329694987193,
#             -1.911320973922129,
#             -2.17372840384577,
#             -2.0286591905435856,
#             -2.2218888357585245,
#             -2.109016695642766,
#             -2.1259722574935624,
#             -1.8300421737647414,
#             -2.2509107802764787,
#             1.7270013523459093,
#             2.0699643912792056,
#             1.6561624973890134,
#             1.6742137466633773,
#             1.3760324728344202,
#             1.4829538412531187,
#             1.2751606876635084,
#             1.6157290108606701,
#             1.530009365193611,
#             1.5530497916272752,
#             -1.219193775302794,
#             -1.1472922153352474,
#             -0.8546232384264556,
#             -1.3325815255166495,
#             -1.24698050446329,
#             -1.4572854396690067,
#             -1.3786074774670394,
#             -0.7915252554845662,
#             -1.018717291979618,
#             -1.0304559707317702,
#             0.822227917384243,
#             0.7488683202487564,
#             0.8870422721367688,
#             0.7362979279810304,
#             1.2144046851397505,
#             1.1183795955276628,
#             0.6177595820659916,
#             0.8486048500362451,
#             0.767632017940363,
#             0.780692002339944,
#             1.8892886276099785,
#             2.0311760050367194,
#             1.7948948979321262,
#         ],
#         "showlegend": true,
#         "mode": "markers",
#         "name": "P",
#         "zmin": null,
#         "legendgroup": "P",
#         "marker": {
#             "symbol": "circle",
#             "color": "rgba(0, 129, 129, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 10
#         },
#         "zmax": null,
#         "y": [
#             -0.6398812079147921,
#             -0.8099369283508638,
#             -0.3381234851256817,
#             -0.4389095372665607,
#             -0.9307077702671825,
#             -0.5668593546263159,
#             -0.6414684257814177,
#             -1.016843673156238,
#             -0.9535495030875416,
#             -0.7371981385221933,
#             0.8113852217673113,
#             0.9118356115920346,
#             1.1761645193807269,
#             0.9136386513717287,
#             1.3404343760613373,
#             0.9500781095454685,

# %% [markdown]
# # 2. Apply the analogous bars method

# %% [markdown]
# ## 2(a) Compute four barcodes

# %%
# run VR persistence
VR_P = eirene(D_P, record = "all")
VR_Q = eirene(D_Q, record = "all");

# run Witness persistence
W_P = compute_Witness_persistence(D_P_Q, maxdim = 1)
W_Q = compute_Witness_persistence(D_Q_P, maxdim = 1);

# %%
# plot barcodes
barcode_P = barcode(VR_P, dim = 1)
barcode_W_PQ = barcode(W_P["eirene_output"], dim = 1)
barcode_W_QP = barcode(W_Q["eirene_output"], dim = 1)
barcode_Q = barcode(VR_Q, dim = 1)

p1 = plot_barcode(barcode_P, title = "barcode(VR(P))")
p2 = plot_barcode(barcode_W_PQ, title = "barcode(W(P,Q))", lw = 3)
p3 = plot_barcode(barcode_W_QP, title = "barcode(W(Q,P))", lw = 3)
p4 = plot_barcode(barcode_Q, title = "barcode(VR(Q))", lw = 3)

plot(p1, p2, p3, p4, layout = grid(4,1), size = (500, 700))
# Out:
# <!DOCTYPE html>
# <html>
#     <head>
#         <title>Plots.jl</title>
#         <meta http-equiv="content-type" content="text/html; charset=UTF-8">
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#     </head>
#     <body>
#             <div id="1a743fbb-7949-4dc2-85a7-1f0b3b063513" style="width:500px;height:700px;"></div>
#     <script>
#     PLOT = document.getElementById('1a743fbb-7949-4dc2-85a7-1f0b3b063513');
#     Plotly.plot(PLOT, [
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 7",
#             "class 7"
#         ],
#         "x": [
#             0.08767742284882879,
#             0.0955554599744082
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y1",
#         "zmin": null,
#         "legendgroup": "y1",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 5.0
#         },
#         "y": [
#             1.0,
#             1.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 1",
#             "class 1"
#         ],
#         "x": [
#             0.10565766228382382,
#             0.11041537643124448
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y2",
#         "zmin": null,
#         "legendgroup": "y2",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 5.0
#         },
#         "y": [
#             2.0,
#             2.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 25",
#             "class 25"
#         ],
#         "x": [
#             0.1334681109319885,
#             0.1816180650122362
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y3",
#         "zmin": null,
#         "legendgroup": "y3",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 5.0
#         },
#         "y": [
#             3.0,
#             3.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 2",
#             "class 2"
#         ],
#         "x": [
#             0.13390633080618083,
#             0.15107275831674657
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y4",
#         "zmin": null,
#         "legendgroup": "y4",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 5.0
#         },
#         "y": [
#             4.0,
#             4.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 8",
#             "class 8"
#         ],
#         "x": [
#             0.1513653347147327,
#             0.16515777286649871
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y5",
#         "zmin": null,
#         "legendgroup": "y5",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 5.0
#         },
#         "y": [
#             5.0,
#             5.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 9",
#             "class 9"
#         ],
#         "x": [
#             0.1569027008639214,
#             0.17355752041497552
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y6",
#         "zmin": null,
#         "legendgroup": "y6",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 5.0
#         },
#         "y": [
#             6.0,
#             6.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 10",
#             "class 10"
#         ],
#         "x": [
#             0.1587915730668123,
#             0.19164557767208026
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y7",
#         "zmin": null,
#         "legendgroup": "y7",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 5.0
#         },
#         "y": [
#             7.0,
#             7.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 11",
#             "class 11"
#         ],
#         "x": [
#             0.15940871161956735,
#             0.1605172603659214
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y8",
#         "zmin": null,
#         "legendgroup": "y8",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 5.0
#         },
#         "y": [
#             8.0,
#             8.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 3",
#             "class 3"
#         ],
#         "x": [
#             0.1651081337886095,
#             0.1705999898440408
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y9",
#         "zmin": null,
#         "legendgroup": "y9",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 5.0
#         },
#         "y": [
#             9.0,
#             9.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 12",
#             "class 12"
#         ],
#         "x": [
#             0.1688500680368225,
#             0.17613304527202323
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y10",
#         "zmin": null,
#         "legendgroup": "y10",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 5.0
#         },
#         "y": [
#             10.0,
#             10.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 13",
#             "class 13"
#         ],
#         "x": [
#             0.18815109544680264,
#             0.20420812559556445
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y11",
#         "zmin": null,
#         "legendgroup": "y11",
#         "zmax": null,
#         "line": {
#             "color": "r

# %% [markdown]
# ## 2(b) Apply the similarity-centric analogous bar method

# %%
# select witness bar
W_PQ_bar = 2

# run similarity-centric analogous bars method
extension_P, extension_Q = run_similarity_analogous(VR_P =  VR_P, 
                                                    D_P = D_P, 
                                                    VR_Q = VR_Q, 
                                                    D_Q = D_Q, 
                                                    W_PQ = W_P, 
                                                    W_PQ_bar = W_PQ_bar, 
                                                    dim = 1);

# %% [markdown]
# Plot the baseline bar extensions

# %%
plot_analogous_bars(extension_P, extension_Q)
# Out:
# <!DOCTYPE html>
# <html>
#     <head>
#         <title>Plots.jl</title>
#         <meta http-equiv="content-type" content="text/html; charset=UTF-8">
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#     </head>
#     <body>
#             <div id="03b4946c-9549-4647-9167-902ee22e0a32" style="width:500px;height:1000px;"></div>
#     <script>
#     PLOT = document.getElementById('03b4946c-9549-4647-9167-902ee22e0a32');
#     Plotly.plot(PLOT, [
#     {
#         "xaxis": "x2",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y2",
#         "text": [
#             "class 7",
#             "class 7"
#         ],
#         "x": [
#             0.08767742284882879,
#             0.0955554599744082
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y1",
#         "zmin": null,
#         "legendgroup": "y1",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 5.0
#         },
#         "y": [
#             1.0,
#             1.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x2",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y2",
#         "text": [
#             "class 1",
#             "class 1"
#         ],
#         "x": [
#             0.10565766228382382,
#             0.11041537643124448
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y2",
#         "zmin": null,
#         "legendgroup": "y2",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 5.0
#         },
#         "y": [
#             2.0,
#             2.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x2",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y2",
#         "text": [
#             "class 25",
#             "class 25"
#         ],
#         "x": [
#             0.1334681109319885,
#             0.1816180650122362
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y3",
#         "zmin": null,
#         "legendgroup": "y3",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 5.0
#         },
#         "y": [
#             3.0,
#             3.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x2",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y2",
#         "text": [
#             "class 2",
#             "class 2"
#         ],
#         "x": [
#             0.13390633080618083,
#             0.15107275831674657
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y4",
#         "zmin": null,
#         "legendgroup": "y4",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 5.0
#         },
#         "y": [
#             4.0,
#             4.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x2",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y2",
#         "text": [
#             "class 8",
#             "class 8"
#         ],
#         "x": [
#             0.1513653347147327,
#             0.16515777286649871
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y5",
#         "zmin": null,
#         "legendgroup": "y5",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 5.0
#         },
#         "y": [
#             5.0,
#             5.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x2",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y2",
#         "text": [
#             "class 9",
#             "class 9"
#         ],
#         "x": [
#             0.1569027008639214,
#             0.17355752041497552
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y6",
#         "zmin": null,
#         "legendgroup": "y6",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 5.0
#         },
#         "y": [
#             6.0,
#             6.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x2",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y2",
#         "text": [
#             "class 10",
#             "class 10"
#         ],
#         "x": [
#             0.1587915730668123,
#             0.19164557767208026
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y7",
#         "zmin": null,
#         "legendgroup": "y7",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 5.0
#         },
#         "y": [
#             7.0,
#             7.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x2",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y2",
#         "text": [
#             "class 11",
#             "class 11"
#         ],
#         "x": [
#             0.15940871161956735,
#             0.1605172603659214
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y8",
#         "zmin": null,
#         "legendgroup": "y8",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 5.0
#         },
#         "y": [
#             8.0,
#             8.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x2",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y2",
#         "text": [
#             "class 3",
#             "class 3"
#         ],
#         "x": [
#             0.1651081337886095,
#             0.1705999898440408
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y9",
#         "zmin": null,
#         "legendgroup": "y9",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 5.0
#         },
#         "y": [
#             9.0,
#             9.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x2",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y2",
#         "text": [
#             "class 12",
#             "class 12"
#         ],
#         "x": [
#             0.1688500680368225,
#             0.17613304527202323
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y10",
#         "zmin": null,
#         "legendgroup": "y10",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 5.0
#         },
#         "y": [
#             10.0,
#             10.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x2",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y2",
#         "text": [
#             "class 13",
#             "class 13"
#         ],
#         "x": [
#             0.18815109544680264,
#             0.20420812559556445
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y11",
#         "zmin": null,
#         "legendgroup": "y11",
#         "zmax": null,
#         "line": {
#             "color": "

# %% [markdown]
# Plot baseline cycle extensions

# %%
# select baseline cycle extension in P
epsilon0_P = extension_P["epsilon_0"]
cycle_P = extension_P["cycle_extensions"][epsilon0_P]["baseline"]

# select baseline cycle extension in Q
epsilon0_Q = extension_Q["epsilon_0"]
cycle_Q = extension_Q["cycle_extensions"][epsilon0_Q]["baseline"]

p1 = plot_cycle_square_torus(P, Q, cycle = cycle_P, cycle_loc = "P", title = "cycle extension to VR(P)"; legend = false)
p2 = plot_cycle_square_torus(P, Q, cycle = cycle_Q, cycle_loc = "Q", title = "cycle extension to VR(Q)"; legend = false)

plot(p1, p2, layout = grid(1,2), size = (600, 300))
# Out:
# <!DOCTYPE html>
# <html>
#     <head>
#         <title>Plots.jl</title>
#         <meta http-equiv="content-type" content="text/html; charset=UTF-8">
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#     </head>
#     <body>
#             <div id="1af00c70-c2a2-4d87-b7fb-5540b303f2d4" style="width:600px;height:300px;"></div>
#     <script>
#     PLOT = document.getElementById('1af00c70-c2a2-4d87-b7fb-5540b303f2d4');
#     Plotly.plot(PLOT, [
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "x": [
#             1.7378376572670056,
#             1.530595031534535,
#             1.6399050793941585,
#             1.8482423435859128,
#             1.5876546695014675,
#             1.5950211747304337,
#             1.4173234754872155,
#             1.1919136754607564,
#             1.3309743912106873,
#             1.6044580828925452,
#             1.4218263776651918,
#             1.7305372925086955,
#             1.438958006233329,
#             1.27153898918799,
#             2.0232118391445333,
#             1.5844763071483745,
#             1.3488887974662611,
#             1.3671988510294675,
#             1.21546398783476,
#             1.5739109522450645,
#             -1.3360080334024425,
#             -1.3052600121589655,
#             -0.6785808121742256,
#             -1.2573017882131345,
#             -0.8550287688729126,
#             -1.1350087892906897,
#             -0.6231203286463911,
#             -0.8674968096694784,
#             -1.2877250840629404,
#             -1.195186822294217,
#             -2.113275122851991,
#             -1.7785329694987193,
#             -1.911320973922129,
#             -2.17372840384577,
#             -2.0286591905435856,
#             -2.2218888357585245,
#             -2.109016695642766,
#             -2.1259722574935624,
#             -1.8300421737647414,
#             -2.2509107802764787,
#             1.7270013523459093,
#             2.0699643912792056,
#             1.6561624973890134,
#             1.6742137466633773,
#             1.3760324728344202,
#             1.4829538412531187,
#             1.2751606876635084,
#             1.6157290108606701,
#             1.530009365193611,
#             1.5530497916272752,
#             -1.219193775302794,
#             -1.1472922153352474,
#             -0.8546232384264556,
#             -1.3325815255166495,
#             -1.24698050446329,
#             -1.4572854396690067,
#             -1.3786074774670394,
#             -0.7915252554845662,
#             -1.018717291979618,
#             -1.0304559707317702,
#             0.822227917384243,
#             0.7488683202487564,
#             0.8870422721367688,
#             0.7362979279810304,
#             1.2144046851397505,
#             1.1183795955276628,
#             0.6177595820659916,
#             0.8486048500362451,
#             0.767632017940363,
#             0.780692002339944,
#             1.8892886276099785,
#             2.0311760050367194,
#         ],
#         "showlegend": true,
#         "mode": "markers",
#         "name": "P",
#         "zmin": null,
#         "legendgroup": "P",
#         "marker": {
#             "symbol": "circle",
#             "color": "rgba(0, 129, 129, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 10
#         },
#         "zmax": null,
#         "y": [
#             -0.6398812079147921,
#             -0.8099369283508638,
#             -0.3381234851256817,
#             -0.4389095372665607,
#             -0.9307077702671825,
#             -0.5668593546263159,
#             -0.6414684257814177,
#             -1.016843673156238,
#             -0.9535495030875416,
#             -0.7371981385221933,
#             0.8113852217673113,
#             0.9118356115920346,
#             1.1761645193807269,
#             0.9136386513717287,
#             1.3404343760613373,
#             0.9500781095454685,

# %% [markdown]
# ## 2(c). Explore cycle extension & bar extension under fixed interval decompositions of `barcode(VR(P))` and `barcode(VR(Q))`.
# * (i) Plotting the extension parameters for both `barcode(VR(P))` and `barcode(VR(Q))`
# * (ii) Finding all cycle extensions and bar extensions (non-interactive).

# %% [markdown]
# ### 2(c)(i) Plot parameters

# %%
p1 = plot_pY(extension_P, title = "barcode(VR(P))")
p2 = plot_pY(extension_Q, title = "barcode(VR(Q))")

plot(p1, p2, grid = (1, 2), size = (700, 300))
# Out:
# <!DOCTYPE html>
# <html>
#     <head>
#         <title>Plots.jl</title>
#         <meta http-equiv="content-type" content="text/html; charset=UTF-8">
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#     </head>
#     <body>
#             <div id="b76854f0-b85c-481b-b9da-6acf65a20c50" style="width:700px;height:300px;"></div>
#     <script>
#     PLOT = document.getElementById('b76854f0-b85c-481b-b9da-6acf65a20c50');
#     Plotly.plot(PLOT, [
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 7",
#             "class 7"
#         ],
#         "x": [
#             0.08767742284882879,
#             0.0955554599744082
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y1",
#         "zmin": null,
#         "legendgroup": "y1",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 5.0
#         },
#         "y": [
#             1.0,
#             1.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 1",
#             "class 1"
#         ],
#         "x": [
#             0.10565766228382382,
#             0.11041537643124448
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y2",
#         "zmin": null,
#         "legendgroup": "y2",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 5.0
#         },
#         "y": [
#             2.0,
#             2.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 25",
#             "class 25"
#         ],
#         "x": [
#             0.1334681109319885,
#             0.1816180650122362
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y3",
#         "zmin": null,
#         "legendgroup": "y3",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 5.0
#         },
#         "y": [
#             3.0,
#             3.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 2",
#             "class 2"
#         ],
#         "x": [
#             0.13390633080618083,
#             0.15107275831674657
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y4",
#         "zmin": null,
#         "legendgroup": "y4",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 5.0
#         },
#         "y": [
#             4.0,
#             4.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 8",
#             "class 8"
#         ],
#         "x": [
#             0.1513653347147327,
#             0.16515777286649871
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y5",
#         "zmin": null,
#         "legendgroup": "y5",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 5.0
#         },
#         "y": [
#             5.0,
#             5.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 9",
#             "class 9"
#         ],
#         "x": [
#             0.1569027008639214,
#             0.17355752041497552
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y6",
#         "zmin": null,
#         "legendgroup": "y6",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 5.0
#         },
#         "y": [
#             6.0,
#             6.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 10",
#             "class 10"
#         ],
#         "x": [
#             0.1587915730668123,
#             0.19164557767208026
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y7",
#         "zmin": null,
#         "legendgroup": "y7",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 5.0
#         },
#         "y": [
#             7.0,
#             7.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 11",
#             "class 11"
#         ],
#         "x": [
#             0.15940871161956735,
#             0.1605172603659214
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y8",
#         "zmin": null,
#         "legendgroup": "y8",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 5.0
#         },
#         "y": [
#             8.0,
#             8.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 3",
#             "class 3"
#         ],
#         "x": [
#             0.1651081337886095,
#             0.1705999898440408
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y9",
#         "zmin": null,
#         "legendgroup": "y9",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 5.0
#         },
#         "y": [
#             9.0,
#             9.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 12",
#             "class 12"
#         ],
#         "x": [
#             0.1688500680368225,
#             0.17613304527202323
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y10",
#         "zmin": null,
#         "legendgroup": "y10",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 5.0
#         },
#         "y": [
#             10.0,
#             10.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 13",
#             "class 13"
#         ],
#         "x": [
#             0.18815109544680264,
#             0.20420812559556445
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y11",
#         "zmin": null,
#         "legendgroup": "y11",
#         "zmax": null,
#         "line": {
#             "color": "r

# %% [markdown]
# Both extensions have unique parameters.

# %% [markdown]
# ### 2(c)(ii) Find all cycle extensions and bar extensions

# %%
CE_P, BE_P = find_CE_BE(extension_P)
CE_Q, BE_Q = find_CE_BE(extension_Q);

# %%
CE_P
# Out:
# Dict{Any,Any} with 1 entry:
#   1.03942 => Dict{Any,Any}(0=>[[137, 179], [17, 137], [14, 179], [9, 194], [8, …

# %%
CE_Q
# Out:
# Dict{Any,Any} with 1 entry:
#   1.99801 => Dict{Any,Any}(0=>[[3, 4], [2, 10], [6, 7], [1, 7], [8, 9], [5, 8],…

# %% [markdown]
# Both extensions have a unique cycle extension.

# %% [markdown]
# ## 2(d) Explore the bar extension result under alternative interval decompositions of `C_VR`
# * Up to this point, the bar extension result has been obtained for some fixed interval decompositions of `barcode(VR(P))` and `barcode(VR(Q))`.
# * In this section, we explore all alternative bar extensions.

# %%
# find alternative bar extensions
alt_BE_P = find_alt_BE(extension_P, BE_P)
alt_BE_Q = find_alt_BE(extension_Q, BE_Q);

# %%
alt_BE_P
# Out:
# Dict{Any,Any} with 1 entry:
#   1.03942 => Any[[24]]

# %%
alt_BE_Q
# Out:
# Dict{Any,Any} with 1 entry:
#   1.99801 => Any[[1]]

# %% [markdown]
# There are no alternative bar extensions
