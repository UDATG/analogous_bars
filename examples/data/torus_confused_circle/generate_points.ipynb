# %% [markdown]
# # Generate points for the torus and confused circle

# %%
using Revise

# %%
includet("../../../extension_method.jl")
using .ext
# Out:
# HTML{String}("<script>\n// Immediately-invoked-function-expression to avoid global variables.\n(function() {\n    var warning_div = document.getElementById(\"webio-warning-15142055094452922587\");\n    var hide = function () {\n        var script = document.getElementById(\"webio-setup-12129068256089961774\");\n        var parent = script && script.parentElement;\n        var grandparent = parent && parent.parentElement;\n        if (grandparent) {\n            grandparent.style.display = \"none\";\n        }\n        warning_div.style.display = \"none\";\n    };\n    if (typeof Jupyter !== \"undefined\") {\n        console.log(\"WebIO detected Jupyter notebook environment.\");\n        // Jupyter notebook.\n        var extensions = (\n            Jupyter\n            && Jupyter.notebook.config.data\n            && Jupyter.notebook.config.data.load_extensions\n        );\n        if (extensions && extensions[\"webio-jupyter-notebook\"]) {\n            // Extension already loaded.\n            console.log(\"Jupyter WebIO nbextension detected; not loading ad-hoc.\");\n            hide();\n            return;\n        }\n    } else if (window.location.pathname.includes(\"/lab\")) {\n        // Guessing JupyterLa\n        console.log(\"Jupyter Lab detected; make sure the @webio/jupyter-lab-provider labextension is installed.\");\n        hide();\n        return;\n    }\n})();\n\n</script>\n<p\n    id=\"webio-warning-15142055094452922587\"\n    class=\"output_text output_stderr\"\n    style=\"padding: 1em; font-weight: bold;\"\n>\n    Unable to load WebIO. Please make sure WebIO works for your Jupyter client.\n    For troubleshooting, please see <a href=\"https://juliagizmos.github.io/WebIO.jl/latest/providers/ijulia/\">\n    the WebIO/IJulia documentation</a>.\n    <!-- TODO: link to installation docs. -->\n</p>\n")
# ┌ Warning: ORCA.jl has been deprecated and all savefig functionality
# │ has been implemented directly in PlotlyBase itself.
# │
# │ By implementing in PlotlyBase.jl, the savefig routines are automatically
# │ available to PlotlyJS.jl also.
# └ @ ORCA /opt/julia/packages/ORCA/U5XaN/src/ORCA.jl:8

# %%
using Distributions
using Eirene
using Plots
using JLD
plotlyjs()
# Out:
# Plots.PlotlyJSBackend()

# %% [markdown]
# #### Sample from torus

# %%
# generate points on torus
n_torus = 300
R = 2
r = 1
torus, torus_theta, torus_phi = sample_torus(R, r, n_torus, return_angles = true);

# %% [markdown]
# #### Sample from circle

# %% [markdown]
# For confused circle, first decide on the relationship between $\theta$ and $\phi$

# %%
function theta_from_phi(phi, h, a)
    # adjust maximum height (h) and range (π-a, π+a)  
    
    if phi <= π - a
        rand(Uniform(0, 0.25))
    elseif π - a < phi <= π 
        h *(phi .- (π .- a)) / a 
    elseif π < phi <= π + a
        h .- h * (phi .- π ) / a
    else
        rand(Uniform(0, 0.25))
    end
end
# Out:
# theta_from_phi (generic function with 1 method)

# %%
h = 1.5* π
a = 1
function theta_function(phi)
   theta_from_phi(phi, h, a) 
end
# Out:
# theta_function (generic function with 1 method)

# %%
# visualize theta_function
plot(range(0, stop = 2π, length = 1000), theta_function, xlabel ="ϕ", ylabel ="θ", label="")
# Out:
# <!DOCTYPE html>
# <html>
#     <head>
#         <title>Plots.jl</title>
#         <meta http-equiv="content-type" content="text/html; charset=UTF-8">
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#     </head>
#     <body>
#             <div id="98e9014a-bfde-4f42-97d9-38017a1d16aa" style="width:600px;height:400px;"></div>
#     <script>
#     PLOT = document.getElementById('98e9014a-bfde-4f42-97d9-38017a1d16aa');
#     Plotly.plot(PLOT, [
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "x": [
#             0.0,
#             0.006289474781961547,
#             0.012578949563923095,
#             0.018868424345884642,
#             0.02515789912784619,
#             0.03144737390980774,
#             0.037736848691769284,
#             0.04402632347373083,
#             0.05031579825569238,
#             0.05660527303765393,
#             0.06289474781961547,
#             0.06918422260157703,
#             0.07547369738353857,
#             0.08176317216550012,
#             0.08805264694746166,
#             0.09434212172942322,
#             0.10063159651138476,
#             0.10692107129334631,
#             0.11321054607530787,
#             0.1195000208572694,
#             0.12578949563923095,
#             0.13207897042119252,
#             0.13836844520315406,
#             0.1446579199851156,
#             0.15094739476707714,
#             0.1572368695490387,
#             0.16352634433100025,
#             0.16981581911296179,
#             0.17610529389492333,
#             0.1823947686768849,
#             0.18868424345884643,
#             0.19497371824080797,
#             0.20126319302276952,
#             0.20755266780473108,
#             0.21384214258669262,
#             0.22013161736865416,
#             0.22642109215061573,
#             0.23271056693257727,
#             0.2390000417145388,
#             0.24528951649650035,
#             0.2515789912784619,
#             0.25786846606042346,
#             0.26415794084238503,
#             0.27044741562434654,
#             0.2767368904063081,
#             0.2830263651882696,
#             0.2893158399702312,
#             0.29560531475219276,
#             0.3018947895341543,
#             0.30818426431611584,
#             0.3144737390980774,
#             0.3207632138800389,
#             0.3270526886620005,
#             0.33334216344396206,
#             0.33963163822592357,
#             0.34592111300788514,
#             0.35221058778984665,
#             0.3585000625718082,
#             0.3647895373537698,
#             0.3710790121357313,
#             0.37736848691769287,
#             0.38365796169965444,
#             0.38994743648161595,
#             0.3962369112635775,
#             0.40252638604553903,
#             0.4088158608275006,
#             0.41510533560946217,
#             0.4213948103914237,
#             0.42768428517338525,
#             0.4339737599553468,
#             0.44026323473730833,
#             0.4465527095192699,
#             0.45284218430123147,
#             0.459131659083193,
#             0.46542113386515455,
#             0.47171060864711606,
#             0.4780000834290776,
#             0.4842895582110392,
#             0.4905790329930007,
#             0.4968685077749623,
#             0.5031579825569238,
#             1.377394977249579,
#             1.3836844520315406,
#             1.389973926813502,
#             1.3962634015954636,
#             1.402552876377425,
#             1.4088423511593866,
#             1.4151318259413483,
#             1.4214213007233099,
#             1.4277107755052714,
#             1.4340002502872329,
#             1.4402897250691944,
#             1.446579199851156,
#             1.45

# %%
##### generate points on a "confused circle"

# sample phi for the "circular" section and the "confused" section
n_circular = 40 
n_confused = 30
phi = rand(Uniform(0, 2π), n_circular)
phi_confused = rand(Uniform(π-a, π+a), n_confused)
circle_phi = vcat(phi, phi_confused)

# find theta
circle_theta = [theta_function(item) for item in circle_phi]

# coordinates in 3D 
x = (R .+ r .* cos.(circle_theta .+ pi)).* cos.(circle_phi)
y = (R .+ r .* cos.(circle_theta .+ pi)) .* sin.(circle_phi)
z = r .* sin.(circle_theta .+ pi)

circle = cat(x,y,z, dims = 2);

# %%
p = plot_3D(circle, torus)
plot(p)
# Out:
# <!DOCTYPE html>
# <html>
#     <head>
#         <title>Plots.jl</title>
#         <meta http-equiv="content-type" content="text/html; charset=UTF-8">
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#     </head>
#     <body>
#             <div id="b5247bf6-4335-428f-a51d-76711fdc8152" style="width:600px;height:400px;"></div>
#     <script>
#     PLOT = document.getElementById('b5247bf6-4335-428f-a51d-76711fdc8152');
#     Plotly.plot(PLOT, [
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "x": [
#             0.4860689447812893,
#             0.939450605260818,
#             -2.757944584672162,
#             0.15885138807829716,
#             0.7200565334435315,
#             -2.838165901213365,
#             -2.471909883559565,
#             1.0149239965364545,
#             0.8839945486157761,
#             -0.3393279441230608,
#             0.8320916761556223,
#             -0.9458273672914187,
#             -0.5263180829283777,
#             -2.02520971292508,
#             0.8754588330999634,
#             0.7406054873253793,
#             -1.7265304201089122,
#             0.3964253930159162,
#             -1.3350347296169542,
#             -0.308319038720237,
#             -0.1108012307118843,
#             -0.5435514130106934,
#             -0.25042468560459286,
#             0.11461731396883437,
#             0.8147033527569396,
#             0.5293122587155814,
#             -0.020714353784583844,
#             0.2879360597590915,
#             -0.5938157711528504,
#             0.7117368674364241,
#             -0.7588526289767816,
#             0.5562368673528925,
#             0.7615588054555733,
#             0.25055922536162517,
#             -2.4466257145676518,
#             -0.5984555002090656,
#             1.022739218142497,
#             1.0144435596924224,
#             0.9820102541499554,
#             0.8446414603958802,
#             -1.5433572212722129,
#             -1.1423972925018897,
#             -2.854025522542105,
#             -2.345971962779072,
#             -1.9771759212947615,
#             -2.30732623589723,
#             -2.4205158673700002,
#             -2.4225103045606513,
#             -2.735318855894172,
#             -0.7799037076336408,
#             -0.5999841337488281,
#             -1.100102223014988,
#             -0.8781845032126561,
#             -2.0834337025862317,
#             -2.7401868612259537,
#             -2.4835074762176603,
#             -2.084526740449383,
#             -1.5974788638229394,
#             -2.726519664981999,
#             -0.7992923933355802,
#             -1.950205804592966,
#             -1.1589125973322385,
#             -1.8050697177764516,
#             -0.9240992945927377,
#             -2.525191455574508,
#             -1.1838453483295905,
#             -0.8885400376163529,
#             -2.8372677759420397,
#             -2.7484856667921878,
#             -2.7154731812550446
#         ],
#         "showlegend": true,
#         "mode": "markers",
#         "name": "P",
#         "zmin": null,
#         "legendgroup": "P",
#         "z": [
#             -0.17826436731651787,
#             -0.027327777577419984,
#             -0.2306412110278419,
#             -0.07104620434784303,
#             -0.17062351030160608,
#             0.01652183552001131,
#             0.8737714879885039,
#             -0.17387424562988543,
#             -0.11704753488223027,
#             -0.19708698230242222,
#             -0.10712946708722498,
#             -0.7787020132064215,
#             -0.07517520173765675,
#             -0.9099475352872894,
#             -0.15806915615977088,
#             -0.08098403175584808,
#             -0.9893424616925155,
#             -0.13632425357333292,
#             -0.9730925434761958,

#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {

# %% [markdown]
# Plot the points on square. Assume that the sides of the squares have been identified to represent a torus

# %%
# plot angles
# Assign colors to visualization
P_color = "#ff8d00"
Q_color = "#008181";

plot(framestyle = :box, yaxis = nothing, xaxis = nothing, legend = :false, size = (400, 400))
# plot torus
scatter!(torus_theta, torus_phi, color = Q_color, markersize = 5, label = "Q")

# plot circle
scatter!(circle_theta, circle_phi, color = P_color, markersize = 7, marker =:xcross, label = "P")
# Out:
# <!DOCTYPE html>
# <html>
#     <head>
#         <title>Plots.jl</title>
#         <meta http-equiv="content-type" content="text/html; charset=UTF-8">
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#     </head>
#     <body>
#             <div id="7c165065-ae20-4b44-ab8b-b0f2d9425f3e" style="width:400px;height:400px;"></div>
#     <script>
#     PLOT = document.getElementById('7c165065-ae20-4b44-ab8b-b0f2d9425f3e');
#     Plotly.plot(PLOT, [
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "x": [
#             5.318876341520126,
#             4.233356298809698,
#             5.4582108261212285,
#             5.1912040670212685,
#             1.5090666145407172,
#             2.8631316427307376,
#             3.4699500764652944,
#             2.1725944288761383,
#             2.2904448612378188,
#             0.8143728651536022,
#             5.0028825617968025,
#             5.361618992871797,
#             4.92058078256647,
#             1.3196055004826612,
#             0.1642155693597539,
#             3.4443636660162538,
#             5.068319974313094,
#             3.849961649296597,
#             1.4230547392505037,
#             2.425028271064775,
#             2.391814072470576,
#             5.521341695223722,
#             0.490002924595842,
#             6.238905343386706,
#             3.060768149373451,
#             6.095712787274627,
#             5.622460803516309,
#             3.7515058116857456,
#             5.691687087141752,
#             0.2617389281332161,
#             2.161094928038166,
#             5.4897483541586585,
#             4.482824768297087,
#             0.5101580284446319,
#             3.4338618365122695,
#             1.8514495090695007,
#             2.7052974615275764,
#             0.21215691188943434,
#             5.2085530204419,
#             4.752755539744876,
#             5.025916488554651,
#             5.263415929304192,
#             5.5641487603363675,
#             0.6755314494150108,
#             0.5382649855947605,
#             4.23866678060347,
#             2.6765668949439445,
#             6.223571636874875,
#             1.9248578885471432,
#             1.3500363140251463,
#             5.019369441133438,
#             6.219910743503323,
#             1.3596753161627968,
#             3.3534657360391673,
#             0.5481290401906737,
#             3.7421843575138585,
#             3.290207267314253,
#             0.32442023035732426,
#             3.5583226447427974,
#             5.145542418601569,
#             4.162021414432478,
#             6.180076270214084,
#             4.798116886640669,
#             1.3520670071494658,
#             1.5221356064044944,
#             1.9439034616044564,
#             3.2461381406894896,
#             4.88876063408888,
#             1.3017174179658408,
#             5.924108492270105,
#             5.937813908706153,
#             2.801066024911304,
#             1.823180530038846,
#             1.2301584404552128,
#             5.481212544924291,
#             4.862132781265402,
#             1.565383617036577,
#             2.6365311552160846,
#             3.380871082896915,
#             2.709208954801873,
#             2.066937723581991,
#             4.794164577448147,
#             5.142002419367383,
#             0.03686008430858517,
#             5.527472261304109,
#             2.799613857714564,
#             4.3354032108544,
#             1.2289544353097765,
#             5.478328522116958,
#             1.0543988937618163,
#             1.3137751926996937,
#             4.09803733722277,
#             0.167472597110621,
#             4.536834616989848,
#             0.7366333902142805,
#             6.0882640334401,
#             1.354168692498172,
#             3.263064505484892,
#             0.39391825929990393,
#             2.028380909744768,
#             0.7832224324325407,
#             2.219252100811135,
#             4.830910888956535,
#             1.8976493171169446,
#             0.11775017461649291,
#             1.9086210854823409,
#             3.9183249908262376,
#             3.2353516265609312,
#             0.1829679574276834,
#             1.9275269289017074,
#             3.7371529731615687,
#             1.6461877143213246,
#             1.6119445682342954,
#             4.0254800505365615,
#             0.3910619088874444,
#             5.432128179819546,
#             3.350020761396479,
#             4.523049489501755,
#             0.3482339256787877,
#             3.181417608865083,
#             0.3627979091532056,
#             5.717283145354906,
#             2.8986329922353304,
#             3.028401507451344,
#             1.3927866109516451,
#             0.2834708573898475,
#             4.5632897498519815,
#             5.1174512581925,
#             2.3481936577879616,
#             3.9886293836476368,
#             0.9024075799450126,
#             0.4714259292939624,
#             0.7528493968329499,
#             5.204155773191018,
#             1.6967509248274362,
#             3.3955083366878074,
#             1.1543601692409229,
#             1.792798510402008,
#             3.331762892049753,
#             3.9925209115568747,
#             5.975632163258857,
#             1.2932715485123352,
#             4.340575110309167,
#             1.7610856419740872,
#             1.1620883150460448,
#             3.380850646038074,
#             5.786937724560712,
#             5.418787899326221,
#             4.6056558808464345,
#             5.495687268499976,
#             4.402499797669605,
#             6.2057284055169974,
#             5.641697394284247,
#             1.4172116502171255,
#             2.4283457507020216,
#             0.3846636020798325,
#             4.9741347561008595,
#             5.465615025027883,
#             0.4286299006040391,
#             0.8022517830975303,
#             5.491054114395702,
#             4.687670164035481,
#             3.482098989673162,
#             0.4555941357448842,
#             4.8479776365909295,
#             1.8851082584641736,
#             1.7535283274434206,
#             5.457610620176254,
#             5.646223332841219,
#             0.12831769713281735,
#             1.2158938427289605,
#             1.7536724363976102,
#             6.014126832337747,
#             0.16868790895629,
#             5.600909867435671,
#             2.816009572888999,
#             2.6722153167038636,
#             0.16182498565575107,
#             1.5529372840648705,
#             5.362889119817788,
#             3.0230140898837314,
#             6.0284617542425885,
#             5.3733594730989855,
#             5.821578108755032,
#             6.079807971674147,
#             4.101316239674981,
#             4.25835370396013,
#             5.5783961057554965,
#             0.0650674214505279,
#             6.1271011707888805,
#             2.0983866516995473,
#             1.689839657354639,
#             3.5294264302947247,
#             2.9420198176297783,
#             0.6980057245969095,
#             1.1324576987793646,
#             3.4643860155078827,
#             0.6391887530752307,
#             5.752720612116882,
#             1.0963769092885622,
#             4.808817135664213,
#             4.013958049558713,
#             2.1838085680312087,
#             2.3065830966485024,
#             5.203580996555027,
#             0.39810755986615076,
#             0.7291176916805622,
#             5.383582310268295,
#             5.609665066653413,
#             4.4010878974319825,
#             5.755275031590493,
#             0.7397474660375107,
#             5.175661146497653,
#             6.1235189264046515,
#             1.0144659060017938,
#             5.777430892207806,
#             0.029611040600830044,
#             4.076132989215108,
#             2.261479581309087,
#             0.19427787075419584,
#             2.2120115548917174,
#             4.877150681931737,
#             2.681062862600076,
#             4.13043735047086,
#             0.30224874799135454,
#             1.3349159069057701,
#             4.224200649047978,
#             0.025450342156185655,
#             5.54982347566727,
#             0.881475978739844,
#             5.563119379564887,
#             3.791384612492216,
#             1.0993502375463724,
#             4.571196461575607,
#             4.475540763505183,
#             1.5594

# %% [markdown]
# # Run VR and Witness persistence
# To check that the barcodes are consistent with expection

# %%
# compute distance
D_torus, D_circle, D_torus_circle, D_circle_torus = compute_distance(torus, circle);

# %%
# Compute Vietoris-Rips persistence on two regions
dim = 1
VR_torus = eirene(D_torus, record = "all", maxdim = dim)
VR_circle = eirene(D_circle, record = "all", maxdim = dim);

# %%
p1 = plot_barcode(barcode(VR_torus, dim = 1), lw = 3, title = "Barcode(VR(torus))", titlefontsize = 12)
p2 = plot_barcode(barcode(VR_circle, dim = 1), lw = 2, title = "Barcode(VR(circle))", titlefontsize = 12)
plot(p1, p2, layout = grid(2,1), size = (500, 700))
# Out:
# <!DOCTYPE html>
# <html>
#     <head>
#         <title>Plots.jl</title>
#         <meta http-equiv="content-type" content="text/html; charset=UTF-8">
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#     </head>
#     <body>
#             <div id="6076b93a-e64c-4ef1-b87e-9d7141df5089" style="width:500px;height:700px;"></div>
#     <script>
#     PLOT = document.getElementById('6076b93a-e64c-4ef1-b87e-9d7141df5089');
#     Plotly.plot(PLOT, [
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 18",
#             "class 18"
#         ],
#         "x": [
#             0.3247747460347165,
#             0.3825014238816475
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y1",
#         "zmin": null,
#         "legendgroup": "y1",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             1.0,
#             1.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 19",
#             "class 19"
#         ],
#         "x": [
#             0.3365860671891834,
#             0.3661182833268045
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y2",
#         "zmin": null,
#         "legendgroup": "y2",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             2.0,
#             2.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 20",
#             "class 20"
#         ],
#         "x": [
#             0.36165715447899527,
#             0.3679808302921057
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y3",
#         "zmin": null,
#         "legendgroup": "y3",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             3.0,
#             3.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 1",
#             "class 1"
#         ],
#         "x": [
#             0.36180174159473855,
#             0.3658141178729323
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y4",
#         "zmin": null,
#         "legendgroup": "y4",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             4.0,
#             4.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 21",
#             "class 21"
#         ],
#         "x": [
#             0.40165475035688847,
#             0.41254565687632805
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y5",
#         "zmin": null,
#         "legendgroup": "y5",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             5.0,
#             5.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 22",
#             "class 22"
#         ],
#         "x": [
#             0.40491725621111757,
#             0.5712583869546479
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y6",
#         "zmin": null,
#         "legendgroup": "y6",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             6.0,
#             6.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 23",
#             "class 23"
#         ],
#         "x": [
#             0.41381334280492227,
#             0.46212342688564517
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y7",
#         "zmin": null,
#         "legendgroup": "y7",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             7.0,
#             7.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 24",
#             "class 24"
#         ],
#         "x": [
#             0.4244011128540355,
#             0.4606337792141955
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y8",
#         "zmin": null,
#         "legendgroup": "y8",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             8.0,
#             8.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 25",
#             "class 25"
#         ],
#         "x": [
#             0.42629792985374143,
#             0.4405773796241507
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y9",
#         "zmin": null,
#         "legendgroup": "y9",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             9.0,
#             9.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 26",
#             "class 26"
#         ],
#         "x": [
#             0.42937508005495206,
#             0.5800986610148263
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y10",
#         "zmin": null,
#         "legendgroup": "y10",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             10.0,
#             10.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 2",
#             "class 2"
#         ],
#         "x": [
#             0.4653082667420761,
#             0.4668585431240205
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y11",
#         "zmin": null,
#         "legendgroup": "y11",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 1

# %%
# compute Witness persistence
W_torus_circle = compute_Witness_persistence(D_torus_circle, maxdim = dim)
W_circle_torus = compute_Witness_persistence(D_circle_torus, maxdim = dim)
# Out:
# Dict{Any,Any} with 8 entries:
#   "fv"                         => Any[Any[0.337898, 0.134063, 0.261707, 0.19789…
#   "param_max"                  => 2.18353
#   "default_vertex_to_W_vertex" => nothing
#   "simplex2index"              => Dict([7, 15, 69]=>13543,[9, 45, 46]=>18426,[1…
#   "eirene_output"              => Dict{String,Any}("rv"=>Any[Int64[], [1, 2, 1,…
#   "index2simplex"              => Dict((325, 1)=>[5, 60],(41710, 2)=>[27, 33, 4…
#   "distance_matrix"            => [2.93753 0.888783 … 3.48277 2.03826; 3.65717 …
#   "W_vertex_to_default_vertex" => nothing

# %%
# plot all four barcodes
l = grid(4,1)
p1 = plot_barcode(barcode(VR_torus, dim = 1), lw = 2, title = "Barcode(VR(torus))", titlefontsize = 12)
p2 = plot_barcode(barcode(W_torus_circle["eirene_output"], dim = 1) , lw = 5, title = "Barcode(W(torus, circle))", titlefontsize = 12)
p3 = plot_barcode(barcode(W_circle_torus["eirene_output"], dim = 1) , lw = 5, title = "Barcode(W(circle, torus))", titlefontsize = 12)
p4 = plot_barcode(barcode(VR_circle, dim = 1), lw = 5, title = "Barcode(VR(circle))", titlefontsize = 12)
plot(p1, p2, p3, p4, layout = l, size = (500, 700))
# Out:
# <!DOCTYPE html>
# <html>
#     <head>
#         <title>Plots.jl</title>
#         <meta http-equiv="content-type" content="text/html; charset=UTF-8">
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#     </head>
#     <body>
#             <div id="29c01c78-aaee-4c12-afab-aa79aa6aa74e" style="width:500px;height:700px;"></div>
#     <script>
#     PLOT = document.getElementById('29c01c78-aaee-4c12-afab-aa79aa6aa74e');
#     Plotly.plot(PLOT, [
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 18",
#             "class 18"
#         ],
#         "x": [
#             0.3247747460347165,
#             0.3825014238816475
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y1",
#         "zmin": null,
#         "legendgroup": "y1",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 2
#         },
#         "y": [
#             1.0,
#             1.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 19",
#             "class 19"
#         ],
#         "x": [
#             0.3365860671891834,
#             0.3661182833268045
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y2",
#         "zmin": null,
#         "legendgroup": "y2",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 2
#         },
#         "y": [
#             2.0,
#             2.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 20",
#             "class 20"
#         ],
#         "x": [
#             0.36165715447899527,
#             0.3679808302921057
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y3",
#         "zmin": null,
#         "legendgroup": "y3",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 2
#         },
#         "y": [
#             3.0,
#             3.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 1",
#             "class 1"
#         ],
#         "x": [
#             0.36180174159473855,
#             0.3658141178729323
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y4",
#         "zmin": null,
#         "legendgroup": "y4",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 2
#         },
#         "y": [
#             4.0,
#             4.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 21",
#             "class 21"
#         ],
#         "x": [
#             0.40165475035688847,
#             0.41254565687632805
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y5",
#         "zmin": null,
#         "legendgroup": "y5",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 2
#         },
#         "y": [
#             5.0,
#             5.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 22",
#             "class 22"
#         ],
#         "x": [
#             0.40491725621111757,
#             0.5712583869546479
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y6",
#         "zmin": null,
#         "legendgroup": "y6",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 2
#         },
#         "y": [
#             6.0,
#             6.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 23",
#             "class 23"
#         ],
#         "x": [
#             0.41381334280492227,
#             0.46212342688564517
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y7",
#         "zmin": null,
#         "legendgroup": "y7",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 2
#         },
#         "y": [
#             7.0,
#             7.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 24",
#             "class 24"
#         ],
#         "x": [
#             0.4244011128540355,
#             0.4606337792141955
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y8",
#         "zmin": null,
#         "legendgroup": "y8",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 2
#         },
#         "y": [
#             8.0,
#             8.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 25",
#             "class 25"
#         ],
#         "x": [
#             0.42629792985374143,
#             0.4405773796241507
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y9",
#         "zmin": null,
#         "legendgroup": "y9",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 2
#         },
#         "y": [
#             9.0,
#             9.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 26",
#             "class 26"
#         ],
#         "x": [
#             0.42937508005495206,
#             0.5800986610148263
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y10",
#         "zmin": null,
#         "legendgroup": "y10",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 2
#         },
#         "y": [
#             10.0,
#             10.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 2",
#             "class 2"
#         ],
#         "x": [
#             0.4653082667420761,
#             0.4668585431240205
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y11",
#         "zmin": null,
#         "legendgroup": "y11",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 1

# %%
# save points
save("data2.jld", "torus", torus, "torus_theta", torus_theta, "torus_phi", torus_phi,
    "circle", circle, "circle_theta", circle_theta, "circle_phi", circle_phi)
# Out:
# ┌ Warning: JLD incorrectly extends FileIO functions (see FileIO documentation)
# └ @ FileIO /opt/julia/packages/FileIO/JA3Vl/src/loadsave.jl:215
