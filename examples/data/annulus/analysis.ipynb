# %% [markdown]
# # Annulus
# * Let `P` and `Q` be two point cloud sampled from two distinct distributions on an annulus.
# * Let `Q` and `R` be two point clouds sampled from the same distributions on an annulus.
#
# ## 1. Comparison of `P` and `Q`
# * This notebook illustrates the problem of constructing persistence modules $$VR(P) \rightarrow VR(P \cup Q) \leftarrow VR(Q)$$
# * This notebook also implements the similarity-centric analogous bars method.
#
# ## 2. Comparison of `Q` and `R`
# * This notebook contains a comparison to existing methods (induced matching, cycle registration) and application of the analogous bars method.
#
# ## 3. Comparison of `P` and `R`
#
# #### Outline
# 1. Load points
# 2. Application of induced matching and cycle registration
# 3. Application of similarity-centric analogous bars method.

# %%
include("../../../extension_method.jl")
# Out:
# HTML{String}("<script>\n// Immediately-invoked-function-expression to avoid global variables.\n(function() {\n    var warning_div = document.getElementById(\"webio-warning-6452897574250202482\");\n    var hide = function () {\n        var script = document.getElementById(\"webio-setup-16567600875401435217\");\n        var parent = script && script.parentElement;\n        var grandparent = parent && parent.parentElement;\n        if (grandparent) {\n            grandparent.style.display = \"none\";\n        }\n        warning_div.style.display = \"none\";\n    };\n    if (typeof Jupyter !== \"undefined\") {\n        console.log(\"WebIO detected Jupyter notebook environment.\");\n        // Jupyter notebook.\n        var extensions = (\n            Jupyter\n            && Jupyter.notebook.config.data\n            && Jupyter.notebook.config.data.load_extensions\n        );\n        if (extensions && extensions[\"webio-jupyter-notebook\"]) {\n            // Extension already loaded.\n            console.log(\"Jupyter WebIO nbextension detected; not loading ad-hoc.\");\n            hide();\n            return;\n        }\n    } else if (window.location.pathname.includes(\"/lab\")) {\n        // Guessing JupyterLa\n        console.log(\"Jupyter Lab detected; make sure the @webio/jupyter-lab-provider labextension is installed.\");\n        hide();\n        return;\n    }\n})();\n\n</script>\n<p\n    id=\"webio-warning-6452897574250202482\"\n    class=\"output_text output_stderr\"\n    style=\"padding: 1em; font-weight: bold;\"\n>\n    Unable to load WebIO. Please make sure WebIO works for your Jupyter client.\n    For troubleshooting, please see <a href=\"https://juliagizmos.github.io/WebIO.jl/latest/providers/ijulia/\">\n    the WebIO/IJulia documentation</a>.\n    <!-- TODO: link to installation docs. -->\n</p>\n")
# ┌ Warning: ORCA.jl has been deprecated and all savefig functionality
# │ has been implemented directly in PlotlyBase itself.
# │
# │ By implementing in PlotlyBase.jl, the savefig routines are automatically
# │ available to PlotlyJS.jl also.
# └ @ ORCA /opt/julia/packages/ORCA/U5XaN/src/ORCA.jl:8
# Main.ext

# %%
using .ext
using Distances
using Distributions
using Eirene
using Plots
using JLD
using Measures

# %% [markdown]
# # 0. Load points

# %% [markdown]
# Note: The points were generated using the following code

# %%
function sample_from_annulus(;mean = 1, variance = 0.3, n = 20)
    samples = zeros(n, 2)
    theta = rand(Uniform(0, 2*pi), n)
    distance = rand(Normal(mean, variance), n)
    
    for i=1:n
        samples[i, 1] = distance[i] * cos(theta[i]) 
        samples[i, 2] = distance[i] * sin(theta[i])
    end
    return samples
end
# Out:
# sample_from_annulus (generic function with 1 method)

# %%
n_small = 30
n_large = 20

P = sample_from_annulus(mean = 0.5, variance = 0.1, n = n_small)
Q = sample_from_annulus(mean = 1, variance = 0.3, n = n_large)
R = sample_from_annulus(mean = 1, variance = 0.3, n = n_large);

#save("three_point_clouds.jld", "P", P, "Q", Q, "R", R)

# %%
# load points
saved = load("three_point_clouds.jld")
P = saved["P"]
Q = saved["Q"]
R = saved["R"];
# Out:
# ┌ Warning: JLD incorrectly extends FileIO functions (see FileIO documentation)
# └ @ FileIO /opt/julia/packages/FileIO/JA3Vl/src/loadsave.jl:215

# %%
plot_P_Q(P, Q)
# Out:
#     <script type="text/javascript">
#         requirejs(["https://cdn.plot.ly/plotly-latest.min.js"], function(p) {
#             window.Plotly = p
#         });
#     </script>
# <!DOCTYPE html>
# <html>
#     <head>
#         <title>Plots.jl</title>
#         <meta http-equiv="content-type" content="text/html; charset=UTF-8">
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#     </head>
#     <body>
#             <div id="0e1f984d-dde6-41d3-88c2-21e30b5303c5" style="width:600px;height:400px;"></div>
#     <script>
#     PLOT = document.getElementById('0e1f984d-dde6-41d3-88c2-21e30b5303c5');
#     Plotly.plot(PLOT, [
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "x": [
#             0.011334298556576297,
#             0.09610804545141757,
#             -0.5392087141906824,
#             0.47847160968225966,
#             -0.19380610871044335,
#             -0.24640854313336613,
#             -0.49720846908908334,
#             0.4747125573898018,
#             0.11684694437726106,
#             0.5137005515823297,
#             -0.4464667449390722,
#             0.6436652659622233,
#             0.5172066139594956,
#             0.38821995293653966,
#             -0.28714592084184565,
#             -0.40230591249850733,
#             0.5602562448394496,
#             -0.32285139945444413,
#             0.19913849384052723,
#             -0.08746299431363219
#         ],
#         "showlegend": true,
#         "mode": "markers",
#         "name": "P",
#         "zmin": null,
#         "legendgroup": "P",
#         "marker": {
#             "symbol": "circle",
#             "color": "rgba(0, 129, 129, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 10
#         },
#         "zmax": null,
#         "y": [
#             -0.538310472332233,
#             0.5220148911189555,
#             0.33633387191292113,
#             0.2528277147570927,
#             -0.5155242699370929,
#             -0.4717103190956037,
#             0.29428228023526287,
#             -0.06079355152168794,
#             0.5437274078854172,
#             -0.2247968726146456,
#             0.5865103860130026,
#             -0.013245936556589925,
#             0.2578134453491295,
#             0.3838006041747468,
#             -0.371136052897404,
#             0.3121961884770816,
#             -0.18498108772489452,
#             -0.3077762965303104,
#             0.3351286243193481,
#             -0.5715430962120742
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "x": [
#             0.838062495581637,
#             -0.5812176851983026,
#             -0.41910542841211473,
#             -0.24510819472703274,
#             0.7461211101787346,
#             -1.3149985210219568,
#             0.5061684536346406,
#             0.6813013185579501,
#             0.8489511992781004,
#             -0.7712461411734617,
#             -0.7476780874153952,
#             -1.1565427159978545,
#             1.369138307123332,
#             1.1049206297750722,
#             1.3513872621206866,
#             0.8720070127788282,
#             0.7166594027132052,
#             0.7529088976721927,
#             1.4716401031579176,
#             -0.8682763211719614
#         ],
#         "showlegend": true,
#         "mode": "markers",
#         "name": "Q",
#         "zmin": null,
#         "legendgroup": "Q",
#         "marker": {
#             "symbol": "x",
#             "color": "rgba(255, 141, 0, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 10
#         },
#         "zmax": null,
#         "y": [
#             -0.05619843176556775,
#             0.7874239008624924,
#             0.7332599630793425,
#             -0.6641366536412023,
#             -0.42181186442589425,
#             -0.42392527463246793,
#             0.24034007492599968,
#             0.41451614769569034,
#             -0.4673925788036644,
#             0.3759838995554585,
#             0.09331546540329595,
#             0.3705619435311422,
#             -1.0323443539011687,
#             0.4014587407106091,
#             1.115556266986947,
#             -0.7775281787563317,
#             0.5347896091650185,
#             0.6029655283125169,
#             0.25081242693040423,
#             0.3834021354238089
#         ],
#         "type": "scatter"
#     }
# ]
# , {
#     "showlegend": true,
#     "xaxis": {
#         "showticklabels": true,
#         "gridwidth": 0.5,
#         "tickvals": [],
#         "visible": true,
#         "ticks": "inside",
#         "range": [
#             -1.398597679747353,
#             1.5552392618833137
#         ],
#         "domain": [
#             0.006561679790026247,
#             0.9934383202099737
#         ],
#         "tickmode": "array",
#         "linecolor": "rgba(0, 0, 0, 1.000)",
#         "showgrid": true,
#         "title": "",
#         "mirror": true,
#         "tickangle": 0,
#         "showline": true,
#         "gridcolor": "rgba(0, 0, 0, 0.100)",
#         "titlefont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 15
#         },
#         "tickcolor": "rgb(0, 0, 0)",
#         "ticktext": [],
#         "zeroline": false,
#         "type": "-",
#         "tickfont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 11
#         },
#         "zerolinecolor": "rgba(0, 0, 0, 1.000)",
#         "anchor": "y1"
#     },
#     "paper_bgcolor": "rgba(255, 255, 255, 1.000)",
#     "annotations": [],
#     "height": 400,
#     "margin": {
#         "l": 0,
#         "b": 20,
#         "r": 0,
#         "t": 20
#     },
#     "plot_bgcolor": "rgba(255, 255, 255, 1.000)",
#     "yaxis": {
#         "showticklabels": true,
#         "gridwidth": 0.5,
#         "tickvals": [],
#         "visible": true,
#         "ticks": "inside",
#         "range": [
#             -1.0967813725278122,
#             1.1799932856135904
#         ],
#         "domain": [
#             0.00984251968503937,
#             0.9901574803149606
#         ],
#         "tickmode": "array",
#         "linecolor": "rgba(0, 0, 0, 1.000)",
#         "showgrid": true,
#         "title": "",
#         "mirror": true,
#         "tickangle": 0,
#         "showline": true,
#         "gridcolor": "rgba(0, 0, 0, 0.100)",
#         "titlefont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 15
#         },
#         "tickcolor": "rgb(0, 0, 0)",
#         "ticktext": [],
#         "zeroline": false,
#         "type": "-",
#         "tickfont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 11
#         },
#         "zerolinecolor": "rgba(0, 0, 0, 1.000)",
#         "anchor": "x1"
#     },
#     "legend": {
#         "tracegroupgap": 0,
#         "bordercolor": "rgba(0, 0, 0, 1.000)",
#         "bgcolor": "rgba(255, 255, 255, 1.000)",
#         "font": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 11
#         },
#         "y": 1.0,
#         "x": 1.0
#     },
#     "width": 600
# }
# );
#     </script>
#
#     </body>
# </html>

# %%
plot_P_Q(Q, R, P_label = "Q", Q_label = "R")
# Out:
# <!DOCTYPE html>
# <html>
#     <head>
#         <title>Plots.jl</title>
#         <meta http-equiv="content-type" content="text/html; charset=UTF-8">
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#     </head>
#     <body>
#             <div id="559c4c49-7387-46f3-84a5-2dd8194d67c2" style="width:600px;height:400px;"></div>
#     <script>
#     PLOT = document.getElementById('559c4c49-7387-46f3-84a5-2dd8194d67c2');
#     Plotly.plot(PLOT, [
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "x": [
#             0.838062495581637,
#             -0.5812176851983026,
#             -0.41910542841211473,
#             -0.24510819472703274,
#             0.7461211101787346,
#             -1.3149985210219568,
#             0.5061684536346406,
#             0.6813013185579501,
#             0.8489511992781004,
#             -0.7712461411734617,
#             -0.7476780874153952,
#             -1.1565427159978545,
#             1.369138307123332,
#             1.1049206297750722,
#             1.3513872621206866,
#             0.8720070127788282,
#             0.7166594027132052,
#             0.7529088976721927,
#             1.4716401031579176,
#             -0.8682763211719614
#         ],
#         "showlegend": true,
#         "mode": "markers",
#         "name": "Q",
#         "zmin": null,
#         "legendgroup": "Q",
#         "marker": {
#             "symbol": "circle",
#             "color": "rgba(0, 129, 129, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 10
#         },
#         "zmax": null,
#         "y": [
#             -0.05619843176556775,
#             0.7874239008624924,
#             0.7332599630793425,
#             -0.6641366536412023,
#             -0.42181186442589425,
#             -0.42392527463246793,
#             0.24034007492599968,
#             0.41451614769569034,
#             -0.4673925788036644,
#             0.3759838995554585,
#             0.09331546540329595,
#             0.3705619435311422,
#             -1.0323443539011687,
#             0.4014587407106091,
#             1.115556266986947,
#             -0.7775281787563317,
#             0.5347896091650185,
#             0.6029655283125169,
#             0.25081242693040423,
#             0.3834021354238089
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "x": [
#             -0.3255579674246518,
#             0.25512808295737105,
#             1.118356825472871,
#             -0.06934362336239511,
#             -1.5229968535608207,
#             0.6356006499283703,
#             -0.6369847921141697,
#             0.005987531030904364,
#             0.4030964498270508,
#             -0.08736301252193243,
#             -1.1999779698773048,
#             -1.0970766521241275,
#             0.6317285591654348,
#             0.9707760615120922,
#             -0.8822108104330701,
#             -0.6792858357598428,
#             1.2112008243081072,
#             0.40213185309411864,
#             -0.23797928366769694,
#             0.11851436189728753
#         ],
#         "showlegend": true,
#         "mode": "markers",
#         "name": "R",
#         "zmin": null,
#         "legendgroup": "R",
#         "marker": {
#             "symbol": "x",
#             "color": "rgba(255, 141, 0, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 10
#         },
#         "zmax": null,
#         "y": [
#             0.7443161918463682,
#             -1.2526705328682548,
#             0.6371516008765375,
#             -0.5732561243632649,
#             0.680029040094087,
#             -0.5967504727073452,
#             0.5730768136066757,
#             1.2360838148519488,
#             0.7701904332007575,
#             0.4035811003703625,
#             -0.2617182754483674,
#             -0.3935252744158049,
#             -1.1790720112822335,
#             -0.10024215535837327,
#             -0.7182412175630253,
#             -0.03868361688582627,
#             -0.3106160878488501,
#             0.9056722997191582,
#             -0.6861194474989248,
#             0.26383200634378917
#         ],
#         "type": "scatter"
#     }
# ]
# , {
#     "showlegend": true,
#     "xaxis": {
#         "showticklabels": true,
#         "gridwidth": 0.5,
#         "tickvals": [],
#         "visible": true,
#         "ticks": "inside",
#         "range": [
#             -1.612835962262383,
#             1.5614792118594798
#         ],
#         "domain": [
#             0.006561679790026247,
#             0.9934383202099737
#         ],
#         "tickmode": "array",
#         "linecolor": "rgba(0, 0, 0, 1.000)",
#         "showgrid": true,
#         "title": "",
#         "mirror": true,
#         "tickangle": 0,
#         "showline": true,
#         "gridcolor": "rgba(0, 0, 0, 0.100)",
#         "titlefont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 15
#         },
#         "tickcolor": "rgb(0, 0, 0)",
#         "ticktext": [],
#         "zeroline": false,
#         "type": "-",
#         "tickfont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 11
#         },
#         "zerolinecolor": "rgba(0, 0, 0, 1.000)",
#         "anchor": "y1"
#     },
#     "paper_bgcolor": "rgba(255, 255, 255, 1.000)",
#     "annotations": [],
#     "height": 400,
#     "margin": {
#         "l": 0,
#         "b": 20,
#         "r": 0,
#         "t": 20
#     },
#     "plot_bgcolor": "rgba(255, 255, 255, 1.000)",
#     "yaxis": {
#         "showticklabels": true,
#         "gridwidth": 0.5,
#         "tickvals": [],
#         "visible": true,
#         "ticks": "inside",
#         "range": [
#             -1.3273331632998608,
#             1.3107464452835549
#         ],
#         "domain": [
#             0.00984251968503937,
#             0.9901574803149606
#         ],
#         "tickmode": "array",
#         "linecolor": "rgba(0, 0, 0, 1.000)",
#         "showgrid": true,
#         "title": "",
#         "mirror": true,
#         "tickangle": 0,
#         "showline": true,
#         "gridcolor": "rgba(0, 0, 0, 0.100)",
#         "titlefont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 15
#         },
#         "tickcolor": "rgb(0, 0, 0)",
#         "ticktext": [],
#         "zeroline": false,
#         "type": "-",
#         "tickfont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 11
#         },
#         "zerolinecolor": "rgba(0, 0, 0, 1.000)",
#         "anchor": "x1"
#     },
#     "legend": {
#         "tracegroupgap": 0,
#         "bordercolor": "rgba(0, 0, 0, 1.000)",
#         "bgcolor": "rgba(255, 255, 255, 1.000)",
#         "font": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 11
#         },
#         "y": 1.0,
#         "x": 1.0
#     },
#     "width": 600
# }
# );
#     </script>
#
#     </body>
# </html>

# %% [markdown]
# # 1. Comparison of $P$ and $Q$

# %% [markdown]
# ## 1(a) Plot barcodes of $P$, $Q$, and $P \cup Q$

# %%
# compute distances among points
P_all = vcat(P, Q)
D_PQ = pairwise(Euclidean(), transpose(P_all), transpose(P_all), dims=2)

# Define submatrices 
n_P = size(P, 1)
D_P = D_PQ[1:n_P, 1:n_P]
D_Q = D_PQ[n_P+1:end, n_P+1:end]
D_P_Q = D_PQ[1:n_P, n_P+1:end]
    # rows (landmarks): P
    # columns (witness) : Q
D_Q_P = D_PQ[n_P+1:end, 1:n_P];
    # rows (landmarks): Q
    # columns (witness) : P

# %%
# run persistence
C_P = eirene(D_P, record = "all")
C_PQ = eirene(D_PQ, record = "all")
C_Q = eirene(D_Q, record = "all");

# %%
# plot all barcodes in dim 1
barcode_P = barcode(C_P, dim = 1)
barcode_PQ = barcode(C_PQ, dim = 1)
barcode_Q = barcode(C_Q, dim = 1)

l = grid(3,1)
p1 = plot_barcode(barcode_P, lw = 3, title = "Barcode(VR(P))", titlefontsize = 12)
p2 = plot_barcode(barcode_PQ, lw = 3, title = "Barcode(VR(P U Q))", titlefontsize = 12)
p3 = plot_barcode(barcode_Q, lw = 3, title = "Barcode(VR(Q))", titlefontsize = 12)
plot(p1, p2, p3, layout = l, size = (500, 700))
# Out:
# <!DOCTYPE html>
# <html>
#     <head>
#         <title>Plots.jl</title>
#         <meta http-equiv="content-type" content="text/html; charset=UTF-8">
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#     </head>
#     <body>
#             <div id="51317b21-5738-4ae5-9e9d-c0eabc0c1cdf" style="width:500px;height:700px;"></div>
#     <script>
#     PLOT = document.getElementById('51317b21-5738-4ae5-9e9d-c0eabc0c1cdf');
#     Plotly.plot(PLOT, [
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 1",
#             "class 1"
#         ],
#         "x": [
#             0.6250431199599833,
#             0.8349303812828015
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y1",
#         "zmin": null,
#         "legendgroup": "y1",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             1.0,
#             1.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x2",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y2",
#         "text": [
#             "class 1",
#             "class 1"
#         ],
#         "x": [
#             0.5921677375431854,
#             0.8349303812828015
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y1",
#         "zmin": null,
#         "legendgroup": "y1",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             1.0,
#             1.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x3",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y3",
#         "text": [
#             "class 1",
#             "class 1"
#         ],
#         "x": [
#             1.0483805477664,
#             1.262437081326607
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y1",
#         "zmin": null,
#         "legendgroup": "y1",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             1.0,
#             1.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     }
# ]
# , {
#     "paper_bgcolor": "rgba(255, 255, 255, 1.000)",
#     "height": 700,
#     "yaxis2": {
#         "showticklabels": true,
#         "gridwidth": 0.5,
#         "tickvals": [],
#         "visible": true,
#         "ticks": "inside",
#         "range": [
#             -1.0,
#             2.0
#         ],
#         "domain": [
#             0.3773278340207474,
#             0.6147356580427447
#         ],
#         "tickmode": "array",
#         "linecolor": "rgba(0, 0, 0, 1.000)",
#         "showgrid": true,
#         "title": "",
#         "mirror": true,
#         "tickangle": 0,
#         "showline": true,
#         "gridcolor": "rgba(0, 0, 0, 0.100)",
#         "titlefont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 15
#         },
#         "tickcolor": "rgb(0, 0, 0)",
#         "ticktext": [],
#         "zeroline": false,
#         "type": "-",
#         "tickfont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 11
#         },
#         "zerolinecolor": "rgba(0, 0, 0, 1.000)",
#         "anchor": "x2"
#     },
#     "xaxis3": {
#         "showticklabels": true,
#         "gridwidth": 0.5,
#         "tickvals": [
#             1.05,
#             1.1,
#             1.1500000000000001,
#             1.2000000000000002,
#             1.25
#         ],
#         "visible": true,
#         "ticks": "inside",
#         "range": [
#             1.041958851759594,
#             1.2688587773334132
#         ],
#         "domain": [
#             0.007874015748031496,
#             0.9921259842519685
#         ],
#         "tickmode": "array",
#         "linecolor": "rgba(0, 0, 0, 1.000)",
#         "showgrid": true,
#         "title": "",
#         "mirror": true,
#         "tickangle": 0,
#         "showline": true,
#         "gridcolor": "rgba(0, 0, 0, 0.100)",
#         "titlefont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 15
#         },
#         "tickcolor": "rgb(0, 0, 0)",
#         "ticktext": [
#             "1.05",
#             "1.10",
#             "1.15",
#             "1.20",
#             "1.25"
#         ],
#         "zeroline": false,
#         "type": "-",
#         "tickfont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 11
#         },
#         "zerolinecolor": "rgba(0, 0, 0, 1.000)",
#         "anchor": "y3"
#     },
#     "yaxis1": {
#         "showticklabels": true,
#         "gridwidth": 0.5,
#         "tickvals": [],
#         "visible": true,
#         "ticks": "inside",
#         "range": [
#             -1.0,
#             2.0
#         ],
#         "domain": [
#             0.7106611673540807,
#             0.948068991376078
#         ],
#         "tickmode": "array",
#         "linecolor": "rgba(0, 0, 0, 1.000)",
#         "showgrid": true,
#         "title": "",
#         "mirror": true,
#         "tickangle": 0,
#         "showline": true,
#         "gridcolor": "rgba(0, 0, 0, 0.100)",
#         "titlefont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 15
#         },
#         "tickcolor": "rgb(0, 0, 0)",
#         "ticktext": [],
#         "zeroline": false,
#         "type": "-",
#         "tickfont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 11
#         },
#         "zerolinecolor": "rgba(0, 0, 0, 1.000)",
#         "anchor": "x1"
#     },
#     "annotations": [
#         {
#             "yanchor": "top",
#             "xanchor": "center",
#             "rotation": -0.0,
#             "y": 1.0,
#             "font": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "family": "sans-serif",
#                 "size": 17
#             },
#             "yref": "paper",
#             "showarrow": false,
#             "text": "Barcode(VR(P))",
#             "xref": "paper",
#             "x": 0.5
#         },
#         {
#             "yanchor": "top",
#             "xanchor": "center",
#             "rotation": -0.0,
#             "y": 0.6666666666666666,
#             "font": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "family": "sans-serif",
#                 "size": 17
#             },
#             "yref": "paper",
#             "showarrow": false,
#             "text": "Barcode(VR(P U Q))",
#             "xref": "paper",
#             "x": 0.5
#         },
#         {
#             "yanchor": "top",
#             "xanchor": "center",
#             "rotation": -0.0,
#             "y": 0.3333333333333333,
#             "font": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "family": "sans-serif",
#                 "size": 17
#             },
#             "yref": "paper",
#             "showarrow": false,
#             "text": "Barcode(VR(Q))",
#             "xref": "paper",
#             "x": 0.5
#         }
#     ],
#     "plot_bgcolor": "rgba(255, 255, 255, 1.000)",
#     "showlegend": false,
#     "xaxis1": {
#         "showticklabels": true,
#         "gridwidth": 0.5,
#         "tickvals": [
#             0.65,
#             0.7000000000000001,
#             0.75,
#             0.8
#         ],
#         "visible": true,
#         "ticks": "inside",
#         "range": [
#             0.6187465021202988,
#             0.841226999122486
#         ],
#         "domain": [
#             0.007874015748031496,
#             0.9921259842519685
#         ],
#         "tickmode": "array",
#         "linecolor": "rgba(0, 0, 0, 1.000)",
#         "showgrid": true,
#         "title": "",
#         "mirror": true,
#         "tickangle": 0,
#         "showline": t

# %% [markdown]
# The features of P and Q exist at very different scales. Therefore, any attempt to matching between `barcode(VR(Q))` and `barcode(VR(P U Q))` will be trivial.

# %% [markdown]
# ## 1(b) Implement the similarity-centric analogous bars method

# %%
# Compute Vietoris-Rips persistence 
dim = 1
VR_P = eirene(D_P, record = "all", maxdim = dim)
VR_Q = eirene(D_Q, record = "all", maxdim = dim )

# Compute Witness filtration
W_P = compute_Witness_persistence(D_P_Q, maxdim = dim)
W_Q = compute_Witness_persistence(D_Q_P, maxdim = dim);

# %%
# plot all four barcodes
barcode_P = barcode(VR_P, dim = 1)
barcode_W_PQ = barcode(W_P["eirene_output"], dim = 1)
barcode_W_QP = barcode(W_Q["eirene_output"], dim = 1)
barcode_Q = barcode(VR_Q, dim = 1)

l = grid(4,1)
p1 = plot_barcode(barcode_P, lw = 3, title = "Barcode(VR(P))", titlefontsize = 12)
p2 = plot_barcode(barcode_W_PQ, lw = 3, title = "Barcode(W(P,Q))", titlefontsize = 12)
p3 = plot_barcode(barcode_W_QP, lw = 3, title = "Barcode(W(Q,P))", titlefontsize = 12)
p4 = plot_barcode(barcode_Q, lw = 2, title = "Barcode(VR(Q))", titlefontsize = 12)
plot(p1, p2, p3, p4, layout = l, size = (500, 700))
# Out:
# <!DOCTYPE html>
# <html>
#     <head>
#         <title>Plots.jl</title>
#         <meta http-equiv="content-type" content="text/html; charset=UTF-8">
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#     </head>
#     <body>
#             <div id="fea215d5-26f0-4142-ad1f-37f68cd0d74a" style="width:500px;height:700px;"></div>
#     <script>
#     PLOT = document.getElementById('fea215d5-26f0-4142-ad1f-37f68cd0d74a');
#     Plotly.plot(PLOT, [
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 1",
#             "class 1"
#         ],
#         "x": [
#             0.6250431199599833,
#             0.8349303812828015
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y1",
#         "zmin": null,
#         "legendgroup": "y1",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             1.0,
#             1.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x2",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y2",
#         "text": [
#             "class 1",
#             "class 1"
#         ],
#         "x": [
#             0.74396477347921,
#             0.9772078808350415
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y1",
#         "zmin": null,
#         "legendgroup": "y1",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             1.0,
#             1.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x3",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y3",
#         "text": [
#             "class 1",
#             "class 1"
#         ],
#         "x": [
#             0.74396477347921,
#             0.9772078808350415
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y1",
#         "zmin": null,
#         "legendgroup": "y1",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             1.0,
#             1.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x4",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y4",
#         "text": [
#             "class 1",
#             "class 1"
#         ],
#         "x": [
#             1.0483805477664,
#             1.262437081326607
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y1",
#         "zmin": null,
#         "legendgroup": "y1",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 2
#         },
#         "y": [
#             1.0,
#             1.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     }
# ]
# , {
#     "paper_bgcolor": "rgba(255, 255, 255, 1.000)",
#     "height": 700,
#     "yaxis4": {
#         "showticklabels": true,
#         "gridwidth": 0.5,
#         "tickvals": [],
#         "visible": true,
#         "ticks": "inside",
#         "range": [
#             -1.0,
#             2.0
#         ],
#         "domain": [
#             0.043994500687414076,
#             0.19806899137607803
#         ],
#         "tickmode": "array",
#         "linecolor": "rgba(0, 0, 0, 1.000)",
#         "showgrid": true,
#         "title": "",
#         "mirror": true,
#         "tickangle": 0,
#         "showline": true,
#         "gridcolor": "rgba(0, 0, 0, 0.100)",
#         "titlefont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 15
#         },
#         "tickcolor": "rgb(0, 0, 0)",
#         "ticktext": [],
#         "zeroline": false,
#         "type": "-",
#         "tickfont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 11
#         },
#         "zerolinecolor": "rgba(0, 0, 0, 1.000)",
#         "anchor": "x4"
#     },
#     "yaxis2": {
#         "showticklabels": true,
#         "gridwidth": 0.5,
#         "tickvals": [],
#         "visible": true,
#         "ticks": "inside",
#         "range": [
#             -1.0,
#             2.0
#         ],
#         "domain": [
#             0.5439945006874141,
#             0.698068991376078
#         ],
#         "tickmode": "array",
#         "linecolor": "rgba(0, 0, 0, 1.000)",
#         "showgrid": true,
#         "title": "",
#         "mirror": true,
#         "tickangle": 0,
#         "showline": true,
#         "gridcolor": "rgba(0, 0, 0, 0.100)",
#         "titlefont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 15
#         },
#         "tickcolor": "rgb(0, 0, 0)",
#         "ticktext": [],
#         "zeroline": false,
#         "type": "-",
#         "tickfont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 11
#         },
#         "zerolinecolor": "rgba(0, 0, 0, 1.000)",
#         "anchor": "x2"
#     },
#     "xaxis3": {
#         "showticklabels": true,
#         "gridwidth": 0.5,
#         "tickvals": [
#             0.75,
#             0.8,
#             0.8500000000000001,
#             0.9,
#             0.9500000000000001
#         ],
#         "visible": true,
#         "ticks": "inside",
#         "range": [
#             0.736967480258535,
#             0.9842051740557165
#         ],
#         "domain": [
#             0.007874015748031496,
#             0.9921259842519685
#         ],
#         "tickmode": "array",
#         "linecolor": "rgba(0, 0, 0, 1.000)",
#         "showgrid": true,
#         "title": "",
#         "mirror": true,
#         "tickangle": 0,
#         "showline": true,
#         "gridcolor": "rgba(0, 0, 0, 0.100)",
#         "titlefont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 15
#         },
#         "tickcolor": "rgb(0, 0, 0)",
#         "ticktext": [
#             "0.75",
#             "0.80",
#             "0.85",
#             "0.90",
#             "0.95"
#         ],
#         "zeroline": false,
#         "type": "-",
#         "tickfont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 11
#         },
#         "zerolinecolor": "rgba(0, 0, 0, 1.000)",
#         "anchor": "y3"
#     },
#     "xaxis4": {
#         "showticklabels": true,
#         "gridwidth": 0.5,
#         "tickvals": [
#             1.05,
#             1.1,
#             1.1500000000000001,
#             1.2000000000000002,
#             1.25
#         ],
#         "visible": true,
#         "ticks": "inside",
#         "range": [
#             1.041958851759594,
#             1.2688587773334132
#         ],
#         "domain": [
#             0.007874015748031496,
#             0.9921259842519685
#         ],
#         "tickmode": "array",
#         "linecolor": "rgba(0, 0, 0, 1.000)",
#         "showgrid": true,
#         "title": "",
#         "mirror": true,
#         "tickangle": 0,
#         "showline": true,
#         "gridcolor": "rgba(0, 0, 0, 0.100)",
#         "titlefont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 15
#         },
#         "tickcolor": "rgb(0, 0, 0)",
#         "ticktext": [
#             "1.05",
#             "1.10",
#             "1.15",
#             "1.20",
#             "1.25"
#         ],
#         "zeroline": false,
#         "type": "-",
#         "tickfont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 11
#         },
#         "zerolinecolor": "rgba(0, 0, 0, 1.000)",
#         "anchor": "y4"
#     },
#     "yaxis1": {
#         "showticklabels": true,
#         "gridwidth": 0.5,
#         "tickvals": [

# %%
# select Witness bar
W_PQ_bar = 1

# run extension
extension_P, extension_Q = run_similarity_analogous(VR_P = VR_P, 
                                                    D_P = D_P, 
                                                    VR_Q = VR_Q, 
                                                    D_Q = D_Q, 
                                                    W_PQ = W_P, 
                                                    W_PQ_bar = W_PQ_bar, 
                                                    dim = dim);

# %%
plot_analogous_bars(extension_P, extension_Q, lw_VR_P = 8)
# Out:
# <!DOCTYPE html>
# <html>
#     <head>
#         <title>Plots.jl</title>
#         <meta http-equiv="content-type" content="text/html; charset=UTF-8">
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#     </head>
#     <body>
#             <div id="4915924b-f49e-4843-ae78-41561074a26f" style="width:500px;height:1000px;"></div>
#     <script>
#     PLOT = document.getElementById('4915924b-f49e-4843-ae78-41561074a26f');
#     Plotly.plot(PLOT, [
#     {
#         "xaxis": "x2",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y2",
#         "text": [
#             "class 1",
#             "class 1"
#         ],
#         "x": [
#             0.6250431199599833,
#             0.6250431199599833
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y1",
#         "zmin": null,
#         "legendgroup": "y1",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 8
#         },
#         "y": [
#             1.0,
#             1.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x2",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y2",
#         "text": [
#             "class 1",
#             "class 1"
#         ],
#         "x": [
#             0.6250431199599833,
#             0.8349303812828015
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y2",
#         "zmin": null,
#         "legendgroup": "y2",
#         "zmax": null,
#         "line": {
#             "color": "rgba(238, 18, 137, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 8
#         },
#         "y": [
#             1.0,
#             1.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x2",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y2",
#         "x": [
#             0.6250431199599833,
#             0.6250431199599833
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y3",
#         "zmin": null,
#         "legendgroup": "y3",
#         "zmax": null,
#         "line": {
#             "color": "rgba(255, 0, 0, 1.000)",
#             "shape": "linear",
#             "dash": "dot",
#             "width": 1
#         },
#         "y": [
#             -301.0,
#             302.0
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x3",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y3",
#         "text": [
#             "class 1",
#             "class 1"
#         ],
#         "x": [
#             0.74396477347921,
#             0.9772078808350415
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y1",
#         "zmin": null,
#         "legendgroup": "y1",
#         "zmax": null,
#         "line": {
#             "color": "rgba(0, 178, 238, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": null
#         },
#         "y": [
#             1.0,
#             1.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x4",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y4",
#         "text": [
#             "class 1",
#             "class 1"
#         ],
#         "x": [
#             0.74396477347921,
#             0.9772078808350415
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y1",
#         "zmin": null,
#         "legendgroup": "y1",
#         "zmax": null,
#         "line": {
#             "color": "rgba(0, 178, 238, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": null
#         },
#         "y": [
#             1.0,
#             1.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x5",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y5",
#         "text": [
#             "class 1",
#             "class 1"
#         ],
#         "x": [
#             1.0483805477664,
#             1.0483805477664
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y1",
#         "zmin": null,
#         "legendgroup": "y1",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": null
#         },
#         "y": [
#             1.0,
#             1.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x5",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y5",
#         "text": [
#             "class 1",
#             "class 1"
#         ],
#         "x": [
#             1.0483805477664,
#             1.262437081326607
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y2",
#         "zmin": null,
#         "legendgroup": "y2",
#         "zmax": null,
#         "line": {
#             "color": "rgba(238, 18, 137, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": null
#         },
#         "y": [
#             1.0,
#             1.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x5",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y5",
#         "x": [
#             1.0483805477664,
#             1.0483805477664
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y3",
#         "zmin": null,
#         "legendgroup": "y3",
#         "zmax": null,
#         "line": {
#             "color": "rgba(255, 0, 0, 1.000)",
#             "shape": "linear",
#             "dash": "dot",
#             "width": 1
#         },
#         "y": [
#             -301.0,
#             302.0
#         ],
#         "type": "scatter"
#     }
# ]
# , {
#     "paper_bgcolor": "rgba(255, 255, 255, 1.000)",
#     "height": 1000,
#     "yaxis4": {
#         "showticklabels": true,
#         "gridwidth": 0.5,
#         "tickvals": [],
#         "visible": true,
#         "ticks": "inside",
#         "range": [
#             -1.0,
#             2.0
#         ],
#         "domain": [
#             0.27278379265091873,
#             0.45040135608049003
#         ],
#         "tickmode": "array",
#         "linecolor": "rgba(0, 0, 0, 1.000)",
#         "showgrid": true,
#         "title": "",
#         "mirror": true,
#         "tickangle": 0,
#         "showline": true,
#         "gridcolor": "rgba(0, 0, 0, 0.100)",
#         "titlefont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 15
#         },
#         "tickcolor": "rgb(0, 0, 0)",
#         "ticktext": [],
#         "zeroline": false,
#         "type": "-",
#         "tickfont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 11
#         },
#         "zerolinecolor": "rgba(0, 0, 0, 1.000)",
#         "anchor": "x4"
#     },
#     "yaxis2": {
#         "showticklabels": true,
#         "gridwidth": 0.5,
#         "tickvals": [],
#         "visible": true,
#         "ticks": "inside",
#         "range": [
#             -1.0,
#             2.0
#         ],
#         "domain": [
#             0.7567590769903763,
#             0.9343766404199475
#         ],
#         "tickmode": "array",
#         "linecolor": "rgba(0, 0, 0, 1.000)",
#         "showgrid": true,
#         "title": "",
#         "mirror": true,
#         "tickangle": 0,
#         "showline": true,
#         "gridcolor": "rgba(0, 0, 0, 0.100)",
#         "titlefont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 15
#         },
#         "tickcolor": "rgb(0, 0, 0)",
#         "ticktext": [],
#         "zeroline": false,
#         "type": "-",
#         "tickfont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 11
#         },
#         "zerolinecolor": "rgba(0, 0, 0, 1.000)",
#         "anchor": "x2"
#     },
#     "xaxis3": {
#         "showticklabel

# %% [markdown]
# # 2. Comparison of `Q` and `R`

# %% [markdown]
# ## 2(a). Plot barcodes on $Q$, $R$, and $Q \cup R$

# %%
# compute distances among points
same_dist = vcat(Q, R)
D_QR = pairwise(Euclidean(), transpose(same_dist), transpose(same_dist), dims=2)

# Define submatrices
n_Q = size(Q, 1)
D_Q = D_QR[1:n_Q, 1:n_Q]
D_R = D_QR[n_Q+1:end, n_Q+1:end]
D_Q_R = D_QR[1:n_Q, n_Q+1:end]
    # rows (landmarks): Q
    # columns (witness) : R
D_R_Q = D_QR[n_Q+1:end, 1:n_Q];
    # rows (landmarks): R
    # columns (witness) : Q

# %%
# run persistence
C_Q = eirene(D_Q, record = "all")
C_QR = eirene(D_QR, record = "all")
C_R = eirene(D_R, record = "all");

# %%
# plot all barcodes in dim 1
barcode_Q = barcode(C_Q, dim = 1)
barcode_QR = barcode(C_QR, dim = 1)
barcode_R = barcode(C_R, dim = 1)

l = grid(3,1)
p1 = plot_barcode(barcode_Q, lw = 3, title = "Barcode(VR(Q))", titlefontsize = 12)
p2 = plot_barcode(barcode_QR, lw = 3, title = "Barcode(VR(Q U R))", titlefontsize = 12)
p3 = plot_barcode(barcode_R, lw = 3, title = "Barcode(VR(R))", titlefontsize = 12)
plot(p1, p2, p3, layout = l, size = (500, 700))
# Out:
# <!DOCTYPE html>
# <html>
#     <head>
#         <title>Plots.jl</title>
#         <meta http-equiv="content-type" content="text/html; charset=UTF-8">
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#     </head>
#     <body>
#             <div id="1abc3c21-0136-4afa-ab39-ccaf29fbe8b7" style="width:500px;height:700px;"></div>
#     <script>
#     PLOT = document.getElementById('1abc3c21-0136-4afa-ab39-ccaf29fbe8b7');
#     Plotly.plot(PLOT, [
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 1",
#             "class 1"
#         ],
#         "x": [
#             1.0483805477664,
#             1.262437081326607
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y1",
#         "zmin": null,
#         "legendgroup": "y1",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             1.0,
#             1.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x2",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y2",
#         "text": [
#             "class 1",
#             "class 1"
#         ],
#         "x": [
#             0.3868342416260324,
#             0.3922714939278195
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y1",
#         "zmin": null,
#         "legendgroup": "y1",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             1.0,
#             1.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x2",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y2",
#         "text": [
#             "class 2",
#             "class 2"
#         ],
#         "x": [
#             0.5193250950135967,
#             0.5297766994726083
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y2",
#         "zmin": null,
#         "legendgroup": "y2",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             2.0,
#             2.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x2",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y2",
#         "text": [
#             "class 3",
#             "class 3"
#         ],
#         "x": [
#             0.5930917404438392,
#             0.729113664764338
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y3",
#         "zmin": null,
#         "legendgroup": "y3",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             3.0,
#             3.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x2",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y2",
#         "text": [
#             "class 5",
#             "class 5"
#         ],
#         "x": [
#             0.7053356738812793,
#             0.9295147917125612
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y4",
#         "zmin": null,
#         "legendgroup": "y4",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             4.0,
#             4.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x2",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y2",
#         "text": [
#             "class 4",
#             "class 4"
#         ],
#         "x": [
#             0.7510892139773243,
#             0.7582812799608022
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y5",
#         "zmin": null,
#         "legendgroup": "y5",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             5.0,
#             5.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x3",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y3",
#         "text": [
#             "class 2",
#             "class 2"
#         ],
#         "x": [
#             0.5930917404438392,
#             0.729113664764338
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y1",
#         "zmin": null,
#         "legendgroup": "y1",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             1.0,
#             1.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x3",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y3",
#         "text": [
#             "class 3",
#             "class 3"
#         ],
#         "x": [
#             0.7510892139773243,
#             0.7582812799608022
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y2",
#         "zmin": null,
#         "legendgroup": "y2",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             2.0,
#             2.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x3",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y3",
#         "text": [
#             "class 5",
#             "class 5"
#         ],
#         "x": [
#             0.7520170434408239,
#             1.0391886415606306
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y3",
#         "zmin": null,
#         "legendgroup": "y3",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             3.0,
#             3.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x3",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y3",
#         "text": [
#             "class 4",
#             "class 4"
#         ],
#         "x": [
#             0.9267685794465885,
#             1.0039822869550836
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y4",
#         "zmin": null,
#         "legendgroup": "y4",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             4.0,
#             4.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x3",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y3",
#         "text": [
#             "class 1",
#             "class 1"
#         ],
#         "x": [
#             0.9956049445174345,
#             1.0068982862823088
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y5",
#         "zmin": null,
#         "legendgroup": "y5",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "line

# %% [markdown]
# ## 2(b) Induced matching / cycle registration
# * We have $VR(Q) \rightarrow VR(Q \cup R) \leftarrow VR(R)$
# * To see the results of induced matching / cycle registration on this dataset, we need to find the induced matching between $VR(Q) \rightarrow VR(Q \cup R)$, and $VR(R) \rightarrow VR(Q \cup R)$
# * To find induced matching for $f: VR(Q) \rightarrow VR(Q \cup R)$, we need to compute the image persistence barcode $im(f)$. I'm not sure if there is a software for this, so for now, we'll just use a 'hack':
#     * For an interval $I$ in $VR(Q)$, find its cycle rep. Find the death time of this cycle in $VR(Q \cup R)$. If there exists an interval $I_* \in barcode(VR(Q \cup R))$, then induced matching will map $I$ to $I_*$.
#     * Similarly for induced matching via $g: VR(R) \to VR(Q \cup R)$.

# %% [markdown]
# ### 2(b)(i) Induced matching $ f: VR(Q) \to VR(Q \cup R) $
# * From the induced matching paper (2015) Theorem 6.1, if an interval $[b,d] \in barcode(VR(Q))$ matches to $[b', d'] \in barcode(VR(Q \cup R))$, they must satisfy $b' \leq b < d' \leq d$.
# * The unique interval (interval 1) of $barcode(VR(Q))$ has a birth time of $b = 1.05$. In $barcode(VR(Q \cup R))$, the latest death time is at $0.93$. So all $d' < b$. Interval 1 of $barcode(VR(Q))$ thus doesn't match to any intervals in $barcode(VR(Q \cup R))$.

# %% [markdown]
# ### 2(b)(ii) Induced matching $g: VR(R) \to VR(Q \cup R) $
# * To compute the induced matching between $barcode(VR(R))$ and $barcode(VR(Q \cup R))$, we need to find the barcode of the image persistence $im (g)$.
# * I'm not sure if there's any software for computing the barcode of the image persistence. So I just checked for the death time of interval 5 in $VR(Q \cup R)$.
# * The following code computes the death time of cycle 5 from $VR(R)$ in $VR(Q \cup R)$

# %%
S = classrep(C_R, class = 5, dim = 1)

# cyclerep as [simplex1, simplex2, ..., simplexk], where each simplex is a list of vertices
chain_vertices = []
for j=1:size(S)[2]
    append!(chain_vertices, [sort(S[:,j])])
end
n_Q = size(Q, 1)
chain_vertices = [item + [n_Q, n_Q] for item in chain_vertices]
chain = ext.chain_to_index(chain_vertices, C_union)
Eirene.deathtime(C_union, chain = chain, dim = 1)
# Out:
# 0.9295147917125612

# %% [markdown]
# From looking at the death time, we know that interval 5 of $VR(R)$ matches to interval 5 of $VR(Q \cup R)$.

# %% [markdown]
# ## 2(c). Implement the similarity-centric analogous bars method

# %%
# Compute Vietoris-Rips persistence on two regions
dim = 1
VR_Q = eirene(D_Q, record = "all", maxdim = dim)
VR_R = eirene(D_R, record = "all", maxdim = dim )

# compute Witness persistence
W_QR = compute_Witness_persistence(D_Q_R, maxdim = dim)
W_RQ = compute_Witness_persistence(D_R_Q, maxdim = dim)

barcode_W_QR = barcode(W_QR["eirene_output"], dim = 1)
barcode_W_RQ = barcode(W_RQ["eirene_output"], dim = 1);

# %%
# plot all four barcodes
l = grid(4,1)
p1 = plot_barcode(barcode(VR_Q, dim = 1), lw = 3, title = "Barcode(VR(Q))", titlefontsize = 12)
p2 = plot_barcode(barcode(W_QR["eirene_output"], dim = 1) , lw = 3, title = "Barcode(W(Q,R))", titlefontsize = 12)
p3 = plot_barcode(barcode(W_RQ["eirene_output"], dim = 1) , lw = 3, title = "Barcode(W(R,Q))", titlefontsize = 12)
p4 = plot_barcode(barcode(VR_R, dim = 1), lw = 2, title = "Barcode(VR(R))", titlefontsize = 12)
plot(p1, p2, p3, p4, layout = l, size = (500, 700))
# Out:
# <!DOCTYPE html>
# <html>
#     <head>
#         <title>Plots.jl</title>
#         <meta http-equiv="content-type" content="text/html; charset=UTF-8">
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#     </head>
#     <body>
#             <div id="453b886b-e86d-401a-b6b4-02c559a7af92" style="width:500px;height:700px;"></div>
#     <script>
#     PLOT = document.getElementById('453b886b-e86d-401a-b6b4-02c559a7af92');
#     Plotly.plot(PLOT, [
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 1",
#             "class 1"
#         ],
#         "x": [
#             1.0483805477664,
#             1.262437081326607
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y1",
#         "zmin": null,
#         "legendgroup": "y1",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             1.0,
#             1.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x2",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y2",
#         "text": [
#             "class 2",
#             "class 2"
#         ],
#         "x": [
#             0.5760698611132902,
#             0.5905689945903578
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y1",
#         "zmin": null,
#         "legendgroup": "y1",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             1.0,
#             1.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x2",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y2",
#         "text": [
#             "class 3",
#             "class 3"
#         ],
#         "x": [
#             0.7786525995132142,
#             0.9510285639274938
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y2",
#         "zmin": null,
#         "legendgroup": "y2",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             2.0,
#             2.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x2",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y2",
#         "text": [
#             "class 1",
#             "class 1"
#         ],
#         "x": [
#             0.8294082803524955,
#             0.8832830613314768
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y3",
#         "zmin": null,
#         "legendgroup": "y3",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             3.0,
#             3.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x3",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y3",
#         "text": [
#             "class 1",
#             "class 1"
#         ],
#         "x": [
#             0.5760698611132902,
#             0.5905689945903578
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y1",
#         "zmin": null,
#         "legendgroup": "y1",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             1.0,
#             1.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x3",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y3",
#         "text": [
#             "class 3",
#             "class 3"
#         ],
#         "x": [
#             0.7786525995132142,
#             0.9510285639274938
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y2",
#         "zmin": null,
#         "legendgroup": "y2",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             2.0,
#             2.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x3",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y3",
#         "text": [
#             "class 2",
#             "class 2"
#         ],
#         "x": [
#             0.8294082803524955,
#             0.8832830613314768
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y3",
#         "zmin": null,
#         "legendgroup": "y3",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             3.0,
#             3.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x4",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y4",
#         "text": [
#             "class 2",
#             "class 2"
#         ],
#         "x": [
#             0.5930917404438392,
#             0.729113664764338
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y1",
#         "zmin": null,
#         "legendgroup": "y1",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 2
#         },
#         "y": [
#             1.0,
#             1.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x4",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y4",
#         "text": [
#             "class 3",
#             "class 3"
#         ],
#         "x": [
#             0.7510892139773243,
#             0.7582812799608022
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y2",
#         "zmin": null,
#         "legendgroup": "y2",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 2
#         },
#         "y": [
#             2.0,
#             2.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x4",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y4",
#         "text": [
#             "class 5",
#             "class 5"
#         ],
#         "x": [
#             0.7520170434408239,
#             1.0391886415606306
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y3",
#         "zmin": null,
#         "legendgroup": "y3",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 2
#         },
#         "y": [
#             3.0,
#             3.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x4",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y4",
#         "text": [
#             "class 4",
#             "class 4"
#         ],
#         "x": [
#             0.9267685794465885,
#             1.0039822869550836
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y4",
#         "zmin": null,
#         "legendgroup": "y4",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "lin

# %%
# select interval
W_QR_bar = 3

# run similarity-centric analogous bars method
extension_Q, extension_R = run_similarity_analogous(VR_P = VR_Q, 
                                                    D_P = D_Q, 
                                                    VR_Q = VR_R, 
                                                    D_Q = D_R, 
                                                    W_PQ = W_QR, 
                                                    W_PQ_bar = W_QR_bar, 
                                                    dim = dim);

# %%
plot_analogous_bars(extension_P, extension_Q)
# Out:
# <!DOCTYPE html>
# <html>
#     <head>
#         <title>Plots.jl</title>
#         <meta http-equiv="content-type" content="text/html; charset=UTF-8">
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#     </head>
#     <body>
#             <div id="4254d8d6-3f61-49a4-aef6-8b118c66e785" style="width:500px;height:1000px;"></div>
#     <script>
#     PLOT = document.getElementById('4254d8d6-3f61-49a4-aef6-8b118c66e785');
#     Plotly.plot(PLOT, [
#     {
#         "xaxis": "x2",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y2",
#         "text": [
#             "class 4",
#             "class 4"
#         ],
#         "x": [
#             0.08792248145060767,
#             0.11126242586590816
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y1",
#         "zmin": null,
#         "legendgroup": "y1",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": null
#         },
#         "y": [
#             1.0,
#             1.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x2",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y2",
#         "text": [
#             "class 5",
#             "class 5"
#         ],
#         "x": [
#             0.100927884170719,
#             0.12507744569856682
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y2",
#         "zmin": null,
#         "legendgroup": "y2",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": null
#         },
#         "y": [
#             2.0,
#             2.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x2",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y2",
#         "text": [
#             "class 1",
#             "class 1"
#         ],
#         "x": [
#             0.10175613326313898,
#             0.12445766055326965
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y3",
#         "zmin": null,
#         "legendgroup": "y3",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": null
#         },
#         "y": [
#             3.0,
#             3.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x2",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y2",
#         "text": [
#             "class 6",
#             "class 6"
#         ],
#         "x": [
#             0.10947754353429609,
#             0.11533247623196696
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y4",
#         "zmin": null,
#         "legendgroup": "y4",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": null
#         },
#         "y": [
#             4.0,
#             4.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x2",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y2",
#         "text": [
#             "class 7",
#             "class 7"
#         ],
#         "x": [
#             0.11007656984410004,
#             0.14447283672155078
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y5",
#         "zmin": null,
#         "legendgroup": "y5",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": null
#         },
#         "y": [
#             5.0,
#             5.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x2",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y2",
#         "text": [
#             "class 2",
#             "class 2"
#         ],
#         "x": [
#             0.11020961050337834,
#             0.11175335503395499
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y6",
#         "zmin": null,
#         "legendgroup": "y6",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": null
#         },
#         "y": [
#             6.0,
#             6.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x2",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y2",
#         "text": [
#             "class 8",
#             "class 8"
#         ],
#         "x": [
#             0.11208139781179971,
#             0.11622879425830553
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y7",
#         "zmin": null,
#         "legendgroup": "y7",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": null
#         },
#         "y": [
#             7.0,
#             7.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x2",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y2",
#         "text": [
#             "class 9",
#             "class 9"
#         ],
#         "x": [
#             0.11269790379962791,
#             0.12745352656678474
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y8",
#         "zmin": null,
#         "legendgroup": "y8",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": null
#         },
#         "y": [
#             8.0,
#             8.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x2",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y2",
#         "text": [
#             "class 10",
#             "class 10"
#         ],
#         "x": [
#             0.12107679006422391,
#             0.1454253068048423
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y9",
#         "zmin": null,
#         "legendgroup": "y9",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": null
#         },
#         "y": [
#             9.0,
#             9.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x2",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y2",
#         "text": [
#             "class 3",
#             "class 3"
#         ],
#         "x": [
#             0.12654256738551817,
#             0.1360209179277099
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y10",
#         "zmin": null,
#         "legendgroup": "y10",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": null
#         },
#         "y": [
#             10.0,
#             10.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x2",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y2",
#         "text": [
#             "class 11",
#             "class 11"
#         ],
#         "x": [
#             0.13917477989659305,
#             0.182960395739603
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y11",
#         "zmin": null,
#         "legendgroup": "y11",
#         "zmax": null,
#         "line": {
#             "c

# %%
# save all relevant barcodes
save("annulus_barcodes.jld", 
    "barcode_P", barcode_P,
    "barcode_Q", barcode_Q,
    "barcode_R", barcode_R,
    "barcode_PQ", barcode_PQ,
    "barcode_QR", barcode_QR,
    "barcode_W_QR", barcode_W_QR,
    "barcode_W_RQ", barcode_W_RQ,
    "int_QR", [5],
    "int_R", [5],
    "bar_Q", [1],
    "bar_W_QR", [3],
    "bar_W_RQ", [3],
    "bar_R", [5]
    )
# Out:
# ┌ Warning: JLD incorrectly extends FileIO functions (see FileIO documentation)
# └ @ FileIO /opt/julia/packages/FileIO/JA3Vl/src/loadsave.jl:215

# %% [markdown]
# # 3. Comparison of $P$ and $R$

# %% [markdown]
# ## 3(a) Plot barcodes of $P$, $R$, and $P \cup R$

# %%
# compute distances among points
PR_all = vcat(P, R)
D_PR = pairwise(Euclidean(), transpose(PR_all), transpose(PR_all), dims=2)

# Define submatrices 
n_P = size(P, 1)
D_P = D_PR[1:n_P, 1:n_P]
D_R = D_PR[n_P+1:end, n_P+1:end]
D_P_R = D_PR[1:n_P, n_P+1:end]
    # rows (landmarks): P
    # columns (witness) : R
D_R_P = D_PR[n_P+1:end, 1:n_P];
    # rows (landmarks): R
    # columns (witness) : P

# %%
# run persistence
C_P = eirene(D_P, record = "all")
C_PR = eirene(D_PR, record = "all")
C_R = eirene(D_R, record = "all");

# %%
# plot all barcodes in dim 1
barcode_P = barcode(C_P, dim = 1)
barcode_PR = barcode(C_PR, dim = 1)
barcode_R = barcode(C_R, dim = 1)

l = grid(3,1)
p1 = plot_barcode(barcode_P, lw = 3, title = "Barcode(VR(P))", titlefontsize = 12)
p2 = plot_barcode(barcode_PR, lw = 3, title = "Barcode(VR(P U R))", titlefontsize = 12)
p3 = plot_barcode(barcode_R, lw = 3, title = "Barcode(VR(R))", titlefontsize = 12)
plot(p1, p2, p3, layout = l, size = (500, 700))
# Out:
# <!DOCTYPE html>
# <html>
#     <head>
#         <title>Plots.jl</title>
#         <meta http-equiv="content-type" content="text/html; charset=UTF-8">
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#     </head>
#     <body>
#             <div id="3d0997bb-0238-4ca2-a0a4-2e5d8f752216" style="width:500px;height:700px;"></div>
#     <script>
#     PLOT = document.getElementById('3d0997bb-0238-4ca2-a0a4-2e5d8f752216');
#     Plotly.plot(PLOT, [
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 1",
#             "class 1"
#         ],
#         "x": [
#             0.6250431199599833,
#             0.8349303812828015
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y1",
#         "zmin": null,
#         "legendgroup": "y1",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             1.0,
#             1.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x2",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y2",
#         "text": [
#             "class 2",
#             "class 2"
#         ],
#         "x": [
#             0.24882785732107993,
#             0.2591533233580061
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y1",
#         "zmin": null,
#         "legendgroup": "y1",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             1.0,
#             1.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x2",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y2",
#         "text": [
#             "class 6",
#             "class 6"
#         ],
#         "x": [
#             0.5921677375431854,
#             0.8092713525599627
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y2",
#         "zmin": null,
#         "legendgroup": "y2",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             2.0,
#             2.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x2",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y2",
#         "text": [
#             "class 3",
#             "class 3"
#         ],
#         "x": [
#             0.5930917404438392,
#             0.7011755869930898
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y3",
#         "zmin": null,
#         "legendgroup": "y3",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             3.0,
#             3.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x2",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y2",
#         "text": [
#             "class 4",
#             "class 4"
#         ],
#         "x": [
#             0.6450318350209504,
#             0.7092087689702388
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y4",
#         "zmin": null,
#         "legendgroup": "y4",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             4.0,
#             4.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x2",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y2",
#         "text": [
#             "class 5",
#             "class 5"
#         ],
#         "x": [
#             0.7510892139773243,
#             0.7582812799608022
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y5",
#         "zmin": null,
#         "legendgroup": "y5",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             5.0,
#             5.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x2",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y2",
#         "text": [
#             "class 1",
#             "class 1"
#         ],
#         "x": [
#             0.9956049445174345,
#             1.0068982862823088
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y6",
#         "zmin": null,
#         "legendgroup": "y6",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             6.0,
#             6.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x3",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y3",
#         "text": [
#             "class 2",
#             "class 2"
#         ],
#         "x": [
#             0.5930917404438392,
#             0.729113664764338
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y1",
#         "zmin": null,
#         "legendgroup": "y1",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             1.0,
#             1.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x3",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y3",
#         "text": [
#             "class 3",
#             "class 3"
#         ],
#         "x": [
#             0.7510892139773243,
#             0.7582812799608022
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y2",
#         "zmin": null,
#         "legendgroup": "y2",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             2.0,
#             2.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x3",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y3",
#         "text": [
#             "class 5",
#             "class 5"
#         ],
#         "x": [
#             0.7520170434408239,
#             1.0391886415606306
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y3",
#         "zmin": null,
#         "legendgroup": "y3",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             3.0,
#             3.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x3",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y3",
#         "text": [
#             "class 4",
#             "class 4"
#         ],
#         "x": [
#             0.9267685794465885,
#             1.0039822869550836
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y4",
#         "zmin": null,
#         "legendgroup": "y4",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape":

# %% [markdown]
# ### 3(b)(i) Induced matching $f: VR(P) \to VR(P \cup R) $
# * To compute the induced matching between $barcode(VR(P))$ and $barcode(VR(P \cup R))$, we need to find the barcode of the image persistence $im (f)$.
# * I'm not sure if there's any software for computing the barcode of the image persistence. So I just checked for the death time of interval 1 (from barcode(VR(P)) ) in $VR(P \cup R)$.
# * The following code computes the death time of cycle 1 from $VR(P)$ in $VR(P \cup R)$

# %%
S = classrep(C_P, class = 1, dim = 1)

# cyclerep as [simplex1, simplex2, ..., simplexk], where each simplex is a list of vertices
chain_vertices = []
for j=1:size(S)[2]
    append!(chain_vertices, [sort(S[:,j])])
end
#n_Q = size(Q, 1)
#chain_vertices = [item + [n_Q, n_Q] for item in chain_vertices]
chain = ext.chain_to_index(chain_vertices, C_PR)
Eirene.deathtime(C_PR, chain = chain, dim = 1)
# Out:
# 0.8092713525599627

# %% [markdown]
# From looking at the death time, we know that interval 1 of $VR(P)$ matches to interval 6 of $VR(P \cup R)$.

# %% [markdown]
# ### 3(b)(ii) Induced matching $g: VR(R) \to VR(P \cup R) $
# * To compute the induced matching between $barcode(VR(R))$ and $barcode(VR(P \cup R))$, we need to find the barcode of the image persistence $im (g)$.
# * I'm not sure if there's any software for computing the barcode of the image persistence. So I just checked for the death time of interval 5 (from barcode(VR(R)) ) in $VR(P \cup R)$.
# * The following code computes the death time of cycle 5 from $VR(R)$ in $VR(P \cup R)$

# %%
S = classrep(C_R, class = 5, dim = 1)

# cyclerep as [simplex1, simplex2, ..., simplexk], where each simplex is a list of vertices
chain_vertices = []
for j=1:size(S)[2]
    append!(chain_vertices, [sort(S[:,j])])
end

n_P = size(P, 1)
chain_vertices = [item + [n_P, n_P] for item in chain_vertices]
chain = ext.chain_to_index(chain_vertices, C_PR)
Eirene.deathtime(C_PR, chain = chain, dim = 1)
# Out:
# 0.8092713525599627

# %% [markdown]
# From looking at the death time, we know that interval 5 of $VR(R)$ matches interval 6 of $VR(P \cup R)$.

# %%
l = grid(3,1)
p1 = plot_barcode(barcode_P, lw = 3, selected_bars = [1], title = "Barcode(VR(P))", titlefontsize = 12)
p2 = plot_barcode(barcode_PR, lw = 3, selected_bars = [6], title = "Barcode(VR(P U R))", titlefontsize = 12)
p3 = plot_barcode(barcode_R, lw = 3, selected_bars = [5], title = "Barcode(VR(R))", titlefontsize = 12)
plot(p1, p2, p3, layout = l, size = (500, 700))
# Out:
# <!DOCTYPE html>
# <html>
#     <head>
#         <title>Plots.jl</title>
#         <meta http-equiv="content-type" content="text/html; charset=UTF-8">
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#     </head>
#     <body>
#             <div id="46a779f3-1c8a-47a9-8372-ae9be36839a1" style="width:500px;height:700px;"></div>
#     <script>
#     PLOT = document.getElementById('46a779f3-1c8a-47a9-8372-ae9be36839a1');
#     Plotly.plot(PLOT, [
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 1",
#             "class 1"
#         ],
#         "x": [
#             0.6250431199599833,
#             0.8349303812828015
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y1",
#         "zmin": null,
#         "legendgroup": "y1",
#         "zmax": null,
#         "line": {
#             "color": "rgba(238, 18, 137, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             1.0,
#             1.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x2",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y2",
#         "text": [
#             "class 2",
#             "class 2"
#         ],
#         "x": [
#             0.24882785732107993,
#             0.2591533233580061
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y1",
#         "zmin": null,
#         "legendgroup": "y1",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             1.0,
#             1.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x2",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y2",
#         "text": [
#             "class 6",
#             "class 6"
#         ],
#         "x": [
#             0.5921677375431854,
#             0.8092713525599627
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y2",
#         "zmin": null,
#         "legendgroup": "y2",
#         "zmax": null,
#         "line": {
#             "color": "rgba(238, 18, 137, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             2.0,
#             2.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x2",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y2",
#         "text": [
#             "class 3",
#             "class 3"
#         ],
#         "x": [
#             0.5930917404438392,
#             0.7011755869930898
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y3",
#         "zmin": null,
#         "legendgroup": "y3",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             3.0,
#             3.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x2",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y2",
#         "text": [
#             "class 4",
#             "class 4"
#         ],
#         "x": [
#             0.6450318350209504,
#             0.7092087689702388
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y4",
#         "zmin": null,
#         "legendgroup": "y4",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             4.0,
#             4.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x2",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y2",
#         "text": [
#             "class 5",
#             "class 5"
#         ],
#         "x": [
#             0.7510892139773243,
#             0.7582812799608022
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y5",
#         "zmin": null,
#         "legendgroup": "y5",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             5.0,
#             5.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x2",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y2",
#         "text": [
#             "class 1",
#             "class 1"
#         ],
#         "x": [
#             0.9956049445174345,
#             1.0068982862823088
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y6",
#         "zmin": null,
#         "legendgroup": "y6",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             6.0,
#             6.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x3",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y3",
#         "text": [
#             "class 2",
#             "class 2"
#         ],
#         "x": [
#             0.5930917404438392,
#             0.729113664764338
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y1",
#         "zmin": null,
#         "legendgroup": "y1",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             1.0,
#             1.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x3",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y3",
#         "text": [
#             "class 3",
#             "class 3"
#         ],
#         "x": [
#             0.7510892139773243,
#             0.7582812799608022
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y2",
#         "zmin": null,
#         "legendgroup": "y2",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             2.0,
#             2.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x3",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y3",
#         "text": [
#             "class 5",
#             "class 5"
#         ],
#         "x": [
#             0.7520170434408239,
#             1.0391886415606306
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y3",
#         "zmin": null,
#         "legendgroup": "y3",
#         "zmax": null,
#         "line": {
#             "color": "rgba(238, 18, 137, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             3.0,
#             3.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x3",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y3",
#         "text": [
#             "class 4",
#             "class 4"
#         ],
#         "x": [
#             0.9267685794465885,
#             1.0039822869550836
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y4",
#         "zmin": null,
#         "legendgroup": "y4",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "l
