# %% [markdown]
# # Example: Feature-centric analogous bars
# * This notebook shows an application of the <b>feature-centric analogous bars method</b> to compare barcodes built on two different point clouds `P` and `Q`.
#
# #### Feature-centric analogous bars
# * <b> Inputs </b>
#     * Distance matrix among points in `P`
#     * Distance matrix among points in `Q`
#     * Corss-system distance matrix among `P` and `Q`.
# * <b> Goal </b>
#     * Given a selected bar in the Vietoris-Rips barcode `barcode(VR(P))`, find its representations in `barcode(VR(Q))`
# * <b> Implementation </b>:
#     * User selects a bar of interest from `barcode(VR(P))`
#     * The function `run_extension_VR_to_W_bar` finds the representation of the selected bar in the Witness complex `W(P,Q)`.
#     * We then apply Dowker's theorem to find the corresponding cycle in `W(Q,P)`.
#     * Lastly, we run the function `run_extension_W_to_VR_bar` to find the bar extension in `barcode(VR(Q))`.
#     * Note that we don't provide an individual function for feature-centric analogous bars method.
#     * All extension methds are implemented component-wise with $\mathbb{F}_2$ coefficients. We assume that all bars of barcodes have unique death times.
# * <b> Comparison to Algorithm 6 of paper </b>
#     * In the paper, we run the first extension method (from VR to W) and find the collection of all cycle extensions $E(\tau, W^\bullet_{P,Q})$. We then apply Dowker's Theorem to all such cycle extensions to find the collection $E(\tau, W^\bullet_{Q,P})$. For each cycle $[\sigma] \in E(\tau, W^\bullet_{Q,P})$, we run the second extension method (from W to VR).
#     * In our implementation, we don't apply the second extension method to the entire collection $E(\tau, W^\bullet_{Q,P})$ as this can require huge computation time. Instead, we allow the user to select a specific cycle in $E(\tau, W^\bullet_{P,Q})$ via `cycle_W_PQ`. We then find its corresponding cycle `cycle_W_QP` in $W^\bullet_{Q,P}$ via Dowker's Theorem and run the second extension method on `cycle_W_QP`.
#
#
# #### Example data
# * `P`: Points sampled from a "confused circle" on the torus.
# * `Q`: Points sampled from a torus. Contains `P`.
# * The goal is to identify which of the S1's of `Q` is encoded in `P`.
#
# #### Contents
# 1. Load points and visualize
# 2. Plot the four relevant barcodes
# 3. Run the extension method from VR to W
# 4. Apply Dowker's Theorem
# 5. Run the extension method from W to VR.
# 6. Explore cycle extension & bar extension under fixed interval decompositions of `barcode(VR(Q))`.
# 7. Explore alternative bar extensions under all possible interval decompositions of `barcode(VR(Q))`.

# %%
using Revise
includet("../../../extension_method.jl")
# Out:
# HTML{String}("<script>\n// Immediately-invoked-function-expression to avoid global variables.\n(function() {\n    var warning_div = document.getElementById(\"webio-warning-5237320912958657468\");\n    var hide = function () {\n        var script = document.getElementById(\"webio-setup-4178426397689951614\");\n        var parent = script && script.parentElement;\n        var grandparent = parent && parent.parentElement;\n        if (grandparent) {\n            grandparent.style.display = \"none\";\n        }\n        warning_div.style.display = \"none\";\n    };\n    if (typeof Jupyter !== \"undefined\") {\n        console.log(\"WebIO detected Jupyter notebook environment.\");\n        // Jupyter notebook.\n        var extensions = (\n            Jupyter\n            && Jupyter.notebook.config.data\n            && Jupyter.notebook.config.data.load_extensions\n        );\n        if (extensions && extensions[\"webio-jupyter-notebook\"]) {\n            // Extension already loaded.\n            console.log(\"Jupyter WebIO nbextension detected; not loading ad-hoc.\");\n            hide();\n            return;\n        }\n    } else if (window.location.pathname.includes(\"/lab\")) {\n        // Guessing JupyterLa\n        console.log(\"Jupyter Lab detected; make sure the @webio/jupyter-lab-provider labextension is installed.\");\n        hide();\n        return;\n    }\n})();\n\n</script>\n<p\n    id=\"webio-warning-5237320912958657468\"\n    class=\"output_text output_stderr\"\n    style=\"padding: 1em; font-weight: bold;\"\n>\n    Unable to load WebIO. Please make sure WebIO works for your Jupyter client.\n    For troubleshooting, please see <a href=\"https://juliagizmos.github.io/WebIO.jl/latest/providers/ijulia/\">\n    the WebIO/IJulia documentation</a>.\n    <!-- TODO: link to installation docs. -->\n</p>\n")
# ┌ Warning: ORCA.jl has been deprecated and all savefig functionality
# │ has been implemented directly in PlotlyBase itself.
# │
# │ By implementing in PlotlyBase.jl, the savefig routines are automatically
# │ available to PlotlyJS.jl also.
# └ @ ORCA /opt/julia/packages/ORCA/U5XaN/src/ORCA.jl:8

# %%
using .ext
using DelimitedFiles
using HDF5
using Printf
using Eirene
using Plots
using JLD

# %% [markdown]
# # 1. Load points and visualize
# * `P`: a "confused circle" on a torus
# * `Q`: points sampled from a torus

# %%
data = load("data.jld")
P = data["circle"] # 3-dimensional coordinates
P_theta = data["circle_theta"]
P_phi = data["circle_phi"]
Q = data["torus"] # 3-dimensional coordinates
Q_theta = data["torus_theta"]
Q_phi = data["torus_phi"];

# print number of points 
print("number of points in P: ", size(P,1), "\n")
print("number of points in Q: ", size(Q,1))
# Out:
# ┌ Warning: JLD incorrectly extends FileIO functions (see FileIO documentation)
# └ @ FileIO /opt/julia/packages/FileIO/JA3Vl/src/loadsave.jl:215
# number of points in P: 70
# number of points in Q: 300

# %% [markdown]
# Plot the points in 3D

# %%
plot_3D(P, Q, P_markersize = 3, Q_markersize = 2)
# Out:
#     <script type="text/javascript">
#         requirejs(["https://cdn.plot.ly/plotly-latest.min.js"], function(p) {
#             window.Plotly = p
#         });
#     </script>
# <!DOCTYPE html>
# <html>
#     <head>
#         <title>Plots.jl</title>
#         <meta http-equiv="content-type" content="text/html; charset=UTF-8">
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#     </head>
#     <body>
#             <div id
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "x": [
#             2.9124896017678927,
#             3.748144707651006,
#             2.8481047403589757,
#             0.39458512788029937,
#             0.037728429372568324,
#             0.9918024361721263,
#             3.877791104833,
#             4.738269159811117,
#             3.5145507951252095,
#             4.885999773228281,
#             0.24873450242148856,
#             4.1395526284973085,
#             0.19351487019163663,
#             1.0867132144054805,
#             0.11981259224484356,
#             5.338521177925433,
#             1.6451509774798445,
#             1.641303297835079,
#             3.5246005084900243,
#             2.143136963084906,
#             2.778319269368517,
#             5.867527971491886,
#             1.367701853145884,
#             5.193868161144979,
#             2.533112377043693,
#             3.3329332424385245,
#             4.602302904401614,
#             5.35304673872395,
#             5.626263431353105,
#             3.7602254594405222,
#             1.170397499242227,
#             1.2829540408073214,
#             3.3640877167164027,
#             0.4220878382727979,
#             1.2203306241156016,
#             1.150328331533381,
#             5.714076481516447,
#             1.9814395091267558,
#             1.2152062726464066,
#             2.341936048961762,
#             2.4513166420236954,
#             5.963796231894422,
#             2.8774084956759647,
#             2.6932015883284284,
#             4.717878053708556,
#             0.8425639765611916,
#             1.4929439090847048,
#             3.1078923729388124,
#             1.0868859159937108,
#             5.557628595701203,
#             5.49771642933164,
#             0.575512268575441,
#             5.343003087122146,
#             5.776070172785507,
#             5.326925478088895,
#             4.186167676339872,
#             0.7225157621246104,
#             4.38777570976479,
#             3.5148754259114554,
#             0.027604802254912974,
#             0.3644316778402582,
#             3.477469428108961,
#             4.51691839635431,
#             0.1667340118241981,
#             6.233563428050544,
#             2.172048543379393,
#             0.9811158287509049,
#             0.47384542901183896,
#             5.616035993533893,
#             0.6418720464534475,
#             6.230083017550607,
#             1.4803491192791571,
#             1.491341856872455,
#             1.4954351316776924,
#             1.903055374918997,

# %% [markdown]
# # 2. Plot the four relevant barcodes

# %%
# compute distance
D_P, D_Q, D_P_Q, D_Q_P = compute_distance(P, Q);

# %%
# Compute Vietoris-Rips persistence on two regions
dim = 1
VR_P = eirene(D_P, record = "all", maxdim = dim)
VR_Q = eirene(D_Q, record = "all", maxdim = dim)

# compute Witness persistence
W_P = compute_Witness_persistence(D_P_Q, maxdim = dim)
W_Q = compute_Witness_persistence(D_Q_P, maxdim = dim);

# %%
# plot all four barcodes
barcode_VR_P = barcode(VR_P, dim = 1)
barcode_W_P = barcode(W_P["eirene_output"], dim = 1)
barcode_W_Q = barcode(W_Q["eirene_output"], dim = 1)
barcode_VR_Q = barcode(VR_Q, dim = 1)

# plot
p1 = plot_barcode(barcode_VR_P, lw = 3, title = "Barcode(VR(P))", titlefontsize = 12)
p2 = plot_barcode(barcode_W_P, lw = 3, title = "Barcode(W(P,Q))", titlefontsize = 12)
p3 = plot_barcode(barcode_W_Q, lw = 3, title = "Barcode(W(Q,P))", titlefontsize = 12)
p4 = plot_barcode(barcode_VR_Q, lw = 2, title = "Barcode(VR(Q))", titlefontsize = 12)
plot(p1, p2, p3, p4, layout = grid(4,1), size = (500, 700))

# %% [markdown]
# # 3. Run the extension method from VR to W

# %% [markdown]
# Given the selected interval in `barcode(VR(P))`, find its cycle extensions in `W(P,Q)`

# %%
# select bar of interest
VR_P_class = 11
# Out:
# 11

# %%
# plot cycle rep of selected bar
cycle = classrep(VR_P, class = VR_P_class, dim = 1)
cycle = [sort(cycle[:,i]) for i = 1:size(cycle,2)]
plot_cycle_square_torus(P_2d, Q_2d, cycle = cycle)
# Out:
# <!DOCTYPE html>
# <html>
#     <head>
#         <title>Plots.jl</title>
#         <meta http-equiv="content-type" content="text/html; charset=UTF-8">
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#     </head>
#     <body>
#             <div id="52abdbad-18ff-46ac-b18c-1b748fc96cfe" style="width:600px;height:400px;"></div>
#     <script>
#     PLOT = document.getElementById('52abdbad-18ff-46ac-b18c-1b748fc96cfe');
#     Plotly.plot(PLOT, [
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "x": [
#             0.041304353515843384,
#             0.17944678105693218,
#             0.1669593282787386,
#             0.1762734247589413,
#             0.18003182576395255,
#             0.1047971967866726,
#             0.0033282878147681827,
#             1.0549798084421629,
#             0.1895080117147726,
#             0.24370065930407964,
#             0.18539076527134268,
#             0.06744278889033994,
#             0.0549474467772863,
#             0.18232706618349387,
#             0.06271722712646782,
#             0.13275562406787222,
#             0.00822437473277643,
#             0.24627947319375937,
#             0.09943077070679279,
#             0.13970388237413195,
#             0.08343771153198759,
#             0.011550197375590321,
#             0.0027981309987917813,
#             0.09249609834593742,
#             0.008236768041308351,
#             0.1766105475664927,
#             0.13132038260819384,
#             0.17207954727997032,
#             0.22859806227340773,
#             0.21350221528715307,
#             0.1296653002839906,
#             0.17485846968111407,
#             0.1059813522375776,
#             0.22695990477667127,
#             0.19755747506653787,
#             0.056099463345583855,
#             0.0970789025967218,
#             0.10849982939625019,
#             0.2097073996884916,
#             0.00501534697627265,
#             2.0236294065532148,
#             4.123804924935145,
#             3.229849331363372,
#             0.39689241317720914,
#             3.504018027757593,
#             0.5216457457019942,
#             0.230060774375052,
#             2.9901385762433663,
#             4.016974042391512,
#             1.518191591819662,
#             1.9466816364060553,
#             4.329792164194545,
#             0.2626622079890826,
#             1.448499947821758,
#             1.1085420048299466,
#             2.154747034392122,
#             1.5293280976691648,
#             3.5581303846218737,
#             2.6886403725984427,
#             2.013012079028466,
#             4.619113653275374,
#             1.052760038386161,
#             2.241982320959244,
#             4.266490890145951,
#             4.197532371479891,
#             3.0065666748644753,
#             2.671644218686961,
#             4.2824225630597255,
#             4.075564046293439,
#             4.055957599312373
#         ],
#         "showlegend": true,
#         "mode": "markers",
#         "name": "P",
#         "zmin": null,
#         "legendgroup": "P",
#         "marker": {
#             "symbol": "circle",
#             "color": "rgba(0, 129, 129, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 10
#         },
#         "zmax": null,
#         "y": [
#             1.5683394798966572,
#             4.640930289304345,
#             0.34286540473702476,
#             2.1242599876354746,
#             2.641767337538475,
#             2.4613027846623297,
#             6.131301358832614,
#             3.3744305530395087,
#             5.727040756729853,
#             5.536810934817648,
#             1.4319333770232912,
#             0.4884940897772061,
#             3.7369675924946852,
#             1.615594901154704,
#             0.6313103638839336,
#             0.1544366533715643,
#             2.338751154278274,
#             6.203604165908586,
#             0.6259738464323762,
#             5.674175361739829,
#             4.167570233831077,
#             3.866413420162268,
#             2.3810223405122226,
#             3.5924472411990482,
#             3.9797791322635887,
#             0.9678591422378849,
#             5.614043033052765,
#             5.965405837331927,
#             4.687434476797595,
#             4.88333302109474,
#             2.231601941464397,
#             6.2238637110738235,
#             2.6212280157455172,
#             5.8389383683215295,
#             5.333468858936719,
#             4.314272125042844,
#             5.0670241514178915,
#             5.6607980136273355,
#             5.899577660436369,
#             0.500600084363365,
#             3.312764404374168,
#             3.1041222288498456,
#             3.2359740589783796,
#             3.4163256978166636,
#             3.218519937669499,
#             2.8748016531783254,
#             3.4269465298084576,
#             3.031950787565351,
#             3.09732116363717,
#             3.344941575030332,
#             3.3176630515656957,
#             3.165949523392946,
#             3.4248710580838355,
#             3.349378282884119,
#             3.371020677712319,
#             3.3044171969353497,
#             2.9389527041311423,
#             3.0681102691410085,
#             3.0127568157879843,
#             2.9697449827422226,
#             3.1475307453409775,
#             2.9086134391893017,
#             2.984321681071915,
#             3.1132058995191008,
#             3.1088158638735015,
#             3.032996632805811,
#             3.2715105001550273,
#             3.1689651658621054,
#             3.1821341880477103,
#             3.099802933950474
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "x": [
#             2.9124896017678927,
#             3.748144707651006,
#             2.8481047403589757,
#             0.39458512788029937,
#             0.037728429372568324,
#             0.9918024361721263,
#             3.877791104833,
#             4.738269159811117,
#             3.5145507951252095,
#             4.885999773228281,
#             0.24873450242148856,
#             4.1395526284973085,
#             0.19351487019163663,
#             1.0867132144054805,
#             0.11981259224484356,
#             5.338521177925433,
#             1.6451509774798445,
#             1.641303297835079,
#             3.5246005084900243,
#             2.143136963084906,
#             2.778319269368517,
#             5.867527971491886,
#             1.367701853145884,
#             5.193868161144979,
#             2.533112377043693,
#             3.3329332424385245,
#             4.602302904401614,
#             5.35304673872395,
#             5.626263431353105,
#             3.7602254594405222,
#             1.170397499242227,
#             1.2829540408073214,
#             3.3640877167164027,
#             0.4220878382727979,
#             1.2203306241156016,
#             1.150328331533381,
#             5.714076481516447,
#             1.9814395091267558,
#             1.2152062726464066,
#             2.341936048961762,
#             2.4513166420236954,
#             5.963796231894422,
#             2.8774084956759647,
#             2.6932015883284284,
#             4.717878053708556,
#             0.8425639765611916,
#             1.4929439090847048,
#             3.1078923729388124,
#             1.0868859159937108,
#             5.557628595701203,
#             5.49771642933164,
#             0.575512268575441,
#             5.343003087122146,
#             5.776070172785507,
#             5.326925478088895,
#             4.186167676339872,
#             0.7225157621246104,
#             4.38777570976479,
#             3.5148754259114554,
#             0.027604802254912974,
#             0.3644316778402582,
#             3.477469428108961,
#             4.51691839635431,
#             0.1667340118241981,
#             6.233563428050544,
#             2.172048543379393,
#             0.9811158287509049,
#             0.47384542901183896,
#             5.616035993533893,
#             0.6418720464534475,
#             6.230083017550607,
#             1.4803491192791571,
#             1.491341856872455,
#             1.4954351316776924,
#             1.903055374918997,

# %%
# run extension method
extension_to_W_PQ = run_extension_VR_to_W_bar(C_VR = VR_P,
                                              D_VR = D_P,
                                              VR_bar = VR_P_class,
                                              W = W_P,
                                              D_W = D_P_Q);

# %% [markdown]
# ### Find all cycle extensions

# %%
# find all cycle extensions
CE1, _ = find_CE_BE(extension_to_W_PQ);

# %%
param = extension_to_W_PQ["epsilon_0"]
CE1[param]
# Out:
# Dict{Any,Any} with 1 entry:
#   0 => [[24, 47], [21, 36], [5, 33], [15, 19], [4, 6], [15, 26], [12, 40], [10,…

# %% [markdown]
# Select the cycle as `cycle_W_PQ`

# %%
cycle_W_PQ = CE1[param][0];

# %%
# plot selected cycle extension
plot_cycle_square_torus(P_2d, Q_2d, cycle = cycle_W_PQ)
# Out:
# <!DOCTYPE html>
# <html>
#     <head>
#         <title>Plots.jl</title>
#         <meta http-equiv="content-type" content="text/html; charset=UTF-8">
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#     </head>
#     <body>
#             <div id
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "x": [
#             2.9124896017678927,
#             3.748144707651006,
#             2.8481047403589757,
#             0.39458512788029937,
#             0.037728429372568324,
#             0.9918024361721263,
#             3.877791104833,
#             4.738269159811117,
#             3.5145507951252095,
#             4.885999773228281,
#             0.24873450242148856,
#             4.1395526284973085,
#             0.19351487019163663,
#             1.0867132144054805,
#             0.11981259224484356,
#             5.338521177925433,
#             1.6451509774798445,
#             1.641303297835079,
#             3.5246005084900243,
#             2.143136963084906,
#             2.778319269368517,
#             5.867527971491886,
#             1.367701853145884,
#             5.193868161144979,
#             2.533112377043693,
#             3.3329332424385245,
#             4.602302904401614,
#             5.35304673872395,
#             5.626263431353105,
#             3.7602254594405222,
#             1.170397499242227,
#             1.2829540408073214,
#             3.3640877167164027,
#             0.4220878382727979,
#             1.2203306241156016,
#             1.150328331533381,
#             5.714076481516447,
#             1.9814395091267558,
#             1.2152062726464066,
#             2.341936048961762,
#             2.4513166420236954,
#             5.963796231894422,
#             2.8774084956759647,
#             2.6932015883284284,
#             4.717878053708556,
#             0.8425639765611916,
#             1.4929439090847048,
#             3.1078923729388124,
#             1.0868859159937108,
#             5.557628595701203,
#             5.49771642933164,
#             0.575512268575441,
#             5.343003087122146,
#             5.776070172785507,
#             5.326925478088895,
#             4.186167676339872,
#             0.7225157621246104,
#             4.38777570976479,
#             3.5148754259114554,
#             0.027604802254912974,
#             0.3644316778402582,
#             3.477469428108961,
#             4.51691839635431,
#             0.1667340118241981,
#             6.233563428050544,
#             2.172048543379393,
#             0.9811158287509049,
#             0.47384542901183896,
#             5.616035993533893,
#             0.6418720464534475,
#             6.230083017550607,
#             1.4803491192791571,
#             1.491341856872455,
#             1.4954351316776924,
#             1.903055374918997,

# %% [markdown]
# # 5. Run the extension method from `W(Q,P)` to `VR(Q)`

# %% [markdown]
# Find parameter at which to run the extension method.
# We'll choose the parameter immediately prior to the death time of `cycle_W_QP`.

# %%
# choose parameter
parameter = find_cycle_death_in_Witness(cycle_W_QP, W_Q)
psi = maximum(D_Q_P[D_Q_P.< parameter])
# Out:
# 1.4807932042291916

# %%
# run extension
extension_to_VR_Q = run_extension_W_to_VR(W = W_Q,
                                          W_cycle = cycle_W_QP,
                                          psi = psi,
                                          C_VR = VR_Q,
                                          D_VR = D_Q);

# %% [markdown]
# ### Explore results of the second extension method.

# %%
plot_pY(extension_to_VR_Q)
# Out:
# <!DOCTYPE html>
# <html>
#     <head>
#         <title>Plots.jl</title>
#         <meta http-equiv="content-type" content="text/html; charset=UTF-8">
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#     </head>
#     <body>
#             <div id="ab8d207c-1631-49b6-85b2-820bd2a22d05" style="width:500px;height:400px;"></div>
#     <script>
#     PLOT = document.getElementById('ab8d207c-1631-49b6-85b2-820bd2a22d05');
#     Plotly.plot(PLOT, [
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 14",
#             "class 14"
#         ],
#         "x": [
#             0.2311642493749857,
#             0.2428134850718575
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y1",
#         "zmin": null,
#         "legendgroup": "y1",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": null
#         },
#         "y": [
#             1.0,
#             1.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 1",
#             "class 1"
#         ],
#         "x": [
#             0.2799478912566844,
#             0.2914355556784754
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y2",
#         "zmin": null,
#         "legendgroup": "y2",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": null
#         },
#         "y": [
#             2.0,
#             2.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 15",
#             "class 15"
#         ],
#         "x": [
#             0.32548786293987564,
#             0.38611143333224146
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y3",
#         "zmin": null,
#         "legendgroup": "y3",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": null
#         },
#         "y": [
#             3.0,
#             3.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 2",
#             "class 2"
#         ],
#         "x": [
#             0.3503800542331914,
#             0.3578082399153021
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y4",
#         "zmin": null,
#         "legendgroup": "y4",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": null
#         },
#         "y": [
#             4.0,
#             4.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 3",
#             "class 3"
#         ],
#         "x": [
#             0.35968236996081326,
#             0.376156028160491
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y5",
#         "zmin": null,
#         "legendgroup": "y5",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": null
#         },
#         "y": [
#             5.0,
#             5.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 16",
#             "class 16"
#         ],
#         "x": [
#             0.3800677078290747,
#             0.49669068186451765
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y6",
#         "zmin": null,
#         "legendgroup": "y6",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": null
#         },
#         "y": [
#             6.0,
#             6.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 17",
#             "class 17"
#         ],
#         "x": [
#             0.4352624638197146,
#             0.48048248099834373
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y7",
#         "zmin": null,
#         "legendgroup": "y7",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": null
#         },
#         "y": [
#             7.0,
#             7.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 83",
#             "class 83"
#         ],
#         "x": [
#             0.44287738987124853,
#             1.7696641858060127
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y8",
#         "zmin": null,
#         "legendgroup": "y8",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": null
#         },
#         "y": [
#             8.0,
#             8.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 67",
#             "class 67"
#         ],
#         "x": [
#             0.44401534525348396,
#             0.5809151866053343
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y9",
#         "zmin": null,
#         "legendgroup": "y9",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": null
#         },
#         "y": [
#             9.0,
#             9.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 18",
#             "class 18"
#         ],
#         "x": [
#             0.4541364424280992,
#             0.6370637921920081
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y10",
#         "zmin": null,
#         "legendgroup": "y10",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": null
#         },
#         "y": [
#             10.0,
#             10.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 19",
#             "class 19"
#         ],
#         "x": [
#             0.4542485408447036,
#             0.5339077644821467
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y11",
#         "zmin": null,
#         "legendgroup": "y11",
#         "zmax": null,
#         "line": {
#             "

# %%
p = return_extension_results_at_parameter(extension_to_VR_Q)
# Out:
# *** Parameter key, value pair ***
# key: 1 parameter: 0.442877
# key: 2 parameter: 0.444015
# key: 3 parameter: 0.454249
# key: 4 parameter: 0.460147
# key: 5 parameter: 0.464035
# key: 6 parameter: 0.478347
# key: 7 parameter: 0.492438
# key: 8 parameter: 0.494427
# key: 9 parameter: 0.502065
# key: 10 parameter: 0.513026
# key: 11 parameter: 0.524723
# key: 12 parameter: 0.532820
# key: 13 parameter: 0.553613
# key: 14 parameter: 0.558562
# key: 15 parameter: 0.562050
# key: 16 parameter: 0.570657
# key: 17 parameter: 0.574416
# key: 18 parameter: 0.585488
# key: 19 parameter: 0.597537
# key: 20 parameter: 0.619915
# key: 21 parameter: 0.727001
# key: 22 parameter: 0.746463
# key: 23 parameter: 0.748513
# key: 24 parameter: 0.798899
# key: 25 parameter: 0.837899
# key: 26 parameter: 0.844131
# key: 27 parameter: 0.848869
# key: 28 parameter: 0.867890
# key: 29 parameter: 0.878824
# key: 30 parameter: 0.895384
# key: 31 parameter: 0.896926
# key: 32 parameter: 0.911642
# key: 33 parameter: 1.095031
# key: 34 parameter: 1.365625
# Select a key for parameter 1
# Selected parameter: 0.44287738987124853
#
# Baseline bars extension at selected parameter: [83]
#
# *** Offset bar extensions at selected parameter ***
# key: 1 offset bar extension: [16]
# Select keys for offset bar extensions.
# Leave blank to select none.
# To select multiple keys, separate keys with space. ex) 1 2 3 :
# Baseline bars extension at selected parameter: [83]
# <!DOCTYPE html>
# <html>
#     <head>
#         <title>Plots.jl</title>
#         <meta http-equiv="content-type" content="text/html; charset=UTF-8">
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#     </head>
#     <body>
#             <div id="2b2e5705-f287-4329-863c-ac3d898cfd39" style="width:600px;height:400px;"></div>
#     <script>
#     PLOT = document.getElementById('2b2e5705-f287-4329-863c-ac3d898cfd39');
#     Plotly.plot(PLOT, [
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 14",
#             "class 14"
#         ],
#         "x": [
#             0.2311642493749857,
#             0.2428134850718575
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y1",
#         "zmin": null,
#         "legendgroup": "y1",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 1
#         },
#         "y": [
#             1.0,
#             1.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 1",
#             "class 1"
#         ],
#         "x": [
#             0.2799478912566844,
#             0.2914355556784754
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y2",
#         "zmin": null,
#         "legendgroup": "y2",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 1
#         },
#         "y": [
#             2.0,
#             2.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 15",
#             "class 15"
#         ],
#         "x": [
#             0.32548786293987564,
#             0.38611143333224146
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y3",
#         "zmin": null,
#         "legendgroup": "y3",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 1
#         },
#         "y": [
#             3.0,
#             3.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 2",
#             "class 2"
#         ],
#         "x": [
#             0.3503800542331914,
#             0.3578082399153021
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y4",
#         "zmin": null,
#         "legendgroup": "y4",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 1
#         },
#         "y": [
#             4.0,
#             4.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 3",
#             "class 3"
#         ],
#         "x": [
#             0.35968236996081326,
#             0.376156028160491
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y5",
#         "zmin": null,
#         "legendgroup": "y5",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 1
#         },
#         "y": [
#             5.0,
#             5.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 16",
#             "class 16"
#         ],
#         "x": [
#             0.3800677078290747,
#             0.49669068186451765
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y6",
#         "zmin": null,
#         "legendgroup": "y6",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 1
#         },
#         "y": [
#             6.0,
#             6.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 17",
#             "class 17"
#         ],
#         "x": [
#             0.4352624638197146,
#             0.48048248099834373
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y7",
#         "zmin": null,
#         "legendgroup": "y7",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 1
#         },
#         "y": [
#             7.0,
#             7.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 83",
#             "class 83"
#         ],
#         "x": [
#             0.44287738987124853,
#             0.44287738987124853
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y8",
#         "zmin": null,
#         "legendgroup": "y8",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 1
#         },
#         "y": [
#             8.0,
#             8.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 83",
#             "class 83"
#         ],
#         "x": [
#             0.44287738987124853,
#             1.7696641858060127
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y9",
#         "zmin": null,
#         "legendgroup": "y9",
#         "zmax": null,
#         "line": {
#             "color": "rgba(238, 18, 137, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 1
#         },
#         "y": [
#             8.0,
#             8.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 67",
#             "class 67"
#         ],
#         "x": [
#             0.44401534525348396,
#             0.5809151866053343
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y10",
#         "zmin": null,
#         "legendgroup": "y10",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 1
#         },
#         "y": [
#             9.0,
#             9.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 18",
#             "class 18"
#         ],
#         "x": [
#             0.4541364424280992,
#             0.6370637921920081
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y11",
#         "zmin": null,
#         "legendgroup": "y11",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.

# %% [markdown]
# # 6. Explore the bar extension under fixed interval decompositions of `barcode(VR(Q))`.

# %% [markdown]
# * We use the function `find_CE_BE_at_param()` to find all cycle extensions and bar extensions at a specific parameter.

# %%
# select parameter
param = extension_to_VR_Q["nontrivial_pY"][1]
CE_param, BE_param = find_CE_BE_at_param(extension_to_VR_Q, param);

# %% [markdown]
# <b> plot cycle extensions to `barcode(VR(Q))`</b>

# %%
@printf("number of cycle extensions at parameter %.4f : %i", param, length(CE_param))
# Out:
# number of cycle extensions at parameter 0.4429 : 2

# %%
# plot a cycle extension at selected parameter
p = plot_cycle_square_torus(P_2d, Q_2d, cycle = CE_param[0], cycle_loc = "Q", title = "cycle extension",
                                P_markersize = 5, Q_markersize = 5; legend = false)
# Out:
# <!DOCTYPE html>
# <html>
#     <head>
#         <title>Plots.jl</title>
#         <meta http-equiv="content-type" content="text/html; charset=UTF-8">
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#     </head>
#     <body>
#             <div id
#             3.031950787565351,
#             3.09732116363717,
#             3.344941575030332,
#             3.3176630515656957,
#             3.165949523392946,
#             3.4248710580838355,
#             3.349378282884119,
#             3.371020677712319,
#             3.3044171969353497,
#             2.9389527041311423,
#             3.0681102691410085,
#             3.0127568157879843,
#             2.9697449827422226,
#             3.1475307453409775,
#             2.9086134391893017,
#             2.984321681071915,
#             3.1132058995191008,
#             3.1088158638735015,
#             3.032996632805811,
#             3.2715105001550273,
#             3.1689651658621054,
#             3.1821341880477103,
#             3.099802933950474
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "x": [
#             2.9124896017678927,
#             3.748144707651006,
#             2.8481047403589757,
#             0.39458512788029937,
#             0.037728429372568324,
#             0.9918024361721263,
#             3.877791104833,
#             4.738269159811117,
#             3.5145507951252095,
#             4.885999773228281,
#             0.24873450242148856,
#             4.1395526284973085,
#             0.19351487019163663,
#             1.0867132144054805,
#             0.11981259224484356,
#             5.338521177925433,
#             1.6451509774798445,
#             1.641303297835079,
#             3.5246005084900243,
#             2.143136963084906,
#             2.778319269368517,
#             5.867527971491886,
#             1.367701853145884,
#             5.193868161144979,
#             2.533112377043693,
#             3.3329332424385245,
#             4.602302904401614,
#             5.35304673872395,
#             5.626263431353105,
#             3.7602254594405222,
#             1.170397499242227,
#             1.2829540408073214,
#             3.3640877167164027,
#             0.4220878382727979,
#             1.2203306241156016,
#             1.150328331533381,
#             5.714076481516447,
#             1.9814395091267558,
#             1.2152062726464066,
#             2.341936048961762,
#             2.4513166420236954,
#             5.963796231894422,
#             2.8774084956759647,
#             2.6932015883284284,
#             4.717878053708556,
#             0.8425639765611916,
#             1.4929439090847048,
#             3.1078923729388124,
#             1.0868859159937108,
#             5.557628595701203,
#             5.49771642933164,
#             0.575512268575441,
#             5.343003087122146,
#             5.776070172785507,
#             5.326925478088895,
#             4.186167676339872,
#             0.7225157621246104,
#             4.38777570976479,
#             3.5148754259114554,
#             0.027604802254912974,
#             0.3644316778402582,
#             3.477469428108961,
#             4.51691839635431,
#             0.1667340118241981,
#             6.233563428050544,
#             2.172048543379393,
#             0.9811158287509049,
#             0.47384542901183896,
#             5.616035993533893,
#             0.6418720464534475,
#             6.230083017550607,
#             1.4803491192791571,
#             1.491341856872455,
#             1.4954351316776924,
#             1.903055374918997,

# %% [markdown]
# Plot the <b>bar extensions</b> at given parameter.
# * Select a cycle extension
# * Find and plot the corresponding bar extensions

# %%
# select parameter 
@printf("number of cycle extensions at parameter %.4f : %i", param, length(CE_param))
# Out:
# number of cycle extensions at parameter 0.4429 : 2

# %%
# select cycle extension 
y= 0

# find the corresponding bar extension
be = BE_param[y]

# plot the bar extension
barcode_VR_Q = barcode(VR_Q, dim = dim)
p = plot_barcode(barcode_VR_Q, title = "selected bar extension to barcode(VR(Q))", lw = 2, selected_bars = be, epsilon= param, v_line = [param])
plot(p, size = (500, 300))
# Out:
# <!DOCTYPE html>
# <html>
#     <head>
#         <title>Plots.jl</title>
#         <meta http-equiv="content-type" content="text/html; charset=UTF-8">
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#     </head>
#     <body>
#             <div id="83f737b9-8317-4ee1-b0dc-ac0115104525" style="width:500px;height:300px;"></div>
#     <script>
#     PLOT = document.getElementById('83f737b9-8317-4ee1-b0dc-ac0115104525');
#     Plotly.plot(PLOT, [
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 14",
#             "class 14"
#         ],
#         "x": [
#             0.2311642493749857,
#             0.2428134850718575
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y1",
#         "zmin": null,
#         "legendgroup": "y1",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 2
#         },
#         "y": [
#             1.0,
#             1.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 1",
#             "class 1"
#         ],
#         "x": [
#             0.2799478912566844,
#             0.2914355556784754
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y2",
#         "zmin": null,
#         "legendgroup": "y2",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 2
#         },
#         "y": [
#             2.0,
#             2.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 15",
#             "class 15"
#         ],
#         "x": [
#             0.32548786293987564,
#             0.38611143333224146
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y3",
#         "zmin": null,
#         "legendgroup": "y3",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 2
#         },
#         "y": [
#             3.0,
#             3.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 2",
#             "class 2"
#         ],
#         "x": [
#             0.3503800542331914,
#             0.3578082399153021
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y4",
#         "zmin": null,
#         "legendgroup": "y4",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 2
#         },
#         "y": [
#             4.0,
#             4.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 3",
#             "class 3"
#         ],
#         "x": [
#             0.35968236996081326,
#             0.376156028160491
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y5",
#         "zmin": null,
#         "legendgroup": "y5",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 2
#         },
#         "y": [
#             5.0,
#             5.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 16",
#             "class 16"
#         ],
#         "x": [
#             0.3800677078290747,
#             0.49669068186451765
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y6",
#         "zmin": null,
#         "legendgroup": "y6",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 2
#         },
#         "y": [
#             6.0,
#             6.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 17",
#             "class 17"
#         ],
#         "x": [
#             0.4352624638197146,
#             0.48048248099834373
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y7",
#         "zmin": null,
#         "legendgroup": "y7",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 2
#         },
#         "y": [
#             7.0,
#             7.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 83",
#             "class 83"
#         ],
#         "x": [
#             0.44287738987124853,
#             0.44287738987124853
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y8",
#         "zmin": null,
#         "legendgroup": "y8",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 2
#         },
#         "y": [
#             8.0,
#             8.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 83",
#             "class 83"
#         ],
#         "x": [
#             0.44287738987124853,
#             1.7696641858060127
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y9",
#         "zmin": null,
#         "legendgroup": "y9",
#         "zmax": null,
#         "line": {
#             "color": "rgba(238, 18, 137, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 2
#         },
#         "y": [
#             8.0,
#             8.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 67",
#             "class 67"
#         ],
#         "x": [
#             0.44401534525348396,
#             0.5809151866053343
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y10",
#         "zmin": null,
#         "legendgroup": "y10",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 2
#         },
#         "y": [
#             9.0,
#             9.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 18",
#             "class 18"
#         ],
#         "x": [
#             0.4541364424280992,
#             0.6370637921920081
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y11",
#         "zmin": null,
#         "legendgroup": "y11",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.

# %% [markdown]
# Plot a summary analogous bars plot under fixed interval decomposition of `barcode(VR(Q))`

# %%
# plot the summary
l = grid(4,1)
p1 = plot_barcode(barcode_VR_P, lw = 3, selected_bars = [VR_P_class], title = "Barcode(VR(P))", titlefontsize = 12)
p2 = plot_barcode(barcode_W_P , lw = 3, title = "Barcode(W(P,Q))", titlefontsize = 12)
p3 = plot_barcode(barcode_W_Q, lw = 3, title = "Barcode(W(Q,P))", titlefontsize = 12)
p4 = plot_barcode(barcode_VR_Q, lw = 2, title = "Barcode(VR(Q))", titlefontsize = 12, selected_bars = be)
plot(p1, p2, p3, p4, layout = l, size = (500, 800))
# Out:
# <!DOCTYPE html>
# <html>
#     <head>
#         <title>Plots.jl</title>
#         <meta http-equiv="content-type" content="text/html; charset=UTF-8">
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#     </head>
#     <body>
#             <div id="a3bc5185-82e7-48be-91af-095e184e1409" style="width:500px;height:800px;"></div>
#     <script>
#     PLOT = document.getElementById('a3bc5185-82e7-48be-91af-095e184e1409');
#     Plotly.plot(PLOT, [
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 4",
#             "class 4"
#         ],
#         "x": [
#             0.14290978642008145,
#             0.14307546700269336
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y1",
#         "zmin": null,
#         "legendgroup": "y1",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             1.0,
#             1.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 1",
#             "class 1"
#         ],
#         "x": [
#             0.20910660455681707,
#             0.22272337019488936
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y2",
#         "zmin": null,
#         "legendgroup": "y2",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             2.0,
#             2.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 2",
#             "class 2"
#         ],
#         "x": [
#             0.5726689245422889,
#             0.6000238553212949
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y3",
#         "zmin": null,
#         "legendgroup": "y3",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             3.0,
#             3.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 11",
#             "class 11"
#         ],
#         "x": [
#             0.6041150495756741,
#             1.7570637253147998
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y4",
#         "zmin": null,
#         "legendgroup": "y4",
#         "zmax": null,
#         "line": {
#             "color": "rgba(238, 18, 137, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             4.0,
#             4.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 10",
#             "class 10"
#         ],
#         "x": [
#             0.6484774088835957,
#             0.9103143766539211
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y5",
#         "zmin": null,
#         "legendgroup": "y5",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             5.0,
#             5.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 5",
#             "class 5"
#         ],
#         "x": [
#             0.6951016464686365,
#             0.8337443666921228
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y6",
#         "zmin": null,
#         "legendgroup": "y6",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             6.0,
#             6.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 6",
#             "class 6"
#         ],
#         "x": [
#             0.7472934111737044,
#             0.770812962893254
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y7",
#         "zmin": null,
#         "legendgroup": "y7",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             7.0,
#             7.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 3",
#             "class 3"
#         ],
#         "x": [
#             0.7857888425671106,
#             0.8335330207236928
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y8",
#         "zmin": null,
#         "legendgroup": "y8",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             8.0,
#             8.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 9",
#             "class 9"
#         ],
#         "x": [
#             0.8289583253798375,
#             0.8959932639859833
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y9",
#         "zmin": null,
#         "legendgroup": "y9",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             9.0,
#             9.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 7",
#             "class 7"
#         ],
#         "x": [
#             0.8304544785777269,
#             0.8410814922775288
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y10",
#         "zmin": null,
#         "legendgroup": "y10",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             10.0,
#             10.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 8",
#             "class 8"
#         ],
#         "x": [
#             1.6669433770569406,
#             1.8207353500387027
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y11",
#         "zmin": null,
#         "legendgroup": "y11",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",

# %% [markdown]
# # 7. Explore alternative bar extensions under all possible interval decompositions of `barcode(VR(Q))`.

# %% [markdown]
# * Up to this point, the bar extension result has been obtained for some fixed interval decomposition of `barcode(VR(Q))`.
# * In this section, we show how to find the bar extensions under all possible interval decompositions. Given `cycle_W_QP` (corresponds to $[\sigma] \in E(\tau, W^\bullet_{Q,P})$ in the paper), the goal is to find $S([\sigma], X^\bullet_Q)$ from Algorithm 6 of paper. We'll refer to this set as <b>alternative bar extensions</b> since these arise from alternative choices of the interval decompositions.
# * There are three different methods for exploring the alternative bar extensions. The appropriate tool depends on the sizes of the barcodes of the auxiliary filtration and the target filtration.
#
# 1. Find all alternative bar extensions for all parameters.
#     * This is recommended for data with small barcodes.
#     * This finds the full $S([\sigma], Y^{\bullet}) = \{ S^{\mathcal{D} \circ L^{-1}}_{[y]} | \ell \in p_Y, [y] \in \mathfrak{E}_{\ell}, L \in L_Y \}$ in Algorithm 3 of paper.
# 2. Find alternative bar extensions at specific parameters.
#     * This is recommended for data with medium size barcodes.
#     * Given a parameter $\ell$, this method finds $S([\sigma], Y^{\bullet}; \ell) = \{ S^{\mathcal{D} \circ L^{-1}}_{[y]} | [y] \in \mathfrak{E}_{\ell}, L \in L_Y \} $
# 3. Find alternative bar extensions of a specific bar extension.
#     * This is recommended for data with large size barcodes.
#     * Given a selected parameter $\ell$ and cycle extension $[y] \in \mathfrak{E}_{\ell}$, this method finds $\{S^{\mathcal{D} \circ L^{-1}}_{[y]} | L \in L_Y \}$.
#
# For this example, we'll implement method 3 due to the large number of bars `barcode(VR(Q))`. Depending on the selected parameter, the function `find_alternative_bar_extension()` can lead to an out of memory error. This will happen when a user selects a parameter at which there are numerous bars in the barcode.
#
# For example implementations of methods 1 and 2, see notebook `EXAMPLE_EXTENSION_VR_VR.ipynb`

# %%
# select a parameter and bar extension
p = return_extension_results_at_parameter(extension_to_VR_Q)
# Out:
# *** Parameter key, value pair ***
# key: 1 parameter: 0.442877
# key: 2 parameter: 0.444015
# key: 3 parameter: 0.454249
# key: 4 parameter: 0.460147
# key: 5 parameter: 0.464035
# key: 6 parameter: 0.478347
# key: 7 parameter: 0.492438
# key: 8 parameter: 0.494427
# key: 9 parameter: 0.502065
# key: 10 parameter: 0.513026
# key: 11 parameter: 0.524723
# key: 12 parameter: 0.532820
# key: 13 parameter: 0.553613
# key: 14 parameter: 0.558562
# key: 15 parameter: 0.562050
# key: 16 parameter: 0.570657
# key: 17 parameter: 0.574416
# key: 18 parameter: 0.585488
# key: 19 parameter: 0.597537
# key: 20 parameter: 0.619915
# key: 21 parameter: 0.727001
# key: 22 parameter: 0.746463
# key: 23 parameter: 0.748513
# key: 24 parameter: 0.798899
# key: 25 parameter: 0.837899
# key: 26 parameter: 0.844131
# key: 27 parameter: 0.848869
# key: 28 parameter: 0.867890
# key: 29 parameter: 0.878824
# key: 30 parameter: 0.895384
# key: 31 parameter: 0.896926
# key: 32 parameter: 0.911642
# key: 33 parameter: 1.095031
# key: 34 parameter: 1.365625
# Select a key for parameter 1
# Selected parameter: 0.44287738987124853
#
# Baseline bars extension at selected parameter: [83]
#
# *** Offset bar extensions at selected parameter ***
# key: 1 offset bar extension: [16]
# Select keys for offset bar extensions.
# Leave blank to select none.
# To select multiple keys, separate keys with space. ex) 1 2 3 :
# Baseline bars extension at selected parameter: [83]
# <!DOCTYPE html>
# <html>
#     <head>
#         <title>Plots.jl</title>
#         <meta http-equiv="content-type" content="text/html; charset=UTF-8">
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#     </head>
#     <body>
#             <div id="b1fd41d2-21aa-42fa-9436-1e2fcb3b15e6" style="width:600px;height:400px;"></div>
#     <script>
#     PLOT = document.getElementById('b1fd41d2-21aa-42fa-9436-1e2fcb3b15e6');
#     Plotly.plot(PLOT, [
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 14",
#             "class 14"
#         ],
#         "x": [
#             0.2311642493749857,
#             0.2428134850718575
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y1",
#         "zmin": null,
#         "legendgroup": "y1",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 1.0
#         },
#         "y": [
#             1.0,
#             1.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 1",
#             "class 1"
#         ],
#         "x": [
#             0.2799478912566844,
#             0.2914355556784754
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y2",
#         "zmin": null,
#         "legendgroup": "y2",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 1.0
#         },
#         "y": [
#             2.0,
#             2.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 15",
#             "class 15"
#         ],
#         "x": [
#             0.32548786293987564,
#             0.38611143333224146
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y3",
#         "zmin": null,
#         "legendgroup": "y3",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 1.0
#         },
#         "y": [
#             3.0,
#             3.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 2",
#             "class 2"
#         ],
#         "x": [
#             0.3503800542331914,
#             0.3578082399153021
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y4",
#         "zmin": null,
#         "legendgroup": "y4",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 1.0
#         },
#         "y": [
#             4.0,
#             4.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 3",
#             "class 3"
#         ],
#         "x": [
#             0.35968236996081326,
#             0.376156028160491
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y5",
#         "zmin": null,
#         "legendgroup": "y5",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 1.0
#         },
#         "y": [
#             5.0,
#             5.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 16",
#             "class 16"
#         ],
#         "x": [
#             0.3800677078290747,
#             0.49669068186451765
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y6",
#         "zmin": null,
#         "legendgroup": "y6",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 1.0
#         },
#         "y": [
#             6.0,
#             6.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 17",
#             "class 17"
#         ],
#         "x": [
#             0.4352624638197146,
#             0.48048248099834373
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y7",
#         "zmin": null,
#         "legendgroup": "y7",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 1.0
#         },
#         "y": [
#             7.0,
#             7.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 83",
#             "class 83"
#         ],
#         "x": [
#             0.44287738987124853,
#             0.44287738987124853
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y8",
#         "zmin": null,
#         "legendgroup": "y8",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 1.0
#         },
#         "y": [
#             8.0,
#             8.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 83",
#             "class 83"
#         ],
#         "x": [
#             0.44287738987124853,
#             1.7696641858060127
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y9",
#         "zmin": null,
#         "legendgroup": "y9",
#         "zmax": null,
#         "line": {
#             "color": "rgba(238, 18, 137, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 1.0
#         },
#         "y": [
#             8.0,
#             8.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 67",
#             "class 67"
#         ],
#         "x": [
#             0.44401534525348396,
#             0.5809151866053343
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y10",
#         "zmin": null,
#         "legendgroup": "y10",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 1.0
#         },
#         "y": [
#             9.0,
#             9.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 18",
#             "class 18"
#         ],
#         "x": [
#             0.4541364424280992,
#             0.6370637921920081
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y11",
#         "zmin": null,
#         "legendgroup": "y11",
#         "zmax": null,
#         "line": {
#             "color": "rg

# %%
param = param = extension_to_VR_Q["nontrivial_pY"][1]
bar_ext = [83]
# Out:
# 1-element Array{Int64,1}:
#  83

# %%
# find alternative representations of the selected bar extension
alt_bar_ext = find_alternative_bar_extension(extension_to_VR_Q, param, bar_extension = bar_ext)
# Out:
# 4-element Array{Array{Int64,1},1}:
#  [83]
#  [16, 83]
#  [17, 83]
#  [16, 17, 83]

# %%
# plot one of the alternative bar extensions

# select an alternative bar extension
alt = alt_bar_ext[2]
barcode_Y = barcode(extension_to_VR_Q["C_VR"], dim = dim)
p =plot_barcode(barcode_Y, selected_bars = alt, lw = 3,
                    epsilon = param, v_line = [param],
                    title = "alternative bar extension")
plot(p)
# Out:
# <!DOCTYPE html>
# <html>
#     <head>
#         <title>Plots.jl</title>
#         <meta http-equiv="content-type" content="text/html; charset=UTF-8">
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#     </head>
#     <body>
#             <div id="16f770cc-3ffc-4f91-a3f0-c44f09665154" style="width:600px;height:400px;"></div>
#     <script>
#     PLOT = document.getElementById('16f770cc-3ffc-4f91-a3f0-c44f09665154');
#     Plotly.plot(PLOT, [
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 14",
#             "class 14"
#         ],
#         "x": [
#             0.2311642493749857,
#             0.2428134850718575
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y1",
#         "zmin": null,
#         "legendgroup": "y1",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             1.0,
#             1.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 1",
#             "class 1"
#         ],
#         "x": [
#             0.2799478912566844,
#             0.2914355556784754
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y2",
#         "zmin": null,
#         "legendgroup": "y2",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             2.0,
#             2.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 15",
#             "class 15"
#         ],
#         "x": [
#             0.32548786293987564,
#             0.38611143333224146
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y3",
#         "zmin": null,
#         "legendgroup": "y3",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             3.0,
#             3.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 2",
#             "class 2"
#         ],
#         "x": [
#             0.3503800542331914,
#             0.3578082399153021
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y4",
#         "zmin": null,
#         "legendgroup": "y4",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             4.0,
#             4.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 3",
#             "class 3"
#         ],
#         "x": [
#             0.35968236996081326,
#             0.376156028160491
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y5",
#         "zmin": null,
#         "legendgroup": "y5",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             5.0,
#             5.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 16",
#             "class 16"
#         ],
#         "x": [
#             0.3800677078290747,
#             0.44287738987124853
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y6",
#         "zmin": null,
#         "legendgroup": "y6",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             6.0,
#             6.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 16",
#             "class 16"
#         ],
#         "x": [
#             0.44287738987124853,
#             0.49669068186451765
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y7",
#         "zmin": null,
#         "legendgroup": "y7",
#         "zmax": null,
#         "line": {
#             "color": "rgba(238, 18, 137, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             6.0,
#             6.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 17",
#             "class 17"
#         ],
#         "x": [
#             0.4352624638197146,
#             0.48048248099834373
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y8",
#         "zmin": null,
#         "legendgroup": "y8",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             7.0,
#             7.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 83",
#             "class 83"
#         ],
#         "x": [
#             0.44287738987124853,
#             0.44287738987124853
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y9",
#         "zmin": null,
#         "legendgroup": "y9",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             8.0,
#             8.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 83",
#             "class 83"
#         ],
#         "x": [
#             0.44287738987124853,
#             1.7696641858060127
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y10",
#         "zmin": null,
#         "legendgroup": "y10",
#         "zmax": null,
#         "line": {
#             "color": "rgba(238, 18, 137, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             8.0,
#             8.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 67",
#             "class 67"
#         ],
#         "x": [
#             0.44401534525348396,
#             0.5809151866053343
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y11",
#         "zmin": null,
#         "legendgroup": "y11",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1
