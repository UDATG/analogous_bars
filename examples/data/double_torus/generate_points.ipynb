# %% [markdown]
# # Generate points
# This notebook samples points from a double torus and a circle
# * P: Points sampled from a double torus
# * Q: Points sampled from a circle that lives on the double torus

# %%
using Revise
includet("../../../extension_method.jl")
# Out:
# HTML{String}("<script>\n// Immediately-invoked-function-expression to avoid global variables.\n(function() {\n    var warning_div = document.getElementById(\"webio-warning-12145134727471439873\");\n    var hide = function () {\n        var script = document.getElementById(\"webio-setup-6086297316445395997\");\n        var parent = script && script.parentElement;\n        var grandparent = parent && parent.parentElement;\n        if (grandparent) {\n            grandparent.style.display = \"none\";\n        }\n        warning_div.style.display = \"none\";\n    };\n    if (typeof Jupyter !== \"undefined\") {\n        console.log(\"WebIO detected Jupyter notebook environment.\");\n        // Jupyter notebook.\n        var extensions = (\n            Jupyter\n            && Jupyter.notebook.config.data\n            && Jupyter.notebook.config.data.load_extensions\n        );\n        if (extensions && extensions[\"webio-jupyter-notebook\"]) {\n            // Extension already loaded.\n            console.log(\"Jupyter WebIO nbextension detected; not loading ad-hoc.\");\n            hide();\n            return;\n        }\n    } else if (window.location.pathname.includes(\"/lab\")) {\n        // Guessing JupyterLa\n        console.log(\"Jupyter Lab detected; make sure the @webio/jupyter-lab-provider labextension is installed.\");\n        hide();\n        return;\n    }\n})();\n\n</script>\n<p\n    id=\"webio-warning-12145134727471439873\"\n    class=\"output_text output_stderr\"\n    style=\"padding: 1em; font-weight: bold;\"\n>\n    Unable to load WebIO. Please make sure WebIO works for your Jupyter client.\n    For troubleshooting, please see <a href=\"https://juliagizmos.github.io/WebIO.jl/latest/providers/ijulia/\">\n    the WebIO/IJulia documentation</a>.\n    <!-- TODO: link to installation docs. -->\n</p>\n")
# ┌ Warning: ORCA.jl has been deprecated and all savefig functionality
# │ has been implemented directly in PlotlyBase itself.
# │
# │ By implementing in PlotlyBase.jl, the savefig routines are automatically
# │ available to PlotlyJS.jl also.
# └ @ ORCA /opt/julia/packages/ORCA/U5XaN/src/ORCA.jl:8

# %%
using .ext
using Distances
using DelimitedFiles
using HDF5
using Plots
using Eirene
using JLD2
#using FileIO

# %% [markdown]
# # 1. Data 1: double torus & pinched circle

# %% [markdown]
# * `P`: points on a double torus
# * `Q`: a **pinched circle** on the double torus
# Recall equation of torus
#
# $x = (R + r \cos \theta) \cos \phi$
# $y = (R + r \cos \theta) \sin \phi$
# $z = r \sin \theta$
#
# * For P, we'll generate two torus that are centered at (-2, 0, 0) and (2,0,0)

# %%
### Sample points from torus
# number of points in each torus
n = 400

# generate "size" of a torus
R = 2
r = 1

# sample theta, phi
theta1 = rand(n) * 2π
phi1 = rand(n) * 2π
theta2 = rand(n) * 2π
phi2 = rand(n) * 2π

### coordinates of torus 1
# center location of torus 1
center1_x = -2
center1_y = 0
center1_z = 0

x1 = (R .+ r .* cos.(theta1) ).* cos.(phi1) .+ center1_x
y1 = (R .+ r .* cos.(theta1)) .* sin.(phi1) .+ center1_y
z1 = r .* sin.(theta1) .+ center1_z ; 

t1_idx = findall(x -> x <0, x1 )
x1 = x1[t1_idx]
y1 = y1[t1_idx]
z1 = z1[t1_idx]

### coordinates of torus 2
# center location of torus 2
center2_x = 2
center2_y = 0
center2_z = 0

x2 = (R .+ r .* cos.(theta2) ).* cos.(phi2) .+ center2_x
y2 = (R .+ r .* cos.(theta2)) .* sin.(phi2) .+ center2_y
z2 = r .* sin.(theta2) .+ center2_z;

t2_idx = findall(x -> x > 0, x2 )
x2 = x2[t2_idx]
y2 = y2[t2_idx]
z2 = z2[t2_idx]

# all coordinates
x = vcat(x1, x2)
y = vcat(y1, y2)
z = vcat(z1, z2)

torus = collect([x y z])

# number of points used:
n_P1 = size(t1_idx,1) + size(t2_idx,1);

##### sample points from circle
# number of points in circle
n_c = 50

# sample theta, phi
theta_c1 = 1 .+rand(n_c) /4 
phi_c1 = rand(n_c) * 2π 
theta_c2 = 1 .+ rand(n_c) /4 
phi_c2 = rand(n_c) * 2π 

# coordinates of first circle
x_c1 = (R .+ r .* cos.(theta_c1) ).* cos.(phi_c1) .+ center1_x
y_c1 = (R .+ r .* cos.(theta_c1)) .* sin.(phi_c1)
z_c1 = r .* sin.(theta_c1)

t1_idx = findall(x -> x <0, x_c1 )
x_c1 = x_c1[t1_idx]
y_c1 = y_c1[t1_idx]
z_c1 = z_c1[t1_idx]

# coordinates of second circle
x_c2 = (R .+ r .* cos.(theta_c2) ).* cos.(phi_c2) .+ center2_x
y_c2 = (R .+ r .* cos.(theta_c2)) .* sin.(phi_c2)
z_c2 = r .* sin.(theta_c2)

t2_idx = findall(x -> x > 0, x_c2 )
x_c2 = x_c2[t2_idx]
y_c2 = y_c2[t2_idx]
z_c2 = z_c2[t2_idx]

# all coordinates
x_c = vcat(x_c1, x_c2)
y_c = vcat(y_c1, y_c2)
z_c = vcat(z_c1, z_c2)
circle = collect([x_c y_c z_c])

# number of points used:
n_P2 = size(t1_idx,1) + size(t2_idx,1);

# %%
p = ext.plot_3D(landmark = torus, witness = circle, landmark_label = "", witness_label = "", 
                xlim = (-5, 5), ylim = (-5, 5), zlim = (-5, 5))
# Out:
# <!DOCTYPE html>
# <html>
#     <head>
#         <title>Plots.jl</title>
#         <meta http-equiv="content-type" content="text/html; charset=UTF-8">
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#     </head>
#     <body>
#             <div id
#             -2.700047695715085,
#             -4.921395515065047,
#             -2.9889523241185794,
#             -1.6887058982716516,
#             -1.0813126951912213,
#             -2.075659501483957,
#             -2.4253115103349465,
#             -0.

# %%
# save
"""
jldopen("data_pinched.jld2", "w") do file
    file["double_torus"] = torus
    file["circle"] = circle
end
"""

# load points
"""
torus = load("data_pinched.jld2", "double_torus")
circle = load("data_pinched.jld2", "circle")

n_P = size(torus,1)
n_Q = size(circle,1);

print("number of points in P: ", n_P, "\n")
print("number of points in Q: ", n_Q)
"""
# Out:
# number of points in P: 731
# number of points in Q: 78

# %% [markdown]
# ## 1(b) Compute the barcodes
# Use this to check that the barcodes behave as expected

# %%
# gather all points 
P = torus
Q = circle
n_P = n_P1
n_Q = n_c
X = vcat(P, Q)

# compute distance
D = pairwise(Euclidean(), X, X, dims = 1)

# Define submatrices 
D_P = D[1:n_P, 1:n_P]
D_Q = D[n_P+1:end, n_P+1:end]
D_P_Q = D[1:n_P, n_P+1:end]
    # rows (landmarks): P
    # columns (witness) : Q
D_Q_P = D[n_P+1:end, 1:n_P];
    # rows (landmarks): Q
    # columns (witness) : P

# %%
# Compute Vietoris-Rips persistence on two regions
dim = 1
VR_P = eirene(D_P, record = "all", maxdim = dim)
VR_Q = eirene(D_Q, record = "all", maxdim = dim);

# %%
# plot barcodes

l = grid(2,1)
p1 = plot_barcode(barcode(VR_P, dim = 1), lw = 3, title = "Barcode(VR(P))", titlefontsize = 12)
p2 = plot_barcode(barcode(VR_Q, dim = 1), lw = 2, title = "Barcode(VR(Q))", titlefontsize = 12)
plot(p1, p2, layout = l, size = (500, 700))
# Out:
# <!DOCTYPE html>
# <html>
#     <head>
#         <title>Plots.jl</title>
#         <meta http-equiv="content-type" content="text/html; charset=UTF-8">
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#     </head>
#     <body>
#             <div id="004d1972-2d8a-4cf8-b45c-e382bb342fdc" style="width:500px;height:700px;"></div>
#     <script>
#     PLOT = document.getElementById('004d1972-2d8a-4cf8-b45c-e382bb342fdc');
#     Plotly.plot(PLOT, [
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 145",
#             "class 145"
#         ],
#         "x": [
#             0.24360982626229677,
#             0.2876129609963494
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y1",
#         "zmin": null,
#         "legendgroup": "y1",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             1.0,
#             1.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 35",
#             "class 35"
#         ],
#         "x": [
#             0.2469411403795905,
#             0.2518270098997663
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y2",
#         "zmin": null,
#         "legendgroup": "y2",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             2.0,
#             2.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 36",
#             "class 36"
#         ],
#         "x": [
#             0.24737596264646694,
#             0.2613912027946792
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y3",
#         "zmin": null,
#         "legendgroup": "y3",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             3.0,
#             3.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 1",
#             "class 1"
#         ],
#         "x": [
#             0.2677657920953179,
#             0.3206275764965169
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y4",
#         "zmin": null,
#         "legendgroup": "y4",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             4.0,
#             4.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 2",
#             "class 2"
#         ],
#         "x": [
#             0.28194538503500227,
#             0.30292977826338696
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y5",
#         "zmin": null,
#         "legendgroup": "y5",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             5.0,
#             5.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 37",
#             "class 37"
#         ],
#         "x": [
#             0.2950967555384476,
#             0.33313593800895175
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y6",
#         "zmin": null,
#         "legendgroup": "y6",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             6.0,
#             6.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 38",
#             "class 38"
#         ],
#         "x": [
#             0.29707661025339444,
#             0.343192461509859
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y7",
#         "zmin": null,
#         "legendgroup": "y7",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             7.0,
#             7.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 39",
#             "class 39"
#         ],
#         "x": [
#             0.29939859078956715,
#             0.31490926955056686
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y8",
#         "zmin": null,
#         "legendgroup": "y8",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             8.0,
#             8.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 40",
#             "class 40"
#         ],
#         "x": [
#             0.3057775864658435,
#             0.3558025113502164
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y9",
#         "zmin": null,
#         "legendgroup": "y9",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             9.0,
#             9.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 41",
#             "class 41"
#         ],
#         "x": [
#             0.3070081920451296,
#             0.34300851722793074
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y10",
#         "zmin": null,
#         "legendgroup": "y10",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             10.0,
#             10.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 3",
#             "class 3"
#         ],
#         "x": [
#             0.318281234506987,
#             0.32320481149064134
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y11",
#         "zmin": null,
#         "legendgroup": "y11",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 14

# %% [markdown]
# # 2. Data 2: double torus and un-pinched circle
# The circle Q is not pinched. It's also not technically on the double torus
# Q is a circle centered at (x0, y0) = (0,0) at height z = 0.9

# %% [markdown]
# ## 2(a) Generate points

# %%
### Sample points from torus
# number of points in each torus
n = 400

# generate "size" of a torus
R = 2
r = 1

# sample theta, phi
theta1 = rand(n) * 2π
phi1 = rand(n) * 2π
theta2 = rand(n) * 2π
phi2 = rand(n) * 2π

### coordinates of torus 1
# center location of torus 1
center1_x = -2
center1_y = 0
center1_z = 0

x1 = (R .+ r .* cos.(theta1) ).* cos.(phi1) .+ center1_x
y1 = (R .+ r .* cos.(theta1)) .* sin.(phi1) .+ center1_y
z1 = r .* sin.(theta1) .+ center1_z ; 

t1_idx = findall(x -> x <0, x1 )
x1 = x1[t1_idx]
y1 = y1[t1_idx]
z1 = z1[t1_idx]

### coordinates of torus 2
# center location of torus 2
center2_x = 2
center2_y = 0
center2_z = 0

x2 = (R .+ r .* cos.(theta2) ).* cos.(phi2) .+ center2_x
y2 = (R .+ r .* cos.(theta2)) .* sin.(phi2) .+ center2_y
z2 = r .* sin.(theta2) .+ center2_z;

t2_idx = findall(x -> x > 0, x2 )
x2 = x2[t2_idx]
y2 = y2[t2_idx]
z2 = z2[t2_idx]

# all coordinates
x = vcat(x1, x2)
y = vcat(y1, y2)
z = vcat(z1, z2)
torus = [x y z]

# number of points used:
n_P1 = size(t1_idx,1) + size(t2_idx,1);

# %%
##### sample points from circle
# number of points in circle
n_c = 60
radius = 5

# sample theta
theta_c = rand(n_c) * 2π

# coordinates 
x_c = radius .* cos.(theta_c)
y_c = radius .* sin.(theta_c)
z_c = ones(n_c) * 0.9

circle = [x_c y_c z_c];

# %%
p = ext.plot_3D(landmark = torus, witness = circle, landmark_label = "", witness_label = "", 
                xlim = (-5, 5), ylim = (-5, 5), zlim = (-5, 5))
# Out:
# <!DOCTYPE html>
# <html>
#     <head>
#         <title>Plots.jl</title>
#         <meta http-equiv="content-type" content="text/html; charset=UTF-8">
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#     </head>
#     <body>
#             <div id="0cf3a5eb-b955-4a8b-b428-fafd16f6b1be" style="width:600px;height:400px;"></div>
#     <script>
#     PLOT = document.getElementById('0cf3a5eb-b955-4a8b-b428-fafd16f6b1be');
#     Plotly.plot(PLOT, [
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "x": [
#             -3.1403898875302003,
#             -3.6195384166821003,
#             -3.0708785836311083,
#             -0.5231829042257188,
#             -1.9579645571476785,
#             -4.293989768973539,
#             -3.830951660532035,
#             -1.1498303574294821,
#             -4.151984014613859,
#             -2.0497422060908876,
#             -0.7724806208563362,
#             -0.39286661513331045,
#             -3.317053487153437,
#             -2.1560949595230707,
#             -3.5416830337397496,
#             -2.792438574012577,
#             -2.525351405739526,
#             -2.01253773669487,
#             -0.04998092897486894,
#             -1.941920880975412,
#             -0.8945343506635475,
#             -0.5893241784873722,
#             -1.9402037622399777,
#             -4.460221380207502,
#             -2.351332588636879,
#             -3.58943071554328,
#             -1.1018105420071342,
#             -2.8189412985535403,
#             -0.9002617864735871,
#             -3.2167436914909873,
#             -1.093629703281422,
#             -2.7065124791856467,
#             -0.40704446681039674,
#             -0.9242471179158289,
#             -2.918606748102632,
#             -3.475157631746524,
#             -2.4222037461802417,
#             -0.7297875695209957,
#             -2.5770745439756464,
#             -3.239789206153212,
#             -0.9524416635388142,
#             -2.340974586344161,
#             -1.478563785592537,
#             -0.7111827976695724,
#             -0.9383889802192393,
#             -2.9249014764767978,
#             -0.5819098805816294,
#             -4.964169275231973,
#             -1.7994929497205367,
#             -2.7439959639066918,
#             -1.8193375369146654,
#             -0.5922483397882521,
#             -2.945854291480596,
#             -2.349705261456693,
#             -2.620152958373298,
#             -3.8751545581275377,
#             -3.9967485293772,
#             -1.0724697175329645,
#             -2.397884830019714,
#             -2.7052970200648065,
#             -2.5104412954213666,
#             -2.7888189500698126,
#             -0.03733100902088693,
#             -4.08307909563024,
#             -1.5637362291657908,
#             -1.1474550868245834,
#             -0.9982914723145504,
#             -0.5623944846990536,
#             -4.831176080489789,
#             -0.5252346062512081,
#             -1.9463792272046658,
#             -0.6109207049606971,
#             -3.3454699664188228,
#             -3.741014725976378,
#             -2.3496053018141208,
#             -4.034291065453958,
#             -0.9999003826517143,
#             -4.531718554784895,
#             -2.852051685926305,
#             -4.2851922183637665,
#             -1.4017459845216753,
#             -1.1268391180396062,
#             -2.77162722608912,
#             -3.4422352296769336,
#             -4.490995672087903,
#             -3.9014919083359354,
#             -1.201221263258683,
#             -3.328862967822996,
#             -3.5031954127373863,
#             -1.7423277228275218,
#             -1.939957091944387,
#             -1.8071324318394766,
#             -0.8831197439248519,
#             -2.1498225035952974,
#             -0.507296530570392,
#             -0.9195896492134172,
#             -3.2658088508651346,
#             -3.2433630589677565,
#             -2.7539780740510715,
#             -3.4014064778589517,
#             -3.133115001790265,
#             -3.4473389349366945,
#             -2.333133693841321,
#             -2.4924446430080387,
#             -2.7098415245054355,
#             -3.032643344495728,
#             -4.8068242394376295,
#             -1.0239820124961359,
#             -

# %%
# save
#jldopen("data_unpinched.jld2", "w") do file
#    file["double_torus"] = torus
#    file["circle"] = circle
#end;

# %% [markdown]
# ## 2(b) Compute the barcodes
# Use this to check that the barcodes behave as expected.
# Because the high number of points, I just computed the two VR barcodes for now.

# %%
# gather all points 
P = torus
Q = circle
n_P = n_P1
n_Q = n_c
X = vcat(P, Q)

# compute distance
D = pairwise(Euclidean(), X, X, dims = 1)

# Define submatrices 
D_P = D[1:n_P, 1:n_P]
D_Q = D[n_P+1:end, n_P+1:end]
D_P_Q = D[1:n_P, n_P+1:end]
    # rows (landmarks): P
    # columns (witness) : Q
D_Q_P = D[n_P+1:end, 1:n_P];
    # rows (landmarks): Q
    # columns (witness) : P

# %%
# Compute Vietoris-Rips persistence on two regions
dim = 1
VR_P = eirene(D_P, record = "all", maxdim = dim)
VR_Q = eirene(D_Q, record = "all", maxdim = dim);

# %%
# plot all four barcodes
l = grid(2,1)
p1 = plot_barcode(barcode(VR_P, dim = 1), lw = 2, title = "Barcode(VR(P))", titlefontsize = 12)
p4 = plot_barcode(barcode(VR_Q, dim = 1), lw = 2, title = "Barcode(VR(Q))", titlefontsize = 12)
plot(p1, p2, layout = l, size = (500, 700))
# Out:
# <!DOCTYPE html>
# <html>
#     <head>
#         <title>Plots.jl</title>
#         <meta http-equiv="content-type" content="text/html; charset=UTF-8">
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#     </head>
#     <body>
#             <div id="21353224-d9fd-405f-84c5-b859a71a47de" style="width:500px;height:700px;"></div>
#     <script>
#     PLOT = document.getElementById('21353224-d9fd-405f-84c5-b859a71a47de');
#     Plotly.plot(PLOT, [
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 33",
#             "class 33"
#         ],
#         "x": [
#             0.17186077106413575,
#             0.21638051524735286
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y1",
#         "zmin": null,
#         "legendgroup": "y1",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 2
#         },
#         "y": [
#             1.0,
#             1.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 34",
#             "class 34"
#         ],
#         "x": [
#             0.2188052013393471,
#             0.22859350227929598
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y2",
#         "zmin": null,
#         "legendgroup": "y2",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 2
#         },
#         "y": [
#             2.0,
#             2.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 35",
#             "class 35"
#         ],
#         "x": [
#             0.23065259418287856,
#             0.2337152587457733
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y3",
#         "zmin": null,
#         "legendgroup": "y3",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 2
#         },
#         "y": [
#             3.0,
#             3.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 36",
#             "class 36"
#         ],
#         "x": [
#             0.2538966795837664,
#             0.2736345257151996
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y4",
#         "zmin": null,
#         "legendgroup": "y4",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 2
#         },
#         "y": [
#             4.0,
#             4.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 37",
#             "class 37"
#         ],
#         "x": [
#             0.2762093706510583,
#             0.3199064706155418
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y5",
#         "zmin": null,
#         "legendgroup": "y5",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 2
#         },
#         "y": [
#             5.0,
#             5.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 38",
#             "class 38"
#         ],
#         "x": [
#             0.28498812029475323,
#             0.35460234425000203
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y6",
#         "zmin": null,
#         "legendgroup": "y6",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 2
#         },
#         "y": [
#             6.0,
#             6.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 39",
#             "class 39"
#         ],
#         "x": [
#             0.29276928723374923,
#             0.33762251759310064
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y7",
#         "zmin": null,
#         "legendgroup": "y7",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 2
#         },
#         "y": [
#             7.0,
#             7.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 40",
#             "class 40"
#         ],
#         "x": [
#             0.2941359947227821,
#             0.31733820266392704
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y8",
#         "zmin": null,
#         "legendgroup": "y8",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 2
#         },
#         "y": [
#             8.0,
#             8.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 41",
#             "class 41"
#         ],
#         "x": [
#             0.29479975237548717,
#             0.2983733237677265
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y9",
#         "zmin": null,
#         "legendgroup": "y9",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 2
#         },
#         "y": [
#             9.0,
#             9.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 1",
#             "class 1"
#         ],
#         "x": [
#             0.2987824629064311,
#             0.34647176670654295
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y10",
#         "zmin": null,
#         "legendgroup": "y10",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 2
#         },
#         "y": [
#             10.0,
#             10.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 42",
#             "class 42"
#         ],
#         "x": [
#             0.2996890430065859,
#             0.333209332955538
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y11",
#         "zmin": null,
#         "legendgroup": "y11",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143

# %% [markdown]
# # 3. Double torus and slightly less pinched circle

# %%
### Sample points from torus
# number of points in each torus
n = 400

# generate "size" of a torus
R = 2
r = 1

# sample theta, phi
theta1 = rand(n) * 2π
phi1 = rand(n) * 2π
theta2 = rand(n) * 2π
phi2 = rand(n) * 2π

### coordinates of torus 1
# center location of torus 1
center1_x = -2
center1_y = 0
center1_z = 0

x1 = (R .+ r .* cos.(theta1) ).* cos.(phi1) .+ center1_x
y1 = (R .+ r .* cos.(theta1)) .* sin.(phi1) .+ center1_y
z1 = r .* sin.(theta1) .+ center1_z ; 

t1_idx = findall(x -> x <0, x1 )
x1 = x1[t1_idx]
y1 = y1[t1_idx]
z1 = z1[t1_idx]

### coordinates of torus 2
# center location of torus 2
center2_x = 2
center2_y = 0
center2_z = 0

x2 = (R .+ r .* cos.(theta2) ).* cos.(phi2) .+ center2_x
y2 = (R .+ r .* cos.(theta2)) .* sin.(phi2) .+ center2_y
z2 = r .* sin.(theta2) .+ center2_z;

t2_idx = findall(x -> x > 0, x2 )
x2 = x2[t2_idx]
y2 = y2[t2_idx]
z2 = z2[t2_idx]

# all coordinates
x = vcat(x1, x2)
y = vcat(y1, y2)
z = vcat(z1, z2)

torus = collect([x y z])

##### sample points from circle
# number of points in circle
n_c = 50

# sample theta, phi
theta_c1 = 0.5 .+rand(n_c) /4 
phi_c1 = rand(n_c) * 2π 
theta_c2 = 0.5 .+ rand(n_c) /4 
phi_c2 = rand(n_c) * 2π 

# coordinates of first circle
x_c1 = (R .+ r .* cos.(theta_c1) ).* cos.(phi_c1) .+ center1_x
y_c1 = (R .+ r .* cos.(theta_c1)) .* sin.(phi_c1)
z_c1 = r .* sin.(theta_c1)

t1_idx = findall(x -> x <0, x_c1 )
x_c1 = x_c1[t1_idx]
y_c1 = y_c1[t1_idx]
z_c1 = z_c1[t1_idx]

# coordinates of second circle
x_c2 = (R .+ r .* cos.(theta_c2) ).* cos.(phi_c2) .+ center2_x
y_c2 = (R .+ r .* cos.(theta_c2)) .* sin.(phi_c2)
z_c2 = r .* sin.(theta_c2)

t2_idx = findall(x -> x > 0, x_c2 )
x_c2 = x_c2[t2_idx]
y_c2 = y_c2[t2_idx]
z_c2 = z_c2[t2_idx]

# all coordinates
x_c = vcat(x_c1, x_c2)
y_c = vcat(y_c1, y_c2)
z_c = vcat(z_c1, z_c2)
circle = collect([x_c y_c z_c]);

# %%
p = ext.plot_3D(landmark = torus, witness = circle, landmark_label = "", witness_label = "", 
                xlim = (-5, 5), ylim = (-5, 5), zlim = (-5, 5))
# Out:
# <!DOCTYPE html>
# <html>
#     <head>
#         <title>Plots.jl</title>
#         <meta http-equiv="content-type" content="text/html; charset=UTF-8">
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#     </head>
#     <body>
#             <div id
#             -1.28078814104002,
#             -2.1730450504257965,
#             -0.007139867047235127,
#             -2.90362910647097,
#             -0.356135676946993,
#             -4.1662

# %%
# save
#jldopen("data_pinched2.jld2", "w") do file
#    file["double_torus"] = torus
#    file["circle"] = circle
#end;

# %% [markdown]
# # 4. Double torus with an oval

# %%
### Sample points from torus
# number of points in each torus
n = 400

# generate "size" of a torus
R = 2
r = 1

# sample theta, phi
theta1 = rand(n) * 2π
phi1 = rand(n) * 2π
theta2 = rand(n) * 2π
phi2 = rand(n) * 2π

### coordinates of torus 1
# center location of torus 1
center1_x = -2
center1_y = 0
center1_z = 0

x1 = (R .+ r .* cos.(theta1) ).* cos.(phi1) .+ center1_x
y1 = (R .+ r .* cos.(theta1)) .* sin.(phi1) .+ center1_y
z1 = r .* sin.(theta1) .+ center1_z ; 

t1_idx = findall(x -> x <0, x1 )
x1 = x1[t1_idx]
y1 = y1[t1_idx]
z1 = z1[t1_idx]

### coordinates of torus 2
# center location of torus 2
center2_x = 2
center2_y = 0
center2_z = 0

x2 = (R .+ r .* cos.(theta2) ).* cos.(phi2) .+ center2_x
y2 = (R .+ r .* cos.(theta2)) .* sin.(phi2) .+ center2_y
z2 = r .* sin.(theta2) .+ center2_z;

t2_idx = findall(x -> x > 0, x2 )
x2 = x2[t2_idx]
y2 = y2[t2_idx]
z2 = z2[t2_idx]

# all coordinates
x = vcat(x1, x2)
y = vcat(y1, y2)
z = vcat(z1, z2)

torus = collect([x y z]);

# %%
##### sample points from oval
# number of points in circle
n_c = 50

# sample theta, phi
theta_c1 = 0.5 .+rand(n_c) /4 
phi_c1 = rand(n_c) * 2π 
theta_c2 = 0.5 .+ rand(n_c) /4 
phi_c2 = rand(n_c) * 2π 

# coordinates of first circle
x_c1 = (R .+ r .* cos.(theta_c1) ).* cos.(phi_c1) .+ center1_x
y_c1 = (R .+ r .* cos.(theta_c1)) .* sin.(phi_c1)
z_c1 = r .* sin.(theta_c1)

t1_idx = findall(x -> x <0, x_c1 )
x_c1 = x_c1[t1_idx]
y_c1 = y_c1[t1_idx]
z_c1 = z_c1[t1_idx]

# coordinates of second circle
x_c2 = (R .+ r .* cos.(theta_c2) ).* cos.(phi_c2) .+ center2_x
y_c2 = (R .+ r .* cos.(theta_c2)) .* sin.(phi_c2)
z_c2 = r .* sin.(theta_c2)

t2_idx = findall(x -> x > 0, x_c2 )
x_c2 = x_c2[t2_idx]
y_c2 = y_c2[t2_idx]
z_c2 = z_c2[t2_idx]

# all coordinates
x_c = vcat(x_c1, x_c2)
y_c = vcat(y_c1, y_c2)
z_c = vcat(z_c1, z_c2);

# %%
# "push out" the pinched portion

# if x in [-2, 2]
    # push negative y values to -2.9, positive y values to 2.9

idx = findall(x -> -2 < x < 2, x_c)
for i in idx
    if y_c[i] < 0
        y_c[i] = -2.9
    else
        y_c[i] = 2.9
    end
end

circle = collect([x_c y_c z_c]);

# %%
p = ext.plot_3D(landmark = torus, witness = circle, landmark_label = "", witness_label = "", 
                xlim = (-5, 5), ylim = (-5, 5), zlim = (-5, 5))
# Out:
# <!DOCTYPE html>
# <html>
#     <head>
#         <title>Plots.jl</title>
#         <meta http-equiv="content-type" content="text/html; charset=UTF-8">
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#     </head>
#     <body>
#             <div id