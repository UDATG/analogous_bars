# %% [markdown]
# # Example: Similarity-centric analogous bars
# * This notebook shows an application of the <b>similarity-centric analogous bars method</b> to compare barcodes built on two different point clouds `P` and `Q`.
#
# #### Similarity-centric analogous bars
# * <b> Inputs </b>:
#     * Distance matrix among points in `P`
#     * Distance matrix among points in `Q`
#     * Corss-system distance matrix among `P` and `Q`.
# * <b> Goal </b>:
#     Given a selected bar in the Witness barcode `barcode(W(P,Q))`, find its representations in `barcode(VR(P))` and `barcode(VR(Q))`
# * <b> Implementation </b>:
#     * Given a selected bar `bar_W_PQ` in `barcode(W(P,Q))`, apply Dowker's Theorem to find the corresponding bar `bar_W_QP` in `barcode(W(Q,P))`.
#     * Apply the bar-to-bars extension method to find the representation of `bar_W_PQ` in `barcode(VR(P))`.
#     * Apply the bar-to-bars extension method second time to find the representation of `bar_W_QP` in `barcode(VR(Q))`.
#     * All extension methds are implemented component-wise with $\mathbb{F}_2$ coefficients. We assume that all bars of barcodes have unique death times.
#
# #### Example data
# * `P`: 300 points sampled from a square torus.
# * `Q`: 20 points along one of the S1's of the torus.
# * The goal is to identify which of the S1's of `P` is encoded in `Q`
#
# #### Contents
# 1. Load points and visualize
# 2. Plot the four relevant barcodes
# 3. Run the similarity-centric analogous bars method
# 4. Explore cycle extension & bar extension under fixed interval decompositions of `barcode(VR(P))` and `barcode(VR(Q))`.
# 5. Explore alternative bar extensions under all possible interval decompositions of `barcode(VR(P))` and `barcode(VR(Q))`.

# %%
using Revise
includet("../extension_method.jl")
# Out:
# HTML{String}("<script>\n// Immediately-invoked-function-expression to avoid global variables.\n(function() {\n    var warning_div = document.getElementById(\"webio-warning-10022999113292283973\");\n    var hide = function () {\n        var script = document.getElementById(\"webio-setup-17828944489053039063\");\n        var parent = script && script.parentElement;\n        var grandparent = parent && parent.parentElement;\n        if (grandparent) {\n            grandparent.style.display = \"none\";\n        }\n        warning_div.style.display = \"none\";\n    };\n    if (typeof Jupyter !== \"undefined\") {\n        console.log(\"WebIO detected Jupyter notebook environment.\");\n        // Jupyter notebook.\n        var extensions = (\n            Jupyter\n            && Jupyter.notebook.config.data\n            && Jupyter.notebook.config.data.load_extensions\n        );\n        if (extensions && extensions[\"webio-jupyter-notebook\"]) {\n            // Extension already loaded.\n            console.log(\"Jupyter WebIO nbextension detected; not loading ad-hoc.\");\n            hide();\n            return;\n        }\n    } else if (window.location.pathname.includes(\"/lab\")) {\n        // Guessing JupyterLa\n        console.log(\"Jupyter Lab detected; make sure the @webio/jupyter-lab-provider labextension is installed.\");\n        hide();\n        return;\n    }\n})();\n\n</script>\n<p\n    id=\"webio-warning-10022999113292283973\"\n    class=\"output_text output_stderr\"\n    style=\"padding: 1em; font-weight: bold;\"\n>\n    Unable to load WebIO. Please make sure WebIO works for your Jupyter client.\n    For troubleshooting, please see <a href=\"https://juliagizmos.github.io/WebIO.jl/latest/providers/ijulia/\">\n    the WebIO/IJulia documentation</a>.\n    <!-- TODO: link to installation docs. -->\n</p>\n")
# ┌ Warning: ORCA.jl has been deprecated and all savefig functionality
# │ has been implemented directly in PlotlyBase itself.
# │
# │ By implementing in PlotlyBase.jl, the savefig routines are automatically
# │ available to PlotlyJS.jl also.
# └ @ ORCA /opt/julia/packages/ORCA/U5XaN/src/ORCA.jl:8

# %%
using .ext
using DelimitedFiles
using Printf
using HDF5
using Eirene
using Plots

# %% [markdown]
# # 1. Load points and visualize
# * `P`: 300 points sampled from a square torus.
# * `Q`: 20 points along one of the S1's of the torus.

# %%
# directory
directory = "data/torus_circle/"

# load points. Coordinates are on a square torus
P = h5read(directory * "coords.h5", "circle")
Q = h5read(directory * "coords.h5", "torus")

# print number of points 
print("number of points in P: ", size(P,1), "\n")
print("number of points in Q: ", size(Q,1))

# load distance matrices
D_P = readdlm(directory * "distance_circle.csv")
D_Q = readdlm(directory * "distance_torus.csv")
D_P_Q = readdlm(directory * "distance_circle_torus.csv")
D_Q_P = readdlm(directory * "distance_torus_circle.csv");
# Out:
# number of points in P: 20
# number of points in Q: 300

# %% [markdown]
# Plot the points on a square torus. Assume that the sides of the squares have been identified to represent a torus

# %%
p = plot_P_Q(P, Q)
# Out:
#     <script type="text/javascript">
#         requirejs(["https://cdn.plot.ly/plotly-latest.min.js"], function(p) {
#             window.Plotly = p
#         });
#     </script>
# <!DOCTYPE html>
# <html>
#     <head>
#         <title>Plots.jl</title>
#         <meta http-equiv="content-type" content="text/html; charset=UTF-8">
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#     </head>
#     <body>
#             <div id="65cb29fa-f04d-44db-b67d-dcbb76db58a3" style="width:600px;height:400px;"></div>
#     <script>
#     PLOT = document.getElementById('65cb29fa-f04d-44db-b67d-dcbb76db58a3');
#     Plotly.plot(PLOT, [
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "x": [
#             1.2007673288583944,
#             0.9256937871952255,
#             0.11995877571545974,
#             0.9980423401029123,
#             1.6284853701515511,
#             0.1092775567610899,
#             4.298411498744067,
#             2.1989475837572168,
#             5.265293729691815,
#             0.8451736841001005,
#             4.87621712297566,
#             3.3254585447242344,
#             0.9296074780028853,
#             3.0632063945921435,
#             1.2223082893390196,
#             1.9009052648123823,
#             3.3642895957444976,
#             1.402836513385794,
#             3.9298405496958897,
#             4.275244533488006
#         ],
#         "showlegend": true,
#         "mode": "markers",
#         "name": "P",
#         "zmin": null,
#         "legendgroup": "P",
#         "marker": {
#             "symbol": "circle",
#             "color": "rgba(0, 129, 129, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 10
#         },
#         "zmax": null,
#         "y": [
#
#             4.911486204483468,
#             1.1082456620891503,
#             5.691568264715149,
#             4.891296343302329,
#             4.893343442308227,
#             5.89571892256287,
#             4.4998942610745045,
#             2.5932786911101404,
#             0.5769071913990185,
#             4.807410504012685,
#             1.107296696652395,
#             4.821243438294209,
#             5.528477400834526,
#             2.8642078520301086,
#             2.9744124952172255,
#             4.448569479230991,
#             3.1486737312304283,
#             4.337761393499303,
#             4.160466503759243,
#             4.595170854227276,
#             3.1247259547353594,
#             0.6356476691338129,
#             5.48155934316255,
#             1.171210846280836,
#             3.831942785273644,
#             4.181507090623986,
#             4.7342917552799575,
#             2.684826869864545,
#             5.314648118319865,
#             1.200677816635204,
#             3.0866183605960655,
#             5.462320061426911,
#             5.0599528436208745,
#             4.616566608387848,
#             5.141464905620005,
#             4.808765855006578,
#             0.12688153594002038,
#             1.850627552350616,
#             3.2300709963124064,
#             0.7177018428848316,
#             4.310550761906158,
#             2.934334853217976,
#             4.631698243017389,
#             1.6857255692608653,
#             5.112904979739172,
#             1.1999731489730714,
#             4.893758871263015,
#             2.3137975056377322,
#             1.2361111958106583,
#             1.8372346911961301,
#             3.485565890884082,
#             5.773007470615817,
#             4.059816474351488,
#             1.902918954803756,
#             1.1498674197548693,
#             2.198726193678424,
#             0.49247969918646634,
#             5.911859083161256,
#             3.655169539300373,
#             5.178370711863971,
#             3.1736016120141337,
#             2.9199862730047723,
#             0.764314187

# %% [markdown]
# # 2. Plot the four relevant barcodes

# %%
# Compute Vietoris-Rips persistence on two regions
dim = 1
VR_P = eirene(D_P, record = "all", maxdim = dim)
VR_Q = eirene(D_Q, record = "all", maxdim = dim)

# compute Witness persistence
W_P = compute_Witness_persistence(D_P_Q, maxdim = dim)
W_Q = compute_Witness_persistence(D_Q_P, maxdim = dim);

# %%
# plot all four barcodes
barcode_VR_P = barcode(VR_P, dim = 1)
barcode_W_P = barcode(W_P["eirene_output"], dim = 1)
barcode_W_Q = barcode(W_Q["eirene_output"], dim = 1)
barcode_VR_Q = barcode(VR_Q, dim = 1)

# plot
p1 = plot_barcode(barcode_VR_P, lw = 3, title = "Barcode(VR(P))", titlefontsize = 12)
p2 = plot_barcode(barcode_W_P, lw = 3, title = "Barcode(W(P,Q))", titlefontsize = 12)
p3 = plot_barcode(barcode_W_Q, lw = 3, title = "Barcode(W(Q,P))", titlefontsize = 12)
p4 = plot_barcode(barcode_VR_Q, lw = 2, title = "Barcode(VR(Q))", titlefontsize = 12)
plot(p1, p2, p3, p4, layout = grid(4,1), size = (500, 700))
# Out:
# <!DOCTYPE html>
# <html>
#     <head>
#         <title>Plots.jl</title>
#         <meta http-equiv="content-type" content="text/html; charset=UTF-8">
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#     </head>
#     <body>
#             <div id="6f328c4d-5d78-47ee-b9d0-aa891cb761b2" style="width:500px;height:700px;"></div>
#     <script>
#     PLOT = document.getElementById('6f328c4d-5d78-47ee-b9d0-aa891cb761b2');
#     Plotly.plot(PLOT, [
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 1",
#             "class 1"
#         ],
#         "x": [
#             0.43461363816968723,
#             0.4624602682545485
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y1",
#         "zmin": null,
#         "legendgroup": "y1",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             1.0,
#             1.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 2",
#             "class 2"
#         ],
#         "x": [
#             1.1447269023005358,
#             2.1071545896100745
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y2",
#         "zmin": null,
#         "legendgroup": "y2",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             2.0,
#             2.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x2",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y2",
#         "text": [
#             "class 2",
#             "class 2"
#         ],
#         "x": [
#             0.3090224712426719,
#             0.36454383762849696
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y1",
#         "zmin": null,
#         "legendgroup": "y1",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             1.0,
#             1.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x2",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y2",
#         "text": [
#             "class 1",
#             "class 1"
#         ],
#         "x": [
#             0.6526576895133331,
#             1.6115900662343297
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y2",
#         "zmin": null,
#         "legendgroup": "y2",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             2.0,
#             2.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x3",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y3",
#         "text": [
#             "class 1",
#             "class 1"
#         ],
#         "x": [
#             0.3090224712426719,
#             0.36454383762849696
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y1",
#         "zmin": null,
#         "legendgroup": "y1",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             1.0,
#             1.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x3",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y3",
#         "text": [
#             "class 2",
#             "class 2"
#         ],
#         "x": [
#             0.6526576895133331,
#             1.6115900662343297
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y2",
#         "zmin": null,
#         "legendgroup": "y2",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             2.0,
#             2.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x4",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y4",
#         "text": [
#             "class 18",
#             "class 18"
#         ],
#         "x": [
#             0.21302414593246224,
#             0.2671154473730644
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y1",
#         "zmin": null,
#         "legendgroup": "y1",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 2
#         },
#         "y": [
#             1.0,
#             1.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x4",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y4",
#         "text": [
#             "class 19",
#             "class 19"
#         ],
#         "x": [
#             0.22172740066803362,
#             0.2599552513795967
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y2",
#         "zmin": null,
#         "legendgroup": "y2",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 2
#         },
#         "y": [
#             2.0,
#             2.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x4",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y4",
#         "text": [
#             "class 20",
#             "class 20"
#         ],
#         "x": [
#             0.2743958714093529,
#             0.3171379470778279
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y3",
#         "zmin": null,
#         "legendgroup": "y3",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 2
#         },
#         "y": [
#             3.0,
#             3.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x4",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y4",
#         "text": [
#             "class 21",
#             "class 21"
#         ],
#         "x": [
#             0.2790547929784377,
#             0.3536732582986236
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y4",
#         "zmin": null,
#         "legendgroup": "y4",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 2
#         },
#         "y": [
#             4.0,
#             4.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x4",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y4",
#         "text": [
#             "class 22",
#             "class 22"
#         ],
#         "x": [
#             0.2825107123053771,
#             0.3859956505917918
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y5",
#         "zmin": null,
#         "legendgroup": "y5",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",

# %% [markdown]
# # 3. Run similarity-centric analogous bars method

# %% [markdown]
# Select bar in `barcode(W(P,Q))`

# %%
# select bar
W_P_bar = 1

# run extension
extension_P, extension_Q = run_similarity_analogous(VR_P = VR_P,
                                                    D_P = D_P,
                                                    VR_Q = VR_Q,
                                                    D_Q = D_Q,
                                                    W_PQ = W_P,
                                                    W_PQ_bar = W_P_bar,
                                                    dim = 1);

# %% [markdown]
# Plot baseline bar extensions

# %%
plot_analogous_bars(extension_P, extension_Q)
# Out:
# <!DOCTYPE html>
# <html>
#     <head>
#         <title>Plots.jl</title>
#         <meta http-equiv="content-type" content="text/html; charset=UTF-8">
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#     </head>
#     <body>
#             <div id="3dcbda17-cac6-4f84-830e-06a51030e9b6" style="width:500px;height:1000px;"></div>
#     <script>
#     PLOT = document.getElementById('3dcbda17-cac6-4f84-830e-06a51030e9b6');
#     Plotly.plot(PLOT, [
#     {
#         "xaxis": "x2",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y2",
#         "text": [
#             "class 1",
#             "class 1"
#         ],
#         "x": [
#             0.43461363816968723,
#             0.4624602682545485
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y1",
#         "zmin": null,
#         "legendgroup": "y1",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": null
#         },
#         "y": [
#             1.0,
#             1.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x2",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y2",
#         "text": [
#             "class 2",
#             "class 2"
#         ],
#         "x": [
#             1.1447269023005358,
#             1.1447269023005358
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y2",
#         "zmin": null,
#         "legendgroup": "y2",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": null
#         },
#         "y": [
#             2.0,
#             2.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x2",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y2",
#         "text": [
#             "class 2",
#             "class 2"
#         ],
#         "x": [
#             1.1447269023005358,
#             2.1071545896100745
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y3",
#         "zmin": null,
#         "legendgroup": "y3",
#         "zmax": null,
#         "line": {
#             "color": "rgba(238, 18, 137, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": null
#         },
#         "y": [
#             2.0,
#             2.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x2",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y2",
#         "x": [
#             1.1447269023005358,
#             1.1447269023005358
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y4",
#         "zmin": null,
#         "legendgroup": "y4",
#         "zmax": null,
#         "line": {
#             "color": "rgba(255, 0, 0, 1.000)",
#             "shape": "linear",
#             "dash": "dot",
#             "width": 1
#         },
#         "y": [
#             -401.0,
#             403.0
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x3",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y3",
#         "text": [
#             "class 2",
#             "class 2"
#         ],
#         "x": [
#             0.3090224712426719,
#             0.36454383762849696
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y1",
#         "zmin": null,
#         "legendgroup": "y1",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": null
#         },
#         "y": [
#             1.0,
#             1.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x3",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y3",
#         "text": [
#             "class 1",
#             "class 1"
#         ],
#         "x": [
#             0.6526576895133331,
#             1.6115900662343297
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y2",
#         "zmin": null,
#         "legendgroup": "y2",
#         "zmax": null,
#         "line": {
#             "color": "rgba(0, 178, 238, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": null
#         },
#         "y": [
#             2.0,
#             2.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x4",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y4",
#         "text": [
#             "class 1",
#             "class 1"
#         ],
#         "x": [
#             0.3090224712426719,
#             0.36454383762849696
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y1",
#         "zmin": null,
#         "legendgroup": "y1",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": null
#         },
#         "y": [
#             1.0,
#             1.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x4",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y4",
#         "text": [
#             "class 2",
#             "class 2"
#         ],
#         "x": [
#             0.6526576895133331,
#             1.6115900662343297
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y2",
#         "zmin": null,
#         "legendgroup": "y2",
#         "zmax": null,
#         "line": {
#             "color": "rgba(0, 178, 238, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": null
#         },
#         "y": [
#             2.0,
#             2.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x5",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y5",
#         "text": [
#             "class 18",
#             "class 18"
#         ],
#         "x": [
#             0.21302414593246224,
#             0.2671154473730644
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y1",
#         "zmin": null,
#         "legendgroup": "y1",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": null
#         },
#         "y": [
#             1.0,
#             1.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x5",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y5",
#         "text": [
#             "class 19",
#             "class 19"
#         ],
#         "x": [
#             0.22172740066803362,
#             0.2599552513795967
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y2",
#         "zmin": null,
#         "legendgroup": "y2",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": null
#         },
#         "y": [
#             2.0,
#             2.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x5",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y5",
#         "text": [
#             "class 20",
#             "class 20"
#         ],
#         "x": [
#             0.2743958714093529,
#             0.3171379470778279
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y3",
#         "zmin": null,
#         "legendgroup": "y3",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": null

# %% [markdown]
# Plot baseline cycle extensions

# %%
# select baseline cycle extension in P
epsilon0_P = extension_P["epsilon_0"]
cycle_P = extension_P["cycle_extensions"][epsilon0_P]["baseline"]

# select baseline cycle extension in Q
epsilon0_Q = extension_Q["epsilon_0"]
cycle_Q = extension_Q["cycle_extensions"][epsilon0_Q]["baseline"]

p1 = plot_cycle_square_torus(P, Q, cycle = cycle_P, cycle_loc = "P", title = "cycle extension to VR(P)"; legend = false)
p2 = plot_cycle_square_torus(P, Q, cycle = cycle_Q, cycle_loc = "Q", title = "cycle extension to VR(Q)"; legend = false)

plot(p1, p2, layout = grid(1,2), size = (600, 300))
# Out:
# <!DOCTYPE html>
# <html>
#     <head>
#         <title>Plots.jl</title>
#         <meta http-equiv="content-type" content="text/html; charset=UTF-8">
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#     </head>
#     <body>
#             <div id="8261596e-0f26-4a09-a6c5-c834f471f1ae" style="width:600px;height:300px;"></div>
#     <script>
#     PLOT = document.getElementById('8261596e-0f26-4a09-a6c5-c834f471f1ae');
#     Plotly.plot(PLOT, [
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "x": [
#             1.2007673288583944,
#             0.9256937871952255,
#             0.11995877571545974,
#             0.9980423401029123,
#             1.6284853701515511,
#             0.1092775567610899,
#             4.298411498744067,
#             2.1989475837572168,
#             5.265293729691815,
#             0.8451736841001005,
#             4.87621712297566,
#             3.3254585447242344,
#             0.9296074780028853,
#             3.0632063945921435,
#             1.2223082893390196,
#             1.9009052648123823,
#             3.3642895957444976,
#             1.402836513385794,
#             3.9298405496958897,
#             4.275244533488006
#         ],
#         "showlegend": true,
#         "mode": "markers",
#         "name": "P",
#         "zmin": null,
#         "legendgroup": "P",
#         "marker": {
#             "symbol": "circle",
#             "color": "rgba(0, 129, 129, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 10
#         },
#         "zmax": null,
#         "y": [
#             2.9541772362853513,
#             3.4311557772574135,
#             3.3855434998809577,
#             3.3698358445784535,
#             3.1299117653088016,
#             3.4644427371933224,
#             3.2298167701031106,
#             3.2404129266508597,
#             3.2602588058203343,
#             3.468191209037778,
#             3.3477999843237116,
#             3.087852625631911,
#             2.9465096291510604,
#             2.8774830152489264,
#             2.8202977859161553,
#             2.9977455888390696,
#             3.010531128373751,
#             3.2116249354750668,
#             3.0023535524553853,
#             3.0212094430725993
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "x": [
#
#             3.0866183605960655,
#             5.462320061426911,
#             5.0599528436208745,
#             4.616566608387848,
#             5.141464905620005,
#             4.808765855006578,
#             0.12688153594002038,
#             1.850627552350616,
#             3.2300709963124064,
#             0.7177018428848316,
#             4.310550761906158,
#             2.934334853217976,
#             4.631698243017389,
#             1.6857255692608653,
#             5.112904979739172,
#             1.1999731489730714,
#             4.893758871263015,
#             2.3137975056377322,
#             1.2361111958106583,
#             1.8372346911961301,
#             3.485565890884082,
#             5.773007470615817,
#             4.059816474351488,
#             1.902918954803756,
#             1.1498674197548693,
#             2.198726193678424,
#             0.49247969918646634,
#             5.911859083161256,
#             3.655169539300373,
#             5.178370711863971,
#             3.1736016120141337,
#             2.9199862730047723,
#             0.764314187

# %% [markdown]
# # 4. Explore cycle extension & bar extension under fixed interval decompositions of `barcode(VR(P))` and `barcode(VR(Q))`.
# * The `run_similarity_analogous()` function presents the component-wise cycle and bar extensions to `barcode(VR(P))` and `barcode(VR(Q))`. This section illustrates the use of various functions to explore all cycle extension & bar extensions.
# * For bar extensions, we only consider the result under a fixed interval decomposition of `barcode(VR(P))` and `barcode(VR(Q))`.
# * This section is organized as the following.
#     * (a) Plotting the extension parameters for both `barcode(VR(P))` and `barcode(VR(Q))`
#     * (b) Interactively exploring the baseline and offset bar-extensions at various parameters.
#     * (c) Finding all cycle extensions and bar extensions (non-interactive).
# * Both subsection (b) and (c) illustrate how one may understand the bar-extensions. If your auxiliary filtration and target filtraiton barcodes have large number of bars, then implementing the non-interactive method may take a while.

# %% [markdown]
# ## 4(a) Examine the parameters `p_Y`

# %%
p1 = plot_pY(extension_P)
p2 = plot_pY(extension_Q)

plot(p1, p2, grid = (1, 2), size = (700, 300))
# Out:
# <!DOCTYPE html>
# <html>
#     <head>
#         <title>Plots.jl</title>
#         <meta http-equiv="content-type" content="text/html; charset=UTF-8">
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#     </head>
#     <body>
#             <div id="17ea94df-23e6-4ec9-a4e2-32211938f5cc" style="width:700px;height:300px;"></div>
#     <script>
#     PLOT = document.getElementById('17ea94df-23e6-4ec9-a4e2-32211938f5cc');
#     Plotly.plot(PLOT, [
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 1",
#             "class 1"
#         ],
#         "x": [
#             0.43461363816968723,
#             0.4624602682545485
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y1",
#         "zmin": null,
#         "legendgroup": "y1",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": null
#         },
#         "y": [
#             1.0,
#             1.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 2",
#             "class 2"
#         ],
#         "x": [
#             1.1447269023005358,
#             2.1071545896100745
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y2",
#         "zmin": null,
#         "legendgroup": "y2",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": null
#         },
#         "y": [
#             2.0,
#             2.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "x": [
#             1.1447269023005358,
#             1.1447269023005358
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y3",
#         "zmin": null,
#         "legendgroup": "y3",
#         "zmax": null,
#         "line": {
#             "color": "rgba(255, 0, 0, 1.000)",
#             "shape": "linear",
#             "dash": "dot",
#             "width": 1
#         },
#         "y": [
#             -401.0,
#             403.0
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x2",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y2",
#         "text": [
#             "class 18",
#             "class 18"
#         ],
#         "x": [
#             0.21302414593246224,
#             0.2671154473730644
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y1",
#         "zmin": null,
#         "legendgroup": "y1",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": null
#         },
#         "y": [
#             1.0,
#             1.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x2",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y2",
#         "text": [
#             "class 19",
#             "class 19"
#         ],
#         "x": [
#             0.22172740066803362,
#             0.2599552513795967
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y2",
#         "zmin": null,
#         "legendgroup": "y2",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": null
#         },
#         "y": [
#             2.0,
#             2.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x2",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y2",
#         "text": [
#             "class 20",
#             "class 20"
#         ],
#         "x": [
#             0.2743958714093529,
#             0.3171379470778279
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y3",
#         "zmin": null,
#         "legendgroup": "y3",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": null
#         },
#         "y": [
#             3.0,
#             3.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x2",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y2",
#         "text": [
#             "class 21",
#             "class 21"
#         ],
#         "x": [
#             0.2790547929784377,
#             0.3536732582986236
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y4",
#         "zmin": null,
#         "legendgroup": "y4",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": null
#         },
#         "y": [
#             4.0,
#             4.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x2",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y2",
#         "text": [
#             "class 22",
#             "class 22"
#         ],
#         "x": [
#             0.2825107123053771,
#             0.3859956505917918
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y5",
#         "zmin": null,
#         "legendgroup": "y5",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": null
#         },
#         "y": [
#             5.0,
#             5.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x2",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y2",
#         "text": [
#             "class 1",
#             "class 1"
#         ],
#         "x": [
#             0.2949948158473116,
#             0.3141041129307108
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y6",
#         "zmin": null,
#         "legendgroup": "y6",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": null
#         },
#         "y": [
#             6.0,
#             6.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x2",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y2",
#         "text": [
#             "class 2",
#             "class 2"
#         ],
#         "x": [
#             0.2981308007961632,
#             0.3250894598232143
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y7",
#         "zmin": null,
#         "legendgroup": "y7",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": null
#         },
#         "y": [
#             7.0,
#             7.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x2",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y2",
#         "text": [
#             "class 3",
#             "class 3"
#         ],
#         "x": [
#             0.30471347657719033,
#             0.32835744427497654
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y8",
#         "zmin": null,
#         "legendgroup": "y8",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": n

# %% [markdown]
# ## 4(b) Interactive exploration of baseline and offset bar extensions
# * We use the function `return_extension_results_at_parameter()`, which is an interactive function that requires the user to select the following:
#     * A parameter of `p_Y`
#     * Offset bar extensions
# * The function shows the baseline bar-extension at selected parameter, along with the final bar-extension (baseline bar extension + selected offset bar extensions).
# * The function returns a plot object that highlights the final bar extension

# %% [markdown]
# <b> Explore extension results to `barcode(VR(P))`</b>

# %%
p = return_extension_results_at_parameter(extension_P);
# Out:
# *** Parameter key, value pair ***
# key: 1 parameter: 1.144727
# Select a key for parameter 1
# Selected parameter: 1.1447269023005358
#
# Baseline bars extension at selected parameter: [2]
#
# *** Offset bar extensions at selected parameter ***
# Select keys for offset bar extensions.
# Leave blank to select none.
# To select multiple keys, separate keys with space. ex) 1 2 3 :
# Baseline bars extension at selected parameter: [2]

# %%
plot(p, title = "barcode(VR(P))")
# Out:
# <!DOCTYPE html>
# <html>
#     <head>
#         <title>Plots.jl</title>
#         <meta http-equiv="content-type" content="text/html; charset=UTF-8">
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#     </head>
#     <body>
#             <div id="b7f2c880-fcc3-4a7f-9064-e62533f4c2b2" style="width:600px;height:400px;"></div>
#     <script>
#     PLOT = document.getElementById('b7f2c880-fcc3-4a7f-9064-e62533f4c2b2');
#     Plotly.plot(PLOT, [
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 1",
#             "class 1"
#         ],
#         "x": [
#             0.43461363816968723,
#             0.4624602682545485
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y1",
#         "zmin": null,
#         "legendgroup": "y1",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 1
#         },
#         "y": [
#             1.0,
#             1.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 2",
#             "class 2"
#         ],
#         "x": [
#             1.1447269023005358,
#             1.1447269023005358
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y2",
#         "zmin": null,
#         "legendgroup": "y2",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 1
#         },
#         "y": [
#             2.0,
#             2.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 2",
#             "class 2"
#         ],
#         "x": [
#             1.1447269023005358,
#             2.1071545896100745
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y3",
#         "zmin": null,
#         "legendgroup": "y3",
#         "zmax": null,
#         "line": {
#             "color": "rgba(238, 18, 137, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 1
#         },
#         "y": [
#             2.0,
#             2.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "x": [
#             1.1447269023005358,
#             1.1447269023005358
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y4",
#         "zmin": null,
#         "legendgroup": "y4",
#         "zmax": null,
#         "line": {
#             "color": "rgba(255, 0, 0, 1.000)",
#             "shape": "linear",
#             "dash": "dot",
#             "width": 1
#         },
#         "y": [
#             -401.0,
#             403.0
#         ],
#         "type": "scatter"
#     }
# ]
# , {
#     "showlegend": false,
#     "xaxis": {
#         "showticklabels": true,
#         "gridwidth": 0.5,
#         "tickvals": [
#             0.5,
#             1.0,
#             1.5,
#             2.0
#         ],
#         "visible": true,
#         "ticks": "inside",
#         "range": [
#             0.3844374096264756,
#             2.157330818153286
#         ],
#         "domain": [
#             0.006561679790026247,
#             0.9934383202099737
#         ],
#         "tickmode": "array",
#         "linecolor": "rgba(0, 0, 0, 1.000)",
#         "showgrid": true,
#         "title": "",
#         "mirror": true,
#         "tickangle": 0,
#         "showline": true,
#         "gridcolor": "rgba(0, 0, 0, 0.100)",
#         "titlefont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 15
#         },
#         "tickcolor": "rgb(0, 0, 0)",
#         "ticktext": [
#             "0.5",
#             "1.0",
#             "1.5",
#             "2.0"
#         ],
#         "zeroline": false,
#         "type": "-",
#         "tickfont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 11
#         },
#         "zerolinecolor": "rgba(0, 0, 0, 1.000)",
#         "anchor": "y1"
#     },
#     "paper_bgcolor": "rgba(255, 255, 255, 1.000)",
#     "annotations": [
#         {
#             "yanchor": "top",
#             "xanchor": "center",
#             "rotation": -0.0,
#             "y": 1.0,
#             "font": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "family": "sans-serif",
#                 "size": 20
#             },
#             "yref": "paper",
#             "showarrow": false,
#             "text": "barcode(VR(P))",
#             "xref": "paper",
#             "x": 0.5
#         }
#     ],
#     "height": 400,
#     "margin": {
#         "l": 0,
#         "b": 20,
#         "r": 0,
#         "t": 20
#     },
#     "plot_bgcolor": "rgba(255, 255, 255, 1.000)",
#     "yaxis": {
#         "showticklabels": true,
#         "gridwidth": 0.5,
#         "tickvals": [],
#         "visible": true,
#         "ticks": "inside",
#         "range": [
#             -1.0,
#             3.0
#         ],
#         "domain": [
#             0.07699037620297464,
#             0.9021762904636921
#         ],
#         "tickmode": "array",
#         "linecolor": "rgba(0, 0, 0, 1.000)",
#         "showgrid": true,
#         "title": "",
#         "mirror": true,
#         "tickangle": 0,
#         "showline": true,
#         "gridcolor": "rgba(0, 0, 0, 0.100)",
#         "titlefont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 15
#         },
#         "tickcolor": "rgb(0, 0, 0)",
#         "ticktext": [],
#         "zeroline": false,
#         "type": "-",
#         "tickfont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 11
#         },
#         "zerolinecolor": "rgba(0, 0, 0, 1.000)",
#         "anchor": "x1"
#     },
#     "width": 600
# }
# );
#     </script>
#
#     </body>
# </html>

# %% [markdown]
# <b>Explore extension results to `barcode(VR(Q))` </b>

# %%
p = return_extension_results_at_parameter(extension_Q);
# Out:
# *** Parameter key, value pair ***
# key: 1 parameter: 0.459276
# key: 2 parameter: 0.468910
# key: 3 parameter: 0.474519
# key: 4 parameter: 0.476031
# key: 5 parameter: 0.502393
# key: 6 parameter: 0.508495
# key: 7 parameter: 0.527879
# key: 8 parameter: 0.550888
# key: 9 parameter: 0.551174
# key: 10 parameter: 0.559679
# key: 11 parameter: 0.567726
# key: 12 parameter: 0.588657
# key: 13 parameter: 0.598662
# key: 14 parameter: 0.634918
# key: 15 parameter: 0.657946
# key: 16 parameter: 0.701574
# key: 17 parameter: 0.707338
# key: 18 parameter: 0.786701
# Select a key for parameter 1
# Selected parameter: 0.45927577558008886
#
# Baseline bars extension at selected parameter: [75, 84, 79]
#
# *** Offset bar extensions at selected parameter ***
# key: 1 offset bar extension: [64]
# key: 2 offset bar extension: [27]
# key: 3 offset bar extension: [73]
# key: 4 offset bar extension: [41]
# key: 5 offset bar extension: [35]
# key: 6 offset bar extension: [34, 28]
# key: 7 offset bar extension: [38]
# key: 8 offset bar extension: [40]
# key: 9 offset bar extension: [10]
# key: 10 offset bar extension: [39]
# key: 11 offset bar extension: [28, 30]
# key: 12 offset bar extension: [31]
# key: 13 offset bar extension: [65]
# key: 14 offset bar extension: [29]
# Select keys for offset bar extensions.
# Leave blank to select none.
# To select multiple keys, separate keys with space. ex) 1 2 3 :
# Baseline bars extension at selected parameter: [75, 84, 79]

# %%
plot(p, title ="barcode(VR(Q))")
# Out:
# <!DOCTYPE html>
# <html>
#     <head>
#         <title>Plots.jl</title>
#         <meta http-equiv="content-type" content="text/html; charset=UTF-8">
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#     </head>
#     <body>
#             <div id="93c98563-795c-40ac-9783-bfcf77467a2c" style="width:600px;height:400px;"></div>
#     <script>
#     PLOT = document.getElementById('93c98563-795c-40ac-9783-bfcf77467a2c');
#     Plotly.plot(PLOT, [
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 18",
#             "class 18"
#         ],
#         "x": [
#             0.21302414593246224,
#             0.2671154473730644
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y1",
#         "zmin": null,
#         "legendgroup": "y1",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 1
#         },
#         "y": [
#             1.0,
#             1.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 19",
#             "class 19"
#         ],
#         "x": [
#             0.22172740066803362,
#             0.2599552513795967
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y2",
#         "zmin": null,
#         "legendgroup": "y2",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 1
#         },
#         "y": [
#             2.0,
#             2.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 20",
#             "class 20"
#         ],
#         "x": [
#             0.2743958714093529,
#             0.3171379470778279
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y3",
#         "zmin": null,
#         "legendgroup": "y3",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 1
#         },
#         "y": [
#             3.0,
#             3.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 21",
#             "class 21"
#         ],
#         "x": [
#             0.2790547929784377,
#             0.3536732582986236
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y4",
#         "zmin": null,
#         "legendgroup": "y4",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 1
#         },
#         "y": [
#             4.0,
#             4.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 22",
#             "class 22"
#         ],
#         "x": [
#             0.2825107123053771,
#             0.3859956505917918
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y5",
#         "zmin": null,
#         "legendgroup": "y5",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 1
#         },
#         "y": [
#             5.0,
#             5.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 1",
#             "class 1"
#         ],
#         "x": [
#             0.2949948158473116,
#             0.3141041129307108
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y6",
#         "zmin": null,
#         "legendgroup": "y6",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 1
#         },
#         "y": [
#             6.0,
#             6.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 2",
#             "class 2"
#         ],
#         "x": [
#             0.2981308007961632,
#             0.3250894598232143
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y7",
#         "zmin": null,
#         "legendgroup": "y7",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 1
#         },
#         "y": [
#             7.0,
#             7.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 3",
#             "class 3"
#         ],
#         "x": [
#             0.30471347657719033,
#             0.32835744427497654
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y8",
#         "zmin": null,
#         "legendgroup": "y8",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 1
#         },
#         "y": [
#             8.0,
#             8.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 23",
#             "class 23"
#         ],
#         "x": [
#             0.3123121780566123,
#             0.3288343265223455
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y9",
#         "zmin": null,
#         "legendgroup": "y9",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 1
#         },
#         "y": [
#             9.0,
#             9.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 73",
#             "class 73"
#         ],
#         "x": [
#             0.32970174881696496,
#             0.7131357543314455
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y10",
#         "zmin": null,
#         "legendgroup": "y10",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 1
#         },
#         "y": [
#             10.0,
#             10.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 24",
#             "class 24"
#         ],
#         "x": [
#             0.330754108802894,
#             0.3467417245519408
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y11",
#         "zmin": null,
#         "legendgroup": "y11",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.0

# %% [markdown]
# ## 4(c) All cycle extensions and bar extensions
# * We use the function `find_CE_BE_at_param()` to find all cycle extensions and bar extensions at a specific parameter.
# * Let `CE_param`, `BE_param` be the outputs of the function.
#     * `CE_param[i]` is the i-th cycle extension at given parameter.
#     * `BE_param[i]` is the bar extension of the corresponding cycle extension.
# * Note that one could use the function `find_CE_BE()` to find the cycle extensions and bar extensions at all parameters. For this particular example, the function takes a long time to complete.

# %% [markdown]
# ### 4(c) i. Extensions to `barcode(VR(P))`

# %%
# select parameter
param = extension_P["nontrivial_pY"][1]
CE_param, BE_param = find_CE_BE_at_param(extension_P, param);

# %% [markdown]
# <b> plot cycle extensions to `barcode(VR(P))`

# %%
@printf("number of cycle extensions at parameter %.4f : %i", param, length(CE_param))
# Out:
# number of cycle extensions at parameter 1.1447 : 1

# %%
# plot the cycle extension at selected parameter
p = plot_cycle_square_torus(P, Q, cycle = CE_param[0], cycle_loc = "P", title = "cycle extension",
                                P_markersize = 5, Q_markersize = 5; legend = false)
# Out:
# <!DOCTYPE html>
# <html>
#     <head>
#         <title>Plots.jl</title>
#         <meta http-equiv="content-type" content="text/html; charset=UTF-8">
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#     </head>
#     <body>
#             <div id="3cdacd2e-f9cd-4c60-8806-c6d07db4d661" style="width:600px;height:400px;"></div>
#     <script>
#     PLOT = document.getElementById('3cdacd2e-f9cd-4c60-8806-c6d07db4d661');
#     Plotly.plot(PLOT, [
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "x": [
#             1
#             2.9338730444091707,
#             4.371314847382558,
#             3.3260039509023955,
#             5.712746597844213,
#             2.996592108832107,
#             3.7708594666997315,
#             4.845247135777276,
#             5.536021307379741,
#             2.8025278596796976,
#             3.853259015174019,
#             1.2473013654908538,
#             0.5812795001485418,
#             3.508526399676272,
#             4.911486204483468,
#             1.1082456620891503,
#             5.691568264715149,
#             4.891296343302329,
#             4.893343442308227,
#             5.89571892256287,
#             4.4998942610745045,
#             2.5932786911101404,
#             0.5769071913990185,
#             4.807410504012685,
#             1.107296696652395,
#             4.821243438294209,
#             5.528477400834526,
#             2.8642078520301086,
#             2.9744124952172255,
#             4.448569479230991,
#             3.1486737312304283,
#             4.337761393499303,
#             4.160466503759243,
#             4.595170854227276,
#             3.1247259547353594,
#             0.6356476691338129,
#             5.48155934316255,
#             1.171210846280836,
#             3.831942785273644,
#             4.181507090623986,
#             4.7342917552799575,
#             2.684826869864545,
#             5.314648118319865,
#             1.200677816635204,
#             3.0866183605960655,
#             5.462320061426911,
#             5.0599528436208745,
#             4.616566608387848,
#             5.141464905620005,
#             4.808765855006578,
#             0.12688153594002038,
#             1.850627552350616,
#             3.2300709963124064,
#             0.7177018428848316,
#             4.310550761906158,
#             2.934334853217976,
#             4.631698243017389,
#             1.6857255692608653,
#             5.112904979739172,
#             1.1999731489730714,
#             4.893758871263015,
#             2.3137975056377322,
#             1.2361111958106583,
#             1.8372346911961301,
#             3.485565890884082,
#             5.773007470615817,
#             4.059816474351488,
#             1.902918954803756,
#             1.1498674197548693,
#             2.198726193678424,
#             0.49247969918646634,
#             5.911859083161256,
#             3.655169539300373,
#             5.178370711863971,
#             3.1736016120141337,
#             2.9199862730047723,
#             0.764314187

# %% [markdown]
# Plot the <b>bar extensions</b> at given parameter.
# * Select a cycle extension
# * Find and plot the corresponding bar extensions

# %%
# select parameter 
@printf("number of cycle extensions at parameter %.4f : %i", param, length(CE_param))
# Out:
# number of cycle extensions at parameter 1.1447 : 1

# %%
# select cycle extension 
y= 0

# find the corresponding bar extension
be = BE_param[y]

# plot the bar extension
barcode_VR_P = barcode(VR_P, dim = dim)
p = plot_barcode(barcode_VR_P, title = "selected bar extension to barcode(VR(P))", lw = 6, selected_bars = be, epsilon= param, v_line = [param])
plot(p, size = (500, 300))
# Out:
# <!DOCTYPE html>
# <html>
#     <head>
#         <title>Plots.jl</title>
#         <meta http-equiv="content-type" content="text/html; charset=UTF-8">
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#     </head>
#     <body>
#             <div id="ee313b75-4c09-42dd-b66a-4ad1c223dc6d" style="width:500px;height:300px;"></div>
#     <script>
#     PLOT = document.getElementById('ee313b75-4c09-42dd-b66a-4ad1c223dc6d');
#     Plotly.plot(PLOT, [
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 1",
#             "class 1"
#         ],
#         "x": [
#             0.43461363816968723,
#             0.4624602682545485
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y1",
#         "zmin": null,
#         "legendgroup": "y1",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 6
#         },
#         "y": [
#             1.0,
#             1.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 2",
#             "class 2"
#         ],
#         "x": [
#             1.1447269023005358,
#             1.1447269023005358
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y2",
#         "zmin": null,
#         "legendgroup": "y2",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 6
#         },
#         "y": [
#             2.0,
#             2.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 2",
#             "class 2"
#         ],
#         "x": [
#             1.1447269023005358,
#             2.1071545896100745
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y3",
#         "zmin": null,
#         "legendgroup": "y3",
#         "zmax": null,
#         "line": {
#             "color": "rgba(238, 18, 137, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 6
#         },
#         "y": [
#             2.0,
#             2.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "x": [
#             1.1447269023005358,
#             1.1447269023005358
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y4",
#         "zmin": null,
#         "legendgroup": "y4",
#         "zmax": null,
#         "line": {
#             "color": "rgba(255, 0, 0, 1.000)",
#             "shape": "linear",
#             "dash": "dot",
#             "width": 1
#         },
#         "y": [
#             -401.0,
#             403.0
#         ],
#         "type": "scatter"
#     }
# ]
# , {
#     "showlegend": false,
#     "xaxis": {
#         "showticklabels": true,
#         "gridwidth": 0.5,
#         "tickvals": [
#             0.5,
#             1.0,
#             1.5,
#             2.0
#         ],
#         "visible": true,
#         "ticks": "inside",
#         "range": [
#             0.3844374096264756,
#             2.157330818153286
#         ],
#         "domain": [
#             0.007874015748031496,
#             0.9921259842519685
#         ],
#         "tickmode": "array",
#         "linecolor": "rgba(0, 0, 0, 1.000)",
#         "showgrid": true,
#         "title": "",
#         "mirror": true,
#         "tickangle": 0,
#         "showline": true,
#         "gridcolor": "rgba(0, 0, 0, 0.100)",
#         "titlefont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 15
#         },
#         "tickcolor": "rgb(0, 0, 0)",
#         "ticktext": [
#             "0.5",
#             "1.0",
#             "1.5",
#             "2.0"
#         ],
#         "zeroline": false,
#         "type": "-",
#         "tickfont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 11
#         },
#         "zerolinecolor": "rgba(0, 0, 0, 1.000)",
#         "anchor": "y1"
#     },
#     "paper_bgcolor": "rgba(255, 255, 255, 1.000)",
#     "annotations": [
#         {
#             "yanchor": "top",
#             "xanchor": "center",
#             "rotation": -0.0,
#             "y": 1.0,
#             "font": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "family": "sans-serif",
#                 "size": 20
#             },
#             "yref": "paper",
#             "showarrow": false,
#             "text": "selected bar extension to barcode(VR(P))",
#             "xref": "paper",
#             "x": 0.5
#         }
#     ],
#     "height": 300,
#     "margin": {
#         "l": 0,
#         "b": 20,
#         "r": 0,
#         "t": 20
#     },
#     "plot_bgcolor": "rgba(255, 255, 255, 1.000)",
#     "yaxis": {
#         "showticklabels": true,
#         "gridwidth": 0.5,
#         "tickvals": [],
#         "visible": true,
#         "ticks": "inside",
#         "range": [
#             -1.0,
#             3.0
#         ],
#         "domain": [
#             0.10265383493729952,
#             0.8695683872849228
#         ],
#         "tickmode": "array",
#         "linecolor": "rgba(0, 0, 0, 1.000)",
#         "showgrid": true,
#         "title": "",
#         "mirror": true,
#         "tickangle": 0,
#         "showline": true,
#         "gridcolor": "rgba(0, 0, 0, 0.100)",
#         "titlefont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 15
#         },
#         "tickcolor": "rgb(0, 0, 0)",
#         "ticktext": [],
#         "zeroline": false,
#         "type": "-",
#         "tickfont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 11
#         },
#         "zerolinecolor": "rgba(0, 0, 0, 1.000)",
#         "anchor": "x1"
#     },
#     "width": 500
# }
# );
#     </script>
#
#     </body>
# </html>

# %% [markdown]
# ### 4(c) ii. Extensions to `barcode(VR(Q))`

# %%
# select parameter
param = extension_Q["nontrivial_pY"][1]
CE_param, BE_param = find_CE_BE_at_param(extension_Q, param);

# %% [markdown]
# <b> plot cycle extensions to `barcode(VR(Q))`</b>

# %%
@printf("number of cycle extensions at parameter %.4f : %i", param, length(C
#             2.5719388746927425,
#             0.8667377024931007,
#             4.0114993467946345,
#             4.788865904962965,
#             0.2579170868407646,
#             4.404943815338161,
#             1.1917100097972093,
#             2.0926904594247984,
#             1.6457293146731808,
#             4.551302025664781,
#             3.1813267530830402,
#             5.222681706064723,
#             2.6555719947467926,
#             3.780193885302952,
#             2.2629944216681217,
#             4.512521730333964,
#             0.669016815546905,
#             4.888896862733852,
#             2.5827840640396666,
#             2.6514606863063066,
#             3.86564520130041,
#             5.0673510679066425,
#             1.7528110763329878,
#             1.7458690105818484,
#             2.2655463453606592,
#             2.6429718495579415,
#             2.9338730444091707,
#             4.371314847382558,
#             3.3260039509023955,
#             5.712746597844213,
#             2.996592108832107,
#             3.7708594666997315,
#             4.845247135777276,
#             5.536021307379741,
#             2.8025278596796976,
#             3.853259015174019,
#             1.2473013654908538,
#             0.5812795001485418,
#             3.508526399676272,
#             4.911486204483468,
#             1.1082456620891503,
#             5.691568264715149,
#             4.891296343302329,
#             4.893343442308227,
#             5.89571892256287,
#             4.4998942610745045,
#             2.5932786911101404,
#             0.5769071913990185,
#             4.807410504012685,
#             1.107296696652395,
#             4.821243438294209,
#             5.528477400834526,
#             2.8642078520301086,
#             2.9744124952172255,
#             4.448569479230991,
#             3.1486737312304283,
#             4.337761393499303,
#             4.160466503759243,
#             4.595170854227276,
#             3.1247259547353594,
#             0.6356476691338129,
#             5.48155934316255,
#             1.171210846280836,
#             3.831942785273644,
#             4.181507090623986,
#             4.7342917552799575,
#             2.684826869864545,
#             5.314648118319865,
#             1.200677816635204,
#             3.0866183605960655,
#             5.462320061426911,
#             5.0599528436208745,
#             4.616566608387848,
#             5.141464905620005,
#             4.808765855006578,
#             0.12688153594002038,
#             1.850627552350616,
#             3.2300709963124064,
#             0.7177018428848316,
#             4.310550761906158,
#             2.934334853217976,
#             4.631698243017389,
#             1.6857255692608653,
#             5.112904979739172,
#             1.1999731489730714,
#             4.893758871263015,
#             2.3137975056377322,
#             1.2361111958106583,
#             1.8372346911961301,
#             3.485565890884082,
#             5.773007470615817,
#             4.059816474351488,
#             1.902918954803756,
#             1.1498674197548693,
#             2.198726193678424,
#             0.49247969918646634,
#             5.911859083161256,
#             3.655169539300373,
#             5.178370711863971,
#             3.1736016120141337,
#             2.9199862730047723,
#             0.764314187

# %% [markdown]
# Plot the <b>bar extensions</b> at given parameter.
# * Select a cycle extension
# * Find and plot the corresponding bar extensions

# %%
# select parameter 
@printf("number of cycle extensions at parameter %.4f : %i", param, length(CE_param))
# Out:
# number of cycle extensions at parameter 0.4593 : 16384

# %%
# select cycle extension 
y= 0

# find the corresponding bar extension
be = BE_param[y]

# plot the bar extension
barcode_VR_Q = barcode(VR_Q, dim = dim)
p = plot_barcode(barcode_VR_Q, title = "selected bar extension to barcode(VR(Q))", lw = 2, selected_bars = be, epsilon= param, v_line = [param])
plot(p, size = (500, 300))
# Out:
# <!DOCTYPE html>
# <html>
#     <head>
#         <title>Plots.jl</title>
#         <meta http-equiv="content-type" content="text/html; charset=UTF-8">
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#     </head>
#     <body>
#             <div id="1dac58e1-dfc1-4e8e-b2e5-68cb3530d2b5" style="width:500px;height:300px;"></div>
#     <script>
#     PLOT = document.getElementById('1dac58e1-dfc1-4e8e-b2e5-68cb3530d2b5');
#     Plotly.plot(PLOT, [
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 18",
#             "class 18"
#         ],
#         "x": [
#             0.21302414593246224,
#             0.2671154473730644
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y1",
#         "zmin": null,
#         "legendgroup": "y1",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 2
#         },
#         "y": [
#             1.0,
#             1.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 19",
#             "class 19"
#         ],
#         "x": [
#             0.22172740066803362,
#             0.2599552513795967
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y2",
#         "zmin": null,
#         "legendgroup": "y2",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 2
#         },
#         "y": [
#             2.0,
#             2.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 20",
#             "class 20"
#         ],
#         "x": [
#             0.2743958714093529,
#             0.3171379470778279
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y3",
#         "zmin": null,
#         "legendgroup": "y3",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 2
#         },
#         "y": [
#             3.0,
#             3.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 21",
#             "class 21"
#         ],
#         "x": [
#             0.2790547929784377,
#             0.3536732582986236
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y4",
#         "zmin": null,
#         "legendgroup": "y4",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 2
#         },
#         "y": [
#             4.0,
#             4.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 22",
#             "class 22"
#         ],
#         "x": [
#             0.2825107123053771,
#             0.3859956505917918
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y5",
#         "zmin": null,
#         "legendgroup": "y5",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 2
#         },
#         "y": [
#             5.0,
#             5.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 1",
#             "class 1"
#         ],
#         "x": [
#             0.2949948158473116,
#             0.3141041129307108
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y6",
#         "zmin": null,
#         "legendgroup": "y6",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 2
#         },
#         "y": [
#             6.0,
#             6.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 2",
#             "class 2"
#         ],
#         "x": [
#             0.2981308007961632,
#             0.3250894598232143
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y7",
#         "zmin": null,
#         "legendgroup": "y7",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 2
#         },
#         "y": [
#             7.0,
#             7.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 3",
#             "class 3"
#         ],
#         "x": [
#             0.30471347657719033,
#             0.32835744427497654
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y8",
#         "zmin": null,
#         "legendgroup": "y8",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 2
#         },
#         "y": [
#             8.0,
#             8.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 23",
#             "class 23"
#         ],
#         "x": [
#             0.3123121780566123,
#             0.3288343265223455
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y9",
#         "zmin": null,
#         "legendgroup": "y9",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 2
#         },
#         "y": [
#             9.0,
#             9.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 73",
#             "class 73"
#         ],
#         "x": [
#             0.32970174881696496,
#             0.7131357543314455
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y10",
#         "zmin": null,
#         "legendgroup": "y10",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 2
#         },
#         "y": [
#             10.0,
#             10.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 24",
#             "class 24"
#         ],
#         "x": [
#             0.330754108802894,
#             0.3467417245519408
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y11",
#         "zmin": null,
#         "legendgroup": "y11",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.0

# %% [markdown]
# # 5. Explore the bar extension result under alternative interval decompositions of `C_VR`
# * Up to this point, the bar extension result has been obtained for some fixed interval decompositions of `barcode(VR(P))` and `barcode(VR(Q))`. In particular, we used the default interval decomposition that is used by Eirene.
# * In this section, we present various functions that allow us to find the full bar extensions under all possible interval decompositions. The goal of this section is to explore $S(\tau, X_P^{\bullet})$  and $S(\tau', X^\bullet_Q)$ from Algorithm 7 of paper. We'll refer to this set as <b>alternative bar extensions</b> since these arise from alternative choices of the interval decompositions.
# * We present three different methods for exploring the collection of alternative bar extensions. The appropriate tool depends on the sizes of the barcodes of the auxiliary filtration and the target filtration.
# * From the bar-to-bars extension method from $W^{\bullet}_{P,Q}$ to $X^\bullet_P$.
#     * Let $p_Y^P$ denote the collection of parameters.
#     * let $\mathfrak{E}_{\ell}^P$ denote the collection of cycle extensions at parameter $\ell$
#     * Let $L_Y^P$ denote the collection of matrices (Algorithm 2 step (5)(b)(ii).
# * From the bar-to-bars extension method from $W^\bullet_{Q,P}$ to $X^\bullet_Q$, let $p_Y^Q$, $\mathfrak{E}_{\ell}^Q$ and $L_Y^Q$ denote the analogous collections.
#
# 1. Find all alternative bar extensions for all parameters.
#     * This is recommended for data with small barcodes.
#     * This finds the full $S(\tau, X^\bullet_P) = \{ S^{\mathcal{D} \circ L^{-1}}_{[y]} | \ell \in p^P_Y, [y] \in \mathfrak{E}^P_{\ell}, L \in L^P_Y \}$ and $S(\tau', X^\bullet_Q) = \{ S^{\mathcal{D} \circ L^{-1}}_{[y]} | \ell \in p^Q_Y, [y] \in \mathfrak{E}^Q_{\ell}, L \in L^Q_Y \}$ from Algorithm 7.
# 2. Find alternative bar extensions at specific parameters.
#     * This is recommended for data with medium size barcodes.
#     * Given a parameter $\ell$, this method finds $S(\tau, X^\bullet_P; \ell) = \{ S^{\mathcal{D} \circ L^{-1}}_{[y]} | [y] \in \mathfrak{E}^P_{\ell}, L \in L^P_Y \}$ and $S(\tau', X^\bullet_Q; \ell) = \{ S^{\mathcal{D} \circ L^{-1}}_{[y]} | [y] \in \mathfrak{E}^Q_{\ell}, L \in L^Q_Y \}$.
# 3. Find alternative bar extensions of a specific bar extension.
#     * This is recommended for data with large size barcodes.
#     * Given a selected parameter $\ell$ and cycle extension $[y] \in \mathfrak{E}^P_{\ell}$, this method finds $\{S^{\mathcal{D} \circ L^{-1}}_{[y]} | L \in L^P_Y \}$. Similarly, given a selected parameter $\ell$ and cycle extension $[y] \in \mathfrak{E}^Q_{\ell}$, this method finds $\{S^{\mathcal{D} \circ L^{-1}}_{[y]} | L \in L^Q_Y \}$.
#
# For this example, we'll implement method 3 due to the large number of bars `barcode(VR(Q))`. Depending on the selected parameter, the function `find_alternative_bar_extension()` can lead to an out of memory error. This will happen when a user selects a parameter at which there are numerous bars in the barcode.
#
# For example implementations of methods 1 and 2, see notebook `EXAMPLE_EXTENSION_VR_VR.ipynb`

# %% [markdown]
# ## 5 i. Find alternative bar extensions of a specific bar extension to `barcode(VR(P))`

# %%
# select a parameter and bar extension
p = return_extension_results_at_parameter(extension_P)
# Out:
# *** Parameter key, value pair ***
# key: 1 parameter: 1.144727
# Select a key for parameter 1
# Selected parameter: 1.1447269023005358
#
# Baseline bars extension at selected parameter: [2]
#
# *** Offset bar extensions at selected parameter ***
# Select keys for offset bar extensions.
# Leave blank to select none.
# To select multiple keys, separate keys with space. ex) 1 2 3 :
# Baseline bars extension at selected parameter: [2]
# <!DOCTYPE html>
# <html>
#     <head>
#         <title>Plots.jl</title>
#         <meta http-equiv="content-type" content="text/html; charset=UTF-8">
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#     </head>
#     <body>
#             <div id="f06b3a94-25eb-47d1-bb7e-aba752e2ff9e" style="width:600px;height:400px;"></div>
#     <script>
#     PLOT = document.getElementById('f06b3a94-25eb-47d1-bb7e-aba752e2ff9e');
#     Plotly.plot(PLOT, [
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 1",
#             "class 1"
#         ],
#         "x": [
#             0.43461363816968723,
#             0.4624602682545485
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y1",
#         "zmin": null,
#         "legendgroup": "y1",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 1
#         },
#         "y": [
#             1.0,
#             1.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 2",
#             "class 2"
#         ],
#         "x": [
#             1.1447269023005358,
#             1.1447269023005358
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y2",
#         "zmin": null,
#         "legendgroup": "y2",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 1
#         },
#         "y": [
#             2.0,
#             2.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 2",
#             "class 2"
#         ],
#         "x": [
#             1.1447269023005358,
#             2.1071545896100745
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y3",
#         "zmin": null,
#         "legendgroup": "y3",
#         "zmax": null,
#         "line": {
#             "color": "rgba(238, 18, 137, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 1
#         },
#         "y": [
#             2.0,
#             2.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "x": [
#             1.1447269023005358,
#             1.1447269023005358
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y4",
#         "zmin": null,
#         "legendgroup": "y4",
#         "zmax": null,
#         "line": {
#             "color": "rgba(255, 0, 0, 1.000)",
#             "shape": "linear",
#             "dash": "dot",
#             "width": 1
#         },
#         "y": [
#             -401.0,
#             403.0
#         ],
#         "type": "scatter"
#     }
# ]
# , {
#     "showlegend": false,
#     "xaxis": {
#         "showticklabels": true,
#         "gridwidth": 0.5,
#         "tickvals": [
#             0.5,
#             1.0,
#             1.5,
#             2.0
#         ],
#         "visible": true,
#         "ticks": "inside",
#         "range": [
#             0.3844374096264756,
#             2.157330818153286
#         ],
#         "domain": [
#             0.006561679790026247,
#             0.9934383202099737
#         ],
#         "tickmode": "array",
#         "linecolor": "rgba(0, 0, 0, 1.000)",
#         "showgrid": true,
#         "title": "",
#         "mirror": true,
#         "tickangle": 0,
#         "showline": true,
#         "gridcolor": "rgba(0, 0, 0, 0.100)",
#         "titlefont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 15
#         },
#         "tickcolor": "rgb(0, 0, 0)",
#         "ticktext": [
#             "0.5",
#             "1.0",
#             "1.5",
#             "2.0"
#         ],
#         "zeroline": false,
#         "type": "-",
#         "tickfont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 11
#         },
#         "zerolinecolor": "rgba(0, 0, 0, 1.000)",
#         "anchor": "y1"
#     },
#     "paper_bgcolor": "rgba(255, 255, 255, 1.000)",
#     "annotations": [
#         {
#             "yanchor": "top",
#             "xanchor": "center",
#             "rotation": -0.0,
#             "y": 1.0,
#             "font": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "family": "sans-serif",
#                 "size": 20
#             },
#             "yref": "paper",
#             "showarrow": false,
#             "text": "barcode(VR)",
#             "xref": "paper",
#             "x": 0.5
#         }
#     ],
#     "height": 400,
#     "margin": {
#         "l": 0,
#         "b": 20,
#         "r": 0,
#         "t": 20
#     },
#     "plot_bgcolor": "rgba(255, 255, 255, 1.000)",
#     "yaxis": {
#         "showticklabels": true,
#         "gridwidth": 0.5,
#         "tickvals": [],
#         "visible": true,
#         "ticks": "inside",
#         "range": [
#             -1.0,
#             3.0
#         ],
#         "domain": [
#             0.07699037620297464,
#             0.9021762904636921
#         ],
#         "tickmode": "array",
#         "linecolor": "rgba(0, 0, 0, 1.000)",
#         "showgrid": true,
#         "title": "",
#         "mirror": true,
#         "tickangle": 0,
#         "showline": true,
#         "gridcolor": "rgba(0, 0, 0, 0.100)",
#         "titlefont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 15
#         },
#         "tickcolor": "rgb(0, 0, 0)",
#         "ticktext": [],
#         "zeroline": false,
#         "type": "-",
#         "tickfont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 11
#         },
#         "zerolinecolor": "rgba(0, 0, 0, 1.000)",
#         "anchor": "x1"
#     },
#     "width": 600
# }
# );
#     </script>
#
#     </body>
# </html>

# %%
param = extension_P["nontrivial_pY"][1]
bar_ext = [2]
# Out:
# 1-element Array{Int64,1}:
#  2

# %%
# find alternative representations of the selected bar extension
alt_bar_ext = find_alternative_bar_extension(extension_P, param, bar_extension = bar_ext)
# Out:
# 1-element Array{Array{Int64,1},1}:
#  [2]

# %%
# plot one of the alternative bar extensions

# select an alternative bar extension
alt = alt_bar_ext[1]
barcode_Y = barcode(extension_P["C_VR"], dim = dim)
p =plot_barcode(barcode_Y, selected_bars = alt, lw = 3,
                    epsilon = param, v_line = [param],
                    title = "alternative bar extension")
plot(p)
# Out:
# <!DOCTYPE html>
# <html>
#     <head>
#         <title>Plots.jl</title>
#         <meta http-equiv="content-type" content="text/html; charset=UTF-8">
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#     </head>
#     <body>
#             <div id="c3b421ee-1dd0-4592-b316-a7c833d9a603" style="width:600px;height:400px;"></div>
#     <script>
#     PLOT = document.getElementById('c3b421ee-1dd0-4592-b316-a7c833d9a603');
#     Plotly.plot(PLOT, [
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 1",
#             "class 1"
#         ],
#         "x": [
#             0.43461363816968723,
#             0.4624602682545485
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y1",
#         "zmin": null,
#         "legendgroup": "y1",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             1.0,
#             1.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 2",
#             "class 2"
#         ],
#         "x": [
#             1.1447269023005358,
#             1.1447269023005358
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y2",
#         "zmin": null,
#         "legendgroup": "y2",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             2.0,
#             2.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 2",
#             "class 2"
#         ],
#         "x": [
#             1.1447269023005358,
#             2.1071545896100745
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y3",
#         "zmin": null,
#         "legendgroup": "y3",
#         "zmax": null,
#         "line": {
#             "color": "rgba(238, 18, 137, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             2.0,
#             2.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "x": [
#             1.1447269023005358,
#             1.1447269023005358
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y4",
#         "zmin": null,
#         "legendgroup": "y4",
#         "zmax": null,
#         "line": {
#             "color": "rgba(255, 0, 0, 1.000)",
#             "shape": "linear",
#             "dash": "dot",
#             "width": 1
#         },
#         "y": [
#             -401.0,
#             403.0
#         ],
#         "type": "scatter"
#     }
# ]
# , {
#     "showlegend": false,
#     "xaxis": {
#         "showticklabels": true,
#         "gridwidth": 0.5,
#         "tickvals": [
#             0.5,
#             1.0,
#             1.5,
#             2.0
#         ],
#         "visible": true,
#         "ticks": "inside",
#         "range": [
#             0.3844374096264756,
#             2.157330818153286
#         ],
#         "domain": [
#             0.006561679790026247,
#             0.9934383202099737
#         ],
#         "tickmode": "array",
#         "linecolor": "rgba(0, 0, 0, 1.000)",
#         "showgrid": true,
#         "title": "",
#         "mirror": true,
#         "tickangle": 0,
#         "showline": true,
#         "gridcolor": "rgba(0, 0, 0, 0.100)",
#         "titlefont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 15
#         },
#         "tickcolor": "rgb(0, 0, 0)",
#         "ticktext": [
#             "0.5",
#             "1.0",
#             "1.5",
#             "2.0"
#         ],
#         "zeroline": false,
#         "type": "-",
#         "tickfont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 11
#         },
#         "zerolinecolor": "rgba(0, 0, 0, 1.000)",
#         "anchor": "y1"
#     },
#     "paper_bgcolor": "rgba(255, 255, 255, 1.000)",
#     "annotations": [
#         {
#             "yanchor": "top",
#             "xanchor": "center",
#             "rotation": -0.0,
#             "y": 1.0,
#             "font": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "family": "sans-serif",
#                 "size": 20
#             },
#             "yref": "paper",
#             "showarrow": false,
#             "text": "alternative bar extension",
#             "xref": "paper",
#             "x": 0.5
#         }
#     ],
#     "height": 400,
#     "margin": {
#         "l": 0,
#         "b": 20,
#         "r": 0,
#         "t": 20
#     },
#     "plot_bgcolor": "rgba(255, 255, 255, 1.000)",
#     "yaxis": {
#         "showticklabels": true,
#         "gridwidth": 0.5,
#         "tickvals": [],
#         "visible": true,
#         "ticks": "inside",
#         "range": [
#             -1.0,
#             3.0
#         ],
#         "domain": [
#             0.07699037620297464,
#             0.9021762904636921
#         ],
#         "tickmode": "array",
#         "linecolor": "rgba(0, 0, 0, 1.000)",
#         "showgrid": true,
#         "title": "",
#         "mirror": true,
#         "tickangle": 0,
#         "showline": true,
#         "gridcolor": "rgba(0, 0, 0, 0.100)",
#         "titlefont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 15
#         },
#         "tickcolor": "rgb(0, 0, 0)",
#         "ticktext": [],
#         "zeroline": false,
#         "type": "-",
#         "tickfont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 11
#         },
#         "zerolinecolor": "rgba(0, 0, 0, 1.000)",
#         "anchor": "x1"
#     },
#     "width": 600
# }
# );
#     </script>
#
#     </body>
# </html>

# %% [markdown]
# In this case, there are no alternative intervals

# %% [markdown]
# ## 5 ii. Find alternative bar extensions of a specific bar extension to `barcode(VR(Q))`

# %%
# select a parameter and bar extension
p = return_extension_results_at_parameter(extension_Q)
# Out:
# *** Parameter key, value pair ***
# key: 1 parameter: 0.459276
# key: 2 parameter: 0.468910
# key: 3 parameter: 0.474519
# key: 4 parameter: 0.476031
# key: 5 parameter: 0.502393
# key: 6 parameter: 0.508495
# key: 7 parameter: 0.527879
# key: 8 parameter: 0.550888
# key: 9 parameter: 0.551174
# key: 10 parameter: 0.559679
# key: 11 parameter: 0.567726
# key: 12 parameter: 0.588657
# key: 13 parameter: 0.598662
# key: 14 parameter: 0.634918
# key: 15 parameter: 0.657946
# key: 16 parameter: 0.701574
# key: 17 parameter: 0.707338
# key: 18 parameter: 0.786701
# Select a key for parameter 1
# Selected parameter: 0.45927577558008886
#
# Baseline bars extension at selected parameter: [75, 84, 79]
#
# *** Offset bar extensions at selected parameter ***
# key: 1 offset bar extension: [64]
# key: 2 offset bar extension: [27]
# key: 3 offset bar extension: [73]
# key: 4 offset bar extension: [41]
# key: 5 offset bar extension: [35]
# key: 6 offset bar extension: [34, 28]
# key: 7 offset bar extension: [38]
# key: 8 offset bar extension: [40]
# key: 9 offset bar extension: [10]
# key: 10 offset bar extension: [39]
# key: 11 offset bar extension: [28, 30]
# key: 12 offset bar extension: [31]
# key: 13 offset bar extension: [65]
# key: 14 offset bar extension: [29]
# Select keys for offset bar extensions.
# Leave blank to select none.
# To select multiple keys, separate keys with space. ex) 1 2 3 :
# Baseline bars extension at selected parameter: [75, 84, 79]
# <!DOCTYPE html>
# <html>
#     <head>
#         <title>Plots.jl</title>
#         <meta http-equiv="content-type" content="text/html; charset=UTF-8">
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#     </head>
#     <body>
#             <div id="d92a0456-deae-4339-9bdc-64eafd1f40d9" style="width:600px;height:400px;"></div>
#     <script>
#     PLOT = document.getElementById('d92a0456-deae-4339-9bdc-64eafd1f40d9');
#     Plotly.plot(PLOT, [
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 18",
#             "class 18"
#         ],
#         "x": [
#             0.21302414593246224,
#             0.2671154473730644
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y1",
#         "zmin": null,
#         "legendgroup": "y1",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 1
#         },
#         "y": [
#             1.0,
#             1.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 19",
#             "class 19"
#         ],
#         "x": [
#             0.22172740066803362,
#             0.2599552513795967
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y2",
#         "zmin": null,
#         "legendgroup": "y2",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 1
#         },
#         "y": [
#             2.0,
#             2.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 20",
#             "class 20"
#         ],
#         "x": [
#             0.2743958714093529,
#             0.3171379470778279
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y3",
#         "zmin": null,
#         "legendgroup": "y3",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 1
#         },
#         "y": [
#             3.0,
#             3.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 21",
#             "class 21"
#         ],
#         "x": [
#             0.2790547929784377,
#             0.3536732582986236
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y4",
#         "zmin": null,
#         "legendgroup": "y4",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 1
#         },
#         "y": [
#             4.0,
#             4.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 22",
#             "class 22"
#         ],
#         "x": [
#             0.2825107123053771,
#             0.3859956505917918
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y5",
#         "zmin": null,
#         "legendgroup": "y5",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 1
#         },
#         "y": [
#             5.0,
#             5.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 1",
#             "class 1"
#         ],
#         "x": [
#             0.2949948158473116,
#             0.3141041129307108
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y6",
#         "zmin": null,
#         "legendgroup": "y6",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 1
#         },
#         "y": [
#             6.0,
#             6.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 2",
#             "class 2"
#         ],
#         "x": [
#             0.2981308007961632,
#             0.3250894598232143
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y7",
#         "zmin": null,
#         "legendgroup": "y7",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 1
#         },
#         "y": [
#             7.0,
#             7.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 3",
#             "class 3"
#         ],
#         "x": [
#             0.30471347657719033,
#             0.32835744427497654
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y8",
#         "zmin": null,
#         "legendgroup": "y8",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 1
#         },
#         "y": [
#             8.0,
#             8.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 23",
#             "class 23"
#         ],
#         "x": [
#             0.3123121780566123,
#             0.3288343265223455
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y9",
#         "zmin": null,
#         "legendgroup": "y9",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 1
#         },
#         "y": [
#             9.0,
#             9.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 73",
#             "class 73"
#         ],
#         "x": [
#             0.32970174881696496,
#             0.7131357543314455
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y10",
#         "zmin": null,
#         "legendgroup": "y10",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 1
#         },
#         "y": [
#             10.0,
#             10.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 24",
#             "class 24"
#         ],
#         "x": [
#             0.330754108802894,
#             0.3467417245519408
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y11",
#         "zmin": null,
#         "legendgroup": "y11",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.0

# %%
param = extension_Q["nontrivial_pY"][13]
bar_ext = [75, 84, 79];

# %%
# find alternative representations of the selected bar extension
alt_bar_ext = find_alternative_bar_extension(extension_Q, param, bar_extension = bar_ext)
# Out:
# 256-element Array{Array{Int64,1},1}:
#  [75, 79, 84]
#  [31, 75, 79, 84]
#  [36, 75, 79, 84]
#  [38, 75, 79, 84]
#  [64, 75, 79, 84]
#  [65, 75, 79, 84]
#  [66, 75, 79, 84]
#  [73, 75, 79, 84]
#  [74, 75, 79, 84]
#  [31, 36, 75, 79, 84]
#  [31, 38, 75, 79, 84]
#  [31, 64, 75, 79, 84]
#  [31, 65, 75, 79, 84]
#  ⋮
#  [36, 38, 65, 66, 73, 74, 75, 79, 84]
#  [36, 64, 65, 66, 73, 74, 75, 79, 84]
#  [38, 64, 65, 66, 73, 74, 75, 79, 84]
#  [31, 36, 38, 64, 65, 66, 73, 75, 79, 84]
#  [31, 36, 38, 64, 65, 66, 74, 75, 79, 84]
#  [31, 36, 38, 64, 65, 73, 74, 75, 79, 84]
#  [31, 36, 38, 64, 66, 73, 74, 75, 79, 84]
#  [31, 36, 38, 65, 66, 73, 74, 75, 79, 84]
#  [31, 36, 64, 65, 66, 73, 74, 75, 79, 84]
#  [31, 38, 64, 65, 66, 73, 74, 75, 79, 84]
#  [36, 38, 64, 65, 66, 73, 74, 75, 79, 84]
#  [31, 36, 38, 64, 65, 66, 73, 74, 75, 79, 84]

# %%
# plot one of the alternative bar extensions

# select an alternative bar extension
alt = alt_bar_ext[2]
barcode_Y = barcode(extension_Q["C_VR"], dim = dim)
p =plot_barcode(barcode_Y, selected_bars = alt, lw = 3,
                    epsilon = param, v_line = [param],
                    title = "alternative bar extension")
plot(p)
# Out:
# <!DOCTYPE html>
# <html>
#     <head>
#         <title>Plots.jl</title>
#         <meta http-equiv="content-type" content="text/html; charset=UTF-8">
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#     </head>
#     <body>
#             <div id="0477bb18-75ec-4a8a-8330-32ce4ec39088" style="width:600px;height:400px;"></div>
#     <script>
#     PLOT = document.getElementById('0477bb18-75ec-4a8a-8330-32ce4ec39088');
#     Plotly.plot(PLOT, [
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 18",
#             "class 18"
#         ],
#         "x": [
#             0.21302414593246224,
#             0.2671154473730644
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y1",
#         "zmin": null,
#         "legendgroup": "y1",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             1.0,
#             1.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 19",
#             "class 19"
#         ],
#         "x": [
#             0.22172740066803362,
#             0.2599552513795967
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y2",
#         "zmin": null,
#         "legendgroup": "y2",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             2.0,
#             2.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 20",
#             "class 20"
#         ],
#         "x": [
#             0.2743958714093529,
#             0.3171379470778279
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y3",
#         "zmin": null,
#         "legendgroup": "y3",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             3.0,
#             3.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 21",
#             "class 21"
#         ],
#         "x": [
#             0.2790547929784377,
#             0.3536732582986236
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y4",
#         "zmin": null,
#         "legendgroup": "y4",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             4.0,
#             4.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 22",
#             "class 22"
#         ],
#         "x": [
#             0.2825107123053771,
#             0.3859956505917918
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y5",
#         "zmin": null,
#         "legendgroup": "y5",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             5.0,
#             5.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 1",
#             "class 1"
#         ],
#         "x": [
#             0.2949948158473116,
#             0.3141041129307108
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y6",
#         "zmin": null,
#         "legendgroup": "y6",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             6.0,
#             6.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 2",
#             "class 2"
#         ],
#         "x": [
#             0.2981308007961632,
#             0.3250894598232143
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y7",
#         "zmin": null,
#         "legendgroup": "y7",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             7.0,
#             7.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 3",
#             "class 3"
#         ],
#         "x": [
#             0.30471347657719033,
#             0.32835744427497654
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y8",
#         "zmin": null,
#         "legendgroup": "y8",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             8.0,
#             8.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 23",
#             "class 23"
#         ],
#         "x": [
#             0.3123121780566123,
#             0.3288343265223455
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y9",
#         "zmin": null,
#         "legendgroup": "y9",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             9.0,
#             9.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 73",
#             "class 73"
#         ],
#         "x": [
#             0.32970174881696496,
#             0.7131357543314455
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y10",
#         "zmin": null,
#         "legendgroup": "y10",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             10.0,
#             10.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 24",
#             "class 24"
#         ],
#         "x": [
#             0.330754108802894,
#             0.3467417245519408
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y11",
#         "zmin": null,
#         "legendgroup": "y11",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.0
