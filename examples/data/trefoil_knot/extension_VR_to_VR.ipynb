# %% [markdown]
# # Example Extension Method: Vietoris Rips to Vietoris Rips
# * This notebook shows an application of the <b>bar-to-bars extension method</b> to compare barcodes obtained from two different Vietoris-Rips filtrations.
# * <b> Implementation </b>: Our function implements a component-wise bar-to-bars extension method with $\mathbb{F}_2$ coefficients. It assumes that all bars of barcodes have unique death times.
# * <b> Comparing VR to VR </b>: Given a point cloud `P`, let `D_Z, D_Y` be two distinct distance metrics on `P`. Let `Z` and `Y` be the two resulting Vietoris-Rips filtrations (corresponding to $Z^{\bullet}$ and $Y^{\bullet}$ in paper). Given a selected bar `Z_bar` of `barcode(Z)`, the extension method finds all representations in `barcode(Y)`.
# * <b> Example data</b>: We study how a topological feature in a point cloud is preserved during dimensionality reduction. In particular, we let `Z` denote the Vietoris-Rips filtration resulting from the original point cloud, and we let `Y` denote the Vietoris-Rips filtration resulting from the reduced-dimension point cloud.
# * <b> Contents </b>
#     1. Load points and visualize
#     2. Examine the two VR barcodes
#     3. Apply bar-to-bars extension method
#     4. Explore cycle extension & bar extension under fixed interval decomposition of `barcode(Y)`.
#     5. Explore alternative bar extensions under all possible interval decompositions of `barcode(Y)`.

# %%
using Revise
includet("../../../extension_method.jl")
# Out:
# HTML{String}("<script>\n// Immediately-invoked-function-expression to avoid global variables.\n(function() {\n    var warning_div = document.getElementById(\"webio-warning-18212017591414494155\");\n    var hide = function () {\n        var script = document.getElementById(\"webio-setup-9411465949107159699\");\n        var parent = script && script.parentElement;\n        var grandparent = parent && parent.parentElement;\n        if (grandparent) {\n            grandparent.style.display = \"none\";\n        }\n        warning_div.style.display = \"none\";\n    };\n    if (typeof Jupyter !== \"undefined\") {\n        console.log(\"WebIO detected Jupyter notebook environment.\");\n        // Jupyter notebook.\n        var extensions = (\n            Jupyter\n            && Jupyter.notebook.config.data\n            && Jupyter.notebook.config.data.load_extensions\n        );\n        if (extensions && extensions[\"webio-jupyter-notebook\"]) {\n            // Extension already loaded.\n            console.log(\"Jupyter WebIO nbextension detected; not loading ad-hoc.\");\n            hide();\n            return;\n        }\n    } else if (window.location.pathname.includes(\"/lab\")) {\n        // Guessing JupyterLa\n        console.log(\"Jupyter Lab detected; make sure the @webio/jupyter-lab-provider labextension is installed.\");\n        hide();\n        return;\n    }\n})();\n\n</script>\n<p\n    id=\"webio-warning-18212017591414494155\"\n    class=\"output_text output_stderr\"\n    style=\"padding: 1em; font-weight: bold;\"\n>\n    Unable to load WebIO. Please make sure WebIO works for your Jupyter client.\n    For troubleshooting, please see <a href=\"https://juliagizmos.github.io/WebIO.jl/latest/providers/ijulia/\">\n    the WebIO/IJulia documentation</a>.\n    <!-- TODO: link to installation docs. -->\n</p>\n")
# ┌ Warning: ORCA.jl has been deprecated and all savefig functionality
# │ has been implemented directly in PlotlyBase itself.
# │
# │ By implementing in PlotlyBase.jl, the savefig routines are automatically
# │ available to PlotlyJS.jl also.
# └ @ ORCA /opt/julia/packages/ORCA/U5XaN/src/ORCA.jl:8

# %%
using .ext
using Distances
using Eirene
using JLD
using Plots
using Printf

# %% [markdown]
# # 1. Load points and visualize
# * `P_original`: points sampled from a trefoil knot
# * `P_pca`: result of PCA into two dimensions
# * We'll use `P_original` and `P_pca` to come up with distance matrices `D_original` and `D_pca` on `P`

# %%
# load points 
P_original = load("points.jld2", "trefoil_knot")
P_pca = load("points_2D.jld", "points_2d");
# Out:
# ┌ Warning: JLD incorrectly extends FileIO functions (see FileIO documentation)
# └ @ FileIO /opt/julia/packages/FileIO/JA3Vl/src/loadsave.jl:215

# %%
# the original points were generated using the following code. 
# P_pca was obtained by 
"""
### Option 1 
# number of points
n = 200

# sample angles
t = rand(n) * 2 * π

# torus 
R1 = 2
R2 = 1

P_x = (R1 .+ R2 .* cos.(3 .* t) ).* cos.(2 .* t) 
P_y = (R1 .+ R2 .* cos.(3 .* t)) .* sin.(2 .* t) 
P_z = R2 .* sin.(3 .* t)  

P = cat(P_x, P_y, P_z, dims = 2);


### Option 2
# number of points
n = 200

# sample theta, phi
t = rand(n) * 2 * π

# coordinates
P_x = sin.(t) + 2 * sin.(2 * t)
P_y = cos.(t) - 2 * cos.(2 * t)
P_z = - sin.(3 * t);

P = cat(P_x, P_y, P_z, dims = 2)
"""

# %% [markdown]
# Plot original points in 3D

# %%
# plot points
scatter3d(P_original[:,1], P_original[:,2], P_original[:,3], label = "", xaxis = nothing, yaxis = nothing, zaxis = nothing)
# Out:
#     <script type="text/javascript">
#         requirejs(["https://cdn.plot.ly/plotly-latest.min.js"], function(p) {
#             window.Plotly = p
#         });
#     </script>
# <!DOCTYPE html>
# <html>
#     <head>
#         <title>Plots.jl</title>
#         <meta http-equiv="content-type" content="text/html; charset=UTF-8">
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#     </head>
#     <body>
#             <div id="94f77b26-fc34-4e45-8a92-4fd10e162902" style="width:600px;height:400px;"></div>
#     <script>
#     PLOT = document.getElementById('94f77b26-fc34-4e45-8a92-4fd10e162902');
#     Plotly.plot(PLOT, [
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "x": [
#             
#             -1.7500970788393768,
#             -0.7018229396735185,
#             -0.9193182135886306,
#             -1.0450634998899688,
#             -1.5040167684664811,
#             -2.1676252739859305,
#             0.28341649407126984,
#             -1.2187243085748105,
#             -2.2028539829976475,
#             -2.9480337559301297,
#             2.66658628579204,
#             0.3397401387901317,
#             1.3060080403148535,
#             0.2410444682396988,
#             -0.7309510430007885,
#             0.5376900678730081,
#             -1.117079430952803,
#             0.3999532098868646,
#             -2.439156869950244,
#             -1.5688571034017544,
#             -1.97078331411418,
#             -1.4186183930337353,
#             -1.4472493099530959,
#             -0.9493210719435209,
#             2.1810212879239192,
#             1.514995693210367,
#             1.0917599168006584,
#             1.6825985346761636,
#             1.0475108267263804,
#             -0.9062153776135788,
#             1.4814496616223838,
#             1.88027554028842,
#             -1.4518362104567082,
#             -2.352799176062824,
#             0.3766199829165974,
#             -0.8502636729534395,
#             -2.0427464720351862,
#             -0.5408913529449051,
#             -0.8415452350255855,
#             2.1155722498183436,
#             2.254019766551209,
#             2.0075363233911507,
#             -0.1550411995382707,
#             -0.023492168932493274,
#             1.4639625249401393,
#             -0.6617691877733594,
#             -0.7839509144502597,
#             -0.8865519999841641,
#             -2.5537243092591195,
#             0.49587577066201943,
#             -1.3970462390279192,
#             -0.9150552775996473,
#             -2.8755232078787927,
#             -2.868091334845265
#         ],
#         "showlegend": false,
#         "mode": "markers",
#         "name": "",
#         "zmin": null,
#         "legendgroup": "",
#         "marker": {
#             "symbol": "circle",
#             "color": "rgba(0, 154, 250, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 16
#         },
#         "zmax": null,
#         "y": [
#             -1.6014362594812266,
#             0.9008791728399415,
#             0.1868119271105137,
#             -1.5929828681967684,
#             -0.6590265800805387,
#             3.1750413263546706,
#             0.06518153978652022,
#             3.165362628675723,
#             -0.47339361619110953,
#             -1.8572154549217919,
#             -0.5313823650420624,
#             -0.5149536469352466,
#             1.3553212493089182,
#             -0.8238653403288091,
#             1.1644916920803308,
#             -1.5837971218953082,
#             -

# %% [markdown]
# # 2. Examine the two VR barcodes

# %% [markdown]
# * The extension method compares two filtrations built on the point cloud `P`.
# * Compute the following two distance matrices:
#     * `D_original`: Distance computed from `P_original`
#     * `D_pca`: Distance computed from `P_pca`
# * Consider the two resulting filtrations:
#     * `C_original`: Vietoris-Rips filtration on `D_original`
#     * `C_pca`: Vietoris-Rips filtration on `D_pca`

# %% [markdown]
# ## 2(a) Prepare distance matrices

# %%
D_original = pairwise(Euclidean(), P_original, P_original, dims = 1)
D_pca = pairwise(Euclidean(), P_pca, P_pca, dims = 1);

# %% [markdown]
# ## 2(b) Observe the two VR barcodes

# %%
# run Eirene
C_original = eirene(D_original)
C_pca = eirene(D_pca);

# specify dimension of interest
dim = 1

# compute barcodes
barcode_orig = barcode(C_original, dim = dim)
barcode_pca = barcode(C_pca, dim = dim)

# plot two barcodes
p1 = plot_barcode(barcode_orig, title = "barcode(C_original) in dim 1", lw = 3)
p2 = plot_barcode(barcode_pca, title = "barcode(C_PCA) in dim 1", lw = 3)
plot(p1, p2, layout = grid(2,1), size = (500, 500))
# Out:
# <!DOCTYPE html>
# <html>
#     <head>
#         <title>Plots.jl</title>
#         <meta http-equiv="content-type" content="text/html; charset=UTF-8">
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#     </head>
#     <body>
#             <div id="509f77b3-240a-428f-ac84-fcb0daebffd1" style="width:500px;height:500px;"></div>
#     <script>
#     PLOT = document.getElementById('509f77b3-240a-428f-ac84-fcb0daebffd1');
#     Plotly.plot(PLOT, [
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 31",
#             "class 31"
#         ],
#         "x": [
#             1.1268349401575317,
#             2.0088499745851633
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y1",
#         "zmin": null,
#         "legendgroup": "y1",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             1.0,
#             1.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 29",
#             "class 29"
#         ],
#         "x": [
#             1.668279155975215,
#             2.005391316610963
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y2",
#         "zmin": null,
#         "legendgroup": "y2",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             2.0,
#             2.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 26",
#             "class 26"
#         ],
#         "x": [
#             1.6683213191081443,
#             2.0021248821901163
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y3",
#         "zmin": null,
#         "legendgroup": "y3",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             3.0,
#             3.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 2",
#             "class 2"
#         ],
#         "x": [
#             1.6687692763592918,
#             1.6693401654342708
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y4",
#         "zmin": null,
#         "legendgroup": "y4",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             4.0,
#             4.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 3",
#             "class 3"
#         ],
#         "x": [
#             1.6688037209621396,
#             1.752884113223493
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y5",
#         "zmin": null,
#         "legendgroup": "y5",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             5.0,
#             5.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 4",
#             "class 4"
#         ],
#         "x": [
#             2.000000064785547,
#             2.0000872550602784
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y6",
#         "zmin": null,
#         "legendgroup": "y6",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             6.0,
#             6.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 21",
#             "class 21"
#         ],
#         "x": [
#             2.000001799879294,
#             2.000602944288297
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y7",
#         "zmin": null,
#         "legendgroup": "y7",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             7.0,
#             7.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 30",
#             "class 30"
#         ],
#         "x": [
#             2.000002583620001,
#             2.0056753809735133
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y8",
#         "zmin": null,
#         "legendgroup": "y8",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             8.0,
#             8.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 22",
#             "class 22"
#         ],
#         "x": [
#             2.0000028349322867,
#             2.001391453557193
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y9",
#         "zmin": null,
#         "legendgroup": "y9",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             9.0,
#             9.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 5",
#             "class 5"
#         ],
#         "x": [
#             2.000003539868851,
#             2.0003493623913045
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y10",
#         "zmin": null,
#         "legendgroup": "y10",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             10.0,
#             10.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 6",
#             "class 6"
#         ],
#         "x": [
#             2.0000082542361843,
#             2.00001529149983
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y11",
#         "zmin": null,
#         "legendgroup": "y11",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "

# %%
class2 = classrep(C_pca, dim = 1, class = 2)
class3 = classrep(C_pca, dim = 1, class = 3)
class4 = classrep(C_pca, dim = 1, class = 4)
class5 = classrep(C_pca, dim = 1, class = 5)

class2 = [class2[:,i] for i in 1:size(class2,2)]
class3 = [class3[:,i] for i in 1:size(class3,2)]
class4 = [class4[:,i] for i in 1:size(class4,2)]
class5 = [class5[:,i] for i in 1:size(class5,2)];

# %%
plot_cycle_single(transpose(P_pca), cycle = class2)
# Out:
# <!DOCTYPE html>
# <html>
#     <head>
#         <title>Plots.jl</title>
#         <meta http-equiv="content-type" content="text/html; charset=UTF-8">
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#     </head>
#     <body>
#             <div id="03393320-1ba8-4c13-b4d3-e1b041d120ae" style="width:600px;height:400px;"></div>
#     <script>
#     PLOT = document.getElementById('03393320-1ba8-4c13-b4d3-e1b041d120ae');
#     Plotly.plot(PLOT, [
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "x": [
#             -0.5559007311204965,
#             -1.446856949565712,
#             -1.1217547872110005,
#             2.371748120704803,
#             -2.895933035069496,
#             0.3295355045526856,
#             -1.0500486987385933,
#             0.048884233152449996,
#             -2.938066020469176,
#             -0.32925516708745906,
#             2.669240436276489,
#             0.682853211911372,
#             -0.25434315883647446,
#             -2.8399706812638903,
#             0.5191632461718072,
#             -2.261227815554792,
#             2.5054150430637163,
#             1.9226060112829397,
#             0.4427632478220325,
#             -2.8354761893689093,
#             -0.4102812454481123,
#             0.26998874180723537,
#             -0.9444745037026557,
#             -1.0847729750435553,
#             2.639029515433066,
#             -0.12374633835829132,
#             -0.9549360856386141,
#             -1.4630989232830143,
#             -1.1093931115628466,
#             1.3943253297746079,
#             -0.08853128556154531,
#             1.718026032809438,
#             2.503954067876427,
#             1.6447039883790937,
#             -1.714183253372809,
#             1.303021051778658,
#             -1.0721611543164256,
#             0.42800170135270516,
#             -1.7709682540028893,
#             2.1030774292850887,
#             -0.961893664542826,
#             0.10642380684337177,
#             1.3557504101374747,
#             -0.905407555823632,
#             0.3005476091255259,
#             2.3461269110059204,
#             1.0755765682504752,
#             0.7831709823694797,
#             -1.1207195309466391,
#             -1.4929216996507702,
#             0.5723523078363658,
#             1.2293637578091345,
#             -1.0464607924083094,
#             0.35099540789818606,
#             -0.9542643730969617,
#             1.9372696109560295,
#             1.6746491732611797,
#             -0.8020586767331093,
#             -2.485018981121557,
#             -2.0287195126859765,
#             -1.495375553713605,
#             0.7789916922875777,
#             2.324653371822515,
#             1.3537490688797589,
#             0.09763229103599382,
#             1.4111709810477062,
#             1.8611430900922714,
#             0.40344297112856586,
#             0.9458609898344696,
#             2.590489163721292,
#             -2.912131488350591,
#             -2.2028539829976475,
#             -2.9480337559301297,
#             2.66658628579204,
#             0.3397401387901317,
#             1.3060080403148535,
#             0.2410444682396988,
#             -0.7309510430007885,
#             0.5376900678730081,
#             -1.117079430952803,
#             0.3999532098868646,
#             -2.439156869950244,
#             -1.5688571034017544,
#             -1.97078331411418,
#             -1.4186183930337353,
#             -1.4472493099530959,
#             -0.9493210719435209,
#             2.1810212879239192,
#             1.514995693210367,
#             1.0917599168006584,
#             1.6825985346761636,
#             1.0475108267263804,
#             -0.9062153776135788,
#             1.4814496616223838,
#             1.88027554028842,
#             -1.4518362104567082,
#             -2.352799176062824,
#             0.3766199829165974,
#             -0.8502636729534395,
#             -2.0427464720351862,
#             -0.5408913529449051,
#             -0.8415452350255855,
#             2.1155722498183436,
#             2.254019766551209,
#             2.0075363233911507,
#             -0.1550411995382707,
#             -0.023492168932493274,
#             1.4639625249401393,
#             -0.6617691877733594,
#             -0.7839509144502597,
#             -0.8865519999841641,
#             -2.5537243092591195,
#             0.49587577066201943,
#             -1.3970462390279192,
#             -0.9150552775996473,
#             -2.8755232078787927,
#             -2.868091334845265
#         ],
#         "showlegend": false,
#         "mode": "markers",
#         "name": "",
#         "zmin": null,
#         "legendgroup": "",
#         "marker": {
#             "symbol": "circle",
#             "color": "rgba(0, 154, 250, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 8
#         },
#         "zmax": null,
#         "y": [
#             -1.6014362594812266,
#             0.9008791728399415,
#             0.1868119271105137,
#             -1.5929828681967684,
#             -0.6590265800805387,
#             3.1750413263546706,
#             0.06518153978652022,
#             3.165362628675723,
#             -0.47339361619110953,
#             -1.8572154549217919,
#             -0.5313823650420624,
#             -0.5149536469352466,
#             1.3553212493089182,
#             -0.8238653403288091,
#             1.1644916920803308,
#             -1.5837971218953082,
#             -1

# %% [markdown]
# We'll now use the bar-to-bars extension method to understand how the long bar in `barcode(C_original)` is represented in `barcode(C_PCA)`.

# %% [markdown]
# # 3. Apply bar-to-bars extension method

# %% [markdown]
# <b> Hover over the above barcode to select interval of interest. </b>
# * We selected bar 31 (the long bar) in the top barcode.
# * Let `Z` denote the filtration that contains the selected bar. In this case, `Z` refers to the Vietoris-Rips filtration on the original point cloud (`C_original`).
# * Let `Y` denote the other filtration. In this case, `Y` refers to the Vietoris-Rips filtration on the reduced-dimension point cloud (`C_Y`).
# * The extension method will then find all representations of bar 34 in the barcode of PCA.
#
# <b> Using the bar-to-bars extension method </b>
# * Since we are implementing the bar-to-bars extension method to compare two VR filtrations, we'll use the function `run_extension_VR_to_VR_bar`.

# %%
# set variables
VR_Z = C_original
D_Z = D_original
VR_Y = C_pca
D_Y = D_pca
Z_bar = 31

# run bar-to-bars extension method
extension = run_extension_VR_to_VR_bar(C_Z = VR_Z,
                                       D_Z = D_Z,
                                       C_Y = VR_Y,
                                       D_Y = D_Y,
                                       Z_bar = Z_bar);

# %% [markdown]
# # 4. Explore the cycle extension & bar extension under fixed interval decomposition of `C_Y`
# * As mentioned in "code_details.pdf", the `run_extension_VR_to_VR_bar()` presents the component-wise cycle and bar extensions. This section illustrates the use of various functions to explore all cycle extension & bar extensions.
# * For bar extensions, we only consider the result under a fixed interval decomposition of $PH_k(Y^{\bullet})$.
# * This section is organized as the following.
#     * (a) Plotting the parameters `p_Y`.
#     * (b) Interactively exploring the baseline and offset bar-extensions at various parameters.
#     * (c) Finding all cycle extensions and bar extensions (non-interactive).
# * Both subsection (b) and (c) illustrate how one may understand the bar-extensions. If your data contains large number of bars in the barcode of `C_auxiliary_filtration` and `C_Y`, then implementing the non-interactive method may take a while.

# %% [markdown]
# ## 4(a) Plot all nontrivial `p_Y`

# %% [markdown]
# Plot all values of `extension["nontrivial_pY"]` on the target barcode $\text{BC}_k(Y^{\bullet})$.

# %%
plot_pY(extension, lw = 4)
# Out:
# <!DOCTYPE html>
# <html>
#     <head>
#         <title>Plots.jl</title>
#         <meta http-equiv="content-type" content="text/html; charset=UTF-8">
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#     </head>
#     <body>
#             <div id="a4e16153-6e99-4e44-a2fc-0de4f4987757" style="width:500px;height:400px;"></div>
#     <script>
#     PLOT = document.getElementById('a4e16153-6e99-4e44-a2fc-0de4f4987757');
#     Plotly.plot(PLOT, [
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 1",
#             "class 1"
#         ],
#         "x": [
#             0.32411292660404395,
#             0.35263527349737434
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y1",
#         "zmin": null,
#         "legendgroup": "y1",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 4
#         },
#         "y": [
#             1.0,
#             1.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 2",
#             "class 2"
#         ],
#         "x": [
#             0.4538696366298648,
#             1.9611529246595443
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y2",
#         "zmin": null,
#         "legendgroup": "y2",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 4
#         },
#         "y": [
#             2.0,
#             2.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 3",
#             "class 3"
#         ],
#         "x": [
#             0.5729492961514668,
#             1.7512260110812434
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y3",
#         "zmin": null,
#         "legendgroup": "y3",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 4
#         },
#         "y": [
#             3.0,
#             3.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 4",
#             "class 4"
#         ],
#         "x": [
#             0.8266400340678861,
#             1.975890293401152
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y4",
#         "zmin": null,
#         "legendgroup": "y4",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 4
#         },
#         "y": [
#             4.0,
#             4.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 5",
#             "class 5"
#         ],
#         "x": [
#             1.0277185186806626,
#             1.9820530711539426
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y5",
#         "zmin": null,
#         "legendgroup": "y5",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 4
#         },
#         "y": [
#             5.0,
#             5.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "x": [
#             1.0277185186806626,
#             1.0277185186806626
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y6",
#         "zmin": null,
#         "legendgroup": "y6",
#         "zmax": null,
#         "line": {
#             "color": "rgba(255, 0, 0, 1.000)",
#             "shape": "linear",
#             "dash": "dot",
#             "width": 1
#         },
#         "y": [
#             -701.0,
#             706.0
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "x": [
#             1.4229545258337644,
#             1.4229545258337644
#         ],
#         "showlegend": false,
#         "mode": "lines",
#         "name": "y6",
#         "zmin": null,
#         "legendgroup": "y6",
#         "zmax": null,
#         "line": {
#             "color": "rgba(255, 0, 0, 1.000)",
#             "shape": "linear",
#             "dash": "dot",
#             "width": 1
#         },
#         "y": [
#             -701.0,
#             706.0
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "x": [
#             1.440683120509135,
#             1.440683120509135
#         ],
#         "showlegend": false,
#         "mode": "lines",
#         "name": "y6",
#         "zmin": null,
#         "legendgroup": "y6",
#         "zmax": null,
#         "line": {
#             "color": "rgba(255, 0, 0, 1.000)",
#             "shape": "linear",
#             "dash": "dot",
#             "width": 1
#         },
#         "y": [
#             -701.0,
#             706.0
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "x": [
#             1.6824511179906363,
#             1.6824511179906363
#         ],
#         "showlegend": false,
#         "mode": "lines",
#         "name": "y6",
#         "zmin": null,
#         "legendgroup": "y6",
#         "zmax": null,
#         "line": {
#             "color": "rgba(255, 0, 0, 1.000)",
#             "shape": "linear",
#             "dash": "dot",
#             "width": 1
#         },
#         "y": [
#             -701.0,
#             706.0
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "x": [
#             1.6845526031473712,
#             1.6845526031473712
#         ],
#         "showlegend": false,
#         "mode": "lines",
#         "name": "y6",
#         "zmin": null,
#         "legendgroup": "y6",
#         "zmax": null,
#         "line": {
#             "color": "rgba(255, 0, 0, 1.000)",
#             "shape": "linear",
#             "dash": "dot",
#             "width": 1
#         },
#         "y": [
#             -701.0,
#             706.0
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "x": [
#             1.6851914863933934,
#             1.6851914863933934
#         ],
#         "showlegend": false,
#         "mode": "lines",
#         "name": "y6",
#         "zmin": null,
#         "legendgroup": "y6",
#         "zmax": null,
#         "line": {
#             "color": "rgba(255, 0, 0, 1.000)",
#             "shape": "linear",
#             "dash": "dot",
#             "width": 1
#         },
#         "y": [
#             -701.0,
#             706.0
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "x": [
#             1.6866706635573108,
#             1.6866706635573108
#         ],
#         "showlegend": false,
#         "mode": "lines",
#         "name": "y6",
#         "zmin": null,
#         "legendgroup": "y6",
#         "zmax": null,
#         "line": {
#             "color": "rgba(255, 0, 0, 1.000)",
#             "

# %% [markdown]
# ## 4(b) Interactive exploration of baseline and offset bar extensions
# * We use the function `return_extension_results_at_parameter()`, which is an interactive function that requires the user to select the following:
#     * A parameter of `p_Y`
#     * Offset bar extensions
# * The function shows the baseline bar-extension at selected parameter, along with the final bar-extension (baseline bar extension + selected offset bar extensions).
# * The function returns a plot object that highlights the final bar extension

# %%
p = return_extension_results_at_parameter(extension);
# Out:
# *** Parameter key, value pair ***
# key: 1 parameter: 1.027719
# key: 2 parameter: 1.422955
# key: 3 parameter: 1.440683
# key: 4 parameter: 1.682451
# key: 5 parameter: 1.684553
# key: 6 parameter: 1.685191
# key: 7 parameter: 1.686671
# key: 8 parameter: 1.690335
# key: 9 parameter: 1.691053
# key: 10 parameter: 1.695975
# key: 11 parameter: 1.701137
# key: 12 parameter: 1.703031
# key: 13 parameter: 1.707123
# key: 14 parameter: 1.709780
# key: 15 parameter: 1.709919
# key: 16 parameter: 1.711123
# key: 17 parameter: 1.716143
# key: 18 parameter: 1.717690
# key: 19 parameter: 1.723076
# key: 20 parameter: 1.726520
# key: 21 parameter: 1.726885
# key: 22 parameter: 1.728641
# key: 23 parameter: 1.730666
# key: 24 parameter: 1.731487
# key: 25 parameter: 1.733846
# key: 26 parameter: 1.734056
# key: 27 parameter: 1.735527
# key: 28 parameter: 1.736430
# key: 29 parameter: 1.737819
# key: 30 parameter: 1.737966
# key: 31 parameter: 1.738558
# key: 32 parameter: 1.738914
# key: 33 parameter: 1.739488
# key: 34 parameter: 1.744271
# key: 35 parameter: 1.744489
# key: 36 parameter: 1.745273
# key: 37 parameter: 1.746157
# key: 38 parameter: 1.747369
# key: 39 parameter: 1.750118
# key: 40 parameter: 1.833740
# Select a key for parameter 1
# Selected parameter: 1.0277185186806626
#
# Baseline bars extension at selected parameter: [5]
#
# *** Offset bar extensions at selected parameter ***
# key: 1 offset bar extension: [2]
# key: 2 offset bar extension: [3]
# key: 3 offset bar extension: [4]
# Select keys for offset bar extensions.
# Leave blank to select none.
# To select multiple keys, separate keys with space. ex) 1 2 3 :  1
# Baseline bars extension at selected parameter: [5]
# Selected offset bar extension: [2]
# Final bar extensions: [5, 2]

# %%
plot(p, lw = 5)
# Out:
# <!DOCTYPE html>
# <html>
#     <head>
#         <title>Plots.jl</title>
#         <meta http-equiv="content-type" content="text/html; charset=UTF-8">
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#     </head>
#     <body>
#             <div id="84d74851-08ae-44f8-abcc-364391dedb12" style="width:600px;height:400px;"></div>
#     <script>
#     PLOT = document.getElementById('84d74851-08ae-44f8-abcc-364391dedb12');
#     Plotly.plot(PLOT, [
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 1",
#             "class 1"
#         ],
#         "x": [
#             0.32411292660404395,
#             0.35263527349737434
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y1",
#         "zmin": null,
#         "legendgroup": "y1",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 5
#         },
#         "y": [
#             1.0,
#             1.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 2",
#             "class 2"
#         ],
#         "x": [
#             0.4538696366298648,
#             1.0277185186806626
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y2",
#         "zmin": null,
#         "legendgroup": "y2",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 5
#         },
#         "y": [
#             2.0,
#             2.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 2",
#             "class 2"
#         ],
#         "x": [
#             1.0277185186806626,
#             1.9611529246595443
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y3",
#         "zmin": null,
#         "legendgroup": "y3",
#         "zmax": null,
#         "line": {
#             "color": "rgba(238, 18, 137, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 5
#         },
#         "y": [
#             2.0,
#             2.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 3",
#             "class 3"
#         ],
#         "x": [
#             0.5729492961514668,
#             1.7512260110812434
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y4",
#         "zmin": null,
#         "legendgroup": "y4",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 5
#         },
#         "y": [
#             3.0,
#             3.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 4",
#             "class 4"
#         ],
#         "x": [
#             0.8266400340678861,
#             1.975890293401152
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y5",
#         "zmin": null,
#         "legendgroup": "y5",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 5
#         },
#         "y": [
#             4.0,
#             4.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 5",
#             "class 5"
#         ],
#         "x": [
#             1.0277185186806626,
#             1.0277185186806626
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y6",
#         "zmin": null,
#         "legendgroup": "y6",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 5
#         },
#         "y": [
#             5.0,
#             5.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 5",
#             "class 5"
#         ],
#         "x": [
#             1.0277185186806626,
#             1.9820530711539426
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y7",
#         "zmin": null,
#         "legendgroup": "y7",
#         "zmax": null,
#         "line": {
#             "color": "rgba(238, 18, 137, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 5
#         },
#         "y": [
#             5.0,
#             5.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "x": [
#             1.0277185186806626,
#             1.0277185186806626
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y8",
#         "zmin": null,
#         "legendgroup": "y8",
#         "zmax": null,
#         "line": {
#             "color": "rgba(255, 0, 0, 1.000)",
#             "shape": "linear",
#             "dash": "dot",
#             "width": 5
#         },
#         "y": [
#             -701.0,
#             706.0
#         ],
#         "type": "scatter"
#     }
# ]
# , {
#     "showlegend": false,
#     "xaxis": {
#         "showticklabels": true,
#         "gridwidth": 0.5,
#         "tickvals": [
#             0.5,
#             1.0,
#             1.5,
#             2.0
#         ],
#         "visible": true,
#         "ticks": "inside",
#         "range": [
#             0.274374722267547,
#             2.0317912754904395
#         ],
#         "domain": [
#             0.006561679790026247,
#             0.9934383202099737
#         ],
#         "tickmode": "array",
#         "linecolor": "rgba(0, 0, 0, 1.000)",
#         "showgrid": true,
#         "title": "",
#         "mirror": true,
#         "tickangle": 0,
#         "showline": true,
#         "gridcolor": "rgba(0, 0, 0, 0.100)",
#         "titlefont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 15
#         },
#         "tickcolor": "rgb(0, 0, 0)",
#         "ticktext": [
#             "0.5",
#             "1.0",
#             "1.5",
#             "2.0"
#         ],
#         "zeroline": false,
#         "type": "-",
#         "tickfont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 11
#         },
#         "zerolinecolor": "rgba(0, 0, 0, 1.000)",
#         "anchor": "y1"
#     },
#     "paper_bgcolor": "rgba(255, 255, 255, 1.000)",
#     "annotations": [
#         {
#             "yanchor": "top",
#             "xanchor": "center",
#             "rotation": -0.0,
#             "y": 1.0,
#             "font": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "family": "sans-serif",
#                 "size": 20
#             },
#             "yref": "paper",
#             "showarrow": false,
#             "text": "barcode(VR(Y))",
#             "xref": "paper",
#             "x": 0.5
#         }
#     ],
#     "height": 400,
#     "margin": {
#         "l": 0,
#         "b": 20,
#         "r": 0,
#         "t": 20
#     },
#     "plot_bgcolor": "rgba(255, 255, 255, 1.000)",
#     "yaxis": {
#         "showticklabels": true,
#         "gridwidth": 0.5,
#         "tickvals": [],
#         "visible": tru

# %% [markdown]
# ## 4(c) All cycle extensions and bar extensions
# * We use the function `find_CE_BE()` to find all cycle extensions and bar extensions at every parameter.
# * Let `CE`, `BE` be the outputs of the function.
# * Given parameter `param`, `CE[param]` is a dictionary. It's keys are indices and values are cycle extensions at given parameter.
#     * That is, `CE[param][i]` is the i-th cycle extension at given parameter
# * Given parameter `param` and an index `i` of the cycle extension, `BE[param][i]` is the bar extension of the corresponding cycle extension.
# * If one wishes to compute the cycle extensions and the bar extensions only at a specific parameter, use the function `find_CE_BE_at_param(extension, param)`. This will result in the same output as `CE[param]` and `BE[param]`.

# %%
# find all cycle extensions & bar extenisons (under a fixed interval decomposition of the target filtration) 
# at every parameter
CE, BE = find_CE_BE(extension);

# %% [markdown]
# <b> Plot cycle extensions </b>

# %%
# select parameter
param = extension["nontrivial_pY"][1]
@printf("number of cycle extensions at parameter %.4f : %i", param, length(CE[param]))
# Out:
# number of cycle extensions at parameter 1.0277 : 8

# %%
# plot the 8 cycle extensions at selected parameter
ms = 3
titlefontsize = 16

p_objects = []
for i=0:7
    p = plot_cycle_single(transpose(P_pca), cycle = CE[param][i], markersize = ms, title = "cycle extension "*string(i), titlefontsize = 10)
    push!(p_objects,p)
end

plot(p_objects..., layout = grid(2, 4), size = (700, 300))
# Out:
# <!DOCTYPE html>
# <html>
#     <head>
#         <title>Plots.jl</title>
#         <meta http-equiv="content-type" content="text/html; charset=UTF-8">
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#     </head>
#     <body>
#             <div id="8f19b665-5c65-4304-8f71-b1fe40bf79dc" style="width:700px;height:300px;"></div>
#     <script>
#     PLOT = document.getElementById('8f19b665-5c65-4304-8f71-b1fe40bf79dc');
#     Plotly.plot(PLOT, [
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "x": [
#             -0.5559007311204965,
#             -1.446856949565712,
#             -1.1217547872110005,
#             2.371748120704803,
#             -2.895933035069496,
#             0.3295355045526856,
#             -1.0500486987385933,
#             0.048884233152449996,
#             -2.938066020469176,
#             -0.32925516708745906,
#             2.669240436276489,
#             0.682853211911372,
#             -0.25434315883647446,
#             -2.8399706812638903,
#             0.5191632461718072,
#             -2.261227815554792,
#             2.5054150430637163,
#             1.9226060112829397,
#             0.4427632478220325,
#             -2.8354761893689093,
#             -0.4102812454481123,
#             0.26998874180723537,
#             -0.9444745037026557,
#             -1.0847729750435553,
#             2.639029515433066,
#             -0.12374633835829132,
#             -0.9549360856386141,
#             -1.4630989232830143,
#             -1.1093931115628466,
#             1.3943253297746079,
#             -0.08853128556154531,
#             1.718026032809438,
#             2.503954067876427,
#             0.2410444682396988,
#             -0.7309510430007885,
#             0.5376900678730081,
#             -1.117079430952803,
#             0.3999532098868646,
#             -2.439156869950244,
#             -1.5688571034017544,
#             -1.97078331411418,
#             -1.4186183930337353,
#             -1.4472493099530959,
#             -0.9493210719435209,
#             2.1810212879239192,
#             1.514995693210367,
#             1.0917599168006584,
#             1.6825985346761636,
#             1.0475108267263804,
#             -0.9062153776135788,
#             1.4814496616223838,
#             1.88027554028842,
#             -1.4518362104567082,
#             -2.352799176062824,
#             0.3766199829165974,
#             -0.8502636729534395,
#             -2.0427464720351862,
#             -0.5408913529449051,
#             -0.8415452350255855,
#             2.1155722498183436,
#             2.254019766551209,
#             2.0075363233911507,
#             -0.1550411995382707,
#             -0.023492168932493274,
#             1.4639625249401393,
#             -0.6617691877733594,
#             -0.7839509144502597,
#             -0.8865519999841641,
#             -2.5537243092591195,
#             0.49587577066201943,
#             -1.3970462390279192,
#             -0.9150552775996473,
#             -2.8755232078787927,
#             -2.868091334845265
#         ],
#         "showlegend": false,
#         "mode": "markers",
#         "name": "",
#         "zmin": null,
#         "legendgroup": "",
#         "marker": {
#             "symbol": "circle",
#             "color": "rgba(0, 154, 250, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 6
#         },
#         "zmax": null,
#         "y": [
#             -1.6014362594812266,
#             0.9008791728399415,
#             0.1868119271105137,
#             -1.5929828681967684,
#             -0.6590265800805387,
#             3.1750413263546706,
#             0.06518153978652022,
#             3.165362628675723,
#             -0.47339361619110953,
#             -1.8572154549217919,
#             -0.5313823650420624,
#             -0.5149536469352466,
#             1.3553212493089182,
#             -0.8238653403288091,
#             1.1644916920803308,
#             -1.5837971218953082,
#             -1

# %% [markdown]
# Plot the <b>bar extensions</b>
# * First select a parameter
# * Then select a cycle extension
# * Find and plot the corresponding bar extensions

# %%
# select parameter 
param = extension["nontrivial_pY"][1]
@printf("number of cycle extensions at parameter %.4f : %i", param, length(CE[param]))
# Out:
# number of cycle extensions at parameter 1.0277 : 8

# %%
# select cycle extension 
y= 0

# find the corresponding bar extension
be = BE[param][y]

# plot the bar extension
barcode_pca = barcode(C_pca, dim = dim)
p = plot_barcode(barcode_pca, title = "selected bar extension", lw = 3, selected_bars = be, epsilon= param, v_line = [param])
plot(p, size = (500, 300))
# Out:
# <!DOCTYPE html>
# <html>
#     <head>
#         <title>Plots.jl</title>
#         <meta http-equiv="content-type" content="text/html; charset=UTF-8">
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#     </head>
#     <body>
#             <div id="46ee1379-f6dd-4df0-abb0-612389cf97c3" style="width:500px;height:300px;"></div>
#     <script>
#     PLOT = document.getElementById('46ee1379-f6dd-4df0-abb0-612389cf97c3');
#     Plotly.plot(PLOT, [
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 1",
#             "class 1"
#         ],
#         "x": [
#             0.32411292660404395,
#             0.35263527349737434
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y1",
#         "zmin": null,
#         "legendgroup": "y1",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             1.0,
#             1.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 2",
#             "class 2"
#         ],
#         "x": [
#             0.4538696366298648,
#             1.9611529246595443
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y2",
#         "zmin": null,
#         "legendgroup": "y2",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             2.0,
#             2.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 3",
#             "class 3"
#         ],
#         "x": [
#             0.5729492961514668,
#             1.7512260110812434
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y3",
#         "zmin": null,
#         "legendgroup": "y3",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             3.0,
#             3.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 4",
#             "class 4"
#         ],
#         "x": [
#             0.8266400340678861,
#             1.975890293401152
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y4",
#         "zmin": null,
#         "legendgroup": "y4",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             4.0,
#             4.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 5",
#             "class 5"
#         ],
#         "x": [
#             1.0277185186806626,
#             1.0277185186806626
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y5",
#         "zmin": null,
#         "legendgroup": "y5",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             5.0,
#             5.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 5",
#             "class 5"
#         ],
#         "x": [
#             1.0277185186806626,
#             1.9820530711539426
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y6",
#         "zmin": null,
#         "legendgroup": "y6",
#         "zmax": null,
#         "line": {
#             "color": "rgba(238, 18, 137, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             5.0,
#             5.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "x": [
#             1.0277185186806626,
#             1.0277185186806626
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y7",
#         "zmin": null,
#         "legendgroup": "y7",
#         "zmax": null,
#         "line": {
#             "color": "rgba(255, 0, 0, 1.000)",
#             "shape": "linear",
#             "dash": "dot",
#             "width": 1
#         },
#         "y": [
#             -701.0,
#             706.0
#         ],
#         "type": "scatter"
#     }
# ]
# , {
#     "showlegend": false,
#     "xaxis": {
#         "showticklabels": true,
#         "gridwidth": 0.5,
#         "tickvals": [
#             0.5,
#             1.0,
#             1.5,
#             2.0
#         ],
#         "visible": true,
#         "ticks": "inside",
#         "range": [
#             0.274374722267547,
#             2.0317912754904395
#         ],
#         "domain": [
#             0.007874015748031496,
#             0.9921259842519685
#         ],
#         "tickmode": "array",
#         "linecolor": "rgba(0, 0, 0, 1.000)",
#         "showgrid": true,
#         "title": "",
#         "mirror": true,
#         "tickangle": 0,
#         "showline": true,
#         "gridcolor": "rgba(0, 0, 0, 0.100)",
#         "titlefont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 15
#         },
#         "tickcolor": "rgb(0, 0, 0)",
#         "ticktext": [
#             "0.5",
#             "1.0",
#             "1.5",
#             "2.0"
#         ],
#         "zeroline": false,
#         "type": "-",
#         "tickfont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 11
#         },
#         "zerolinecolor": "rgba(0, 0, 0, 1.000)",
#         "anchor": "y1"
#     },
#     "paper_bgcolor": "rgba(255, 255, 255, 1.000)",
#     "annotations": [
#         {
#             "yanchor": "top",
#             "xanchor": "center",
#             "rotation": -0.0,
#             "y": 1.0,
#             "font": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "family": "sans-serif",
#                 "size": 20
#             },
#             "yref": "paper",
#             "showarrow": false,
#             "text": "selected bar extension",
#             "xref": "paper",
#             "x": 0.5
#         }
#     ],
#     "height": 300,
#     "margin": {
#         "l": 0,
#         "b": 20,
#         "r": 0,
#         "t": 20
#     },
#     "plot_bgcolor": "rgba(255, 255, 255, 1.000)",
#     "yaxis": {
#         "showticklabels": true,
#         "gridwidth": 0.5,
#         "tickvals": [],
#         "visible": true,
#         "ticks": "inside",
#         "range": [
#             -1.0,
#             6.0
#         ],
#         "domain": [
#             0.10265383493729952,
#             0.8695683872849228
#         ],
#         "tickmode": "array",
#         "linecolor": "rgba(0, 0, 0, 1.000)",
#         "showgrid": true,
#         "title": "",
#         "mirror": true,
#         "tickangle": 0,
#         "showline": true,
#         "gridcolor": "rgba(0, 0, 0, 0.100)",
#         "titlefont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 15
#         },
#         "tickcolor": "rgb(0, 0, 0)",
#         "ticktext": [],
#         "zeroline": false,
#         "type": "-",
#         "tickfont":

# %% [markdown]
# For speed reasons, one may wish to find the cycle extensions and bar extensions only at a specific parameter. Use the function `find_CE_BE_at_param()`

# %%
# select parameter
param = extension["nontrivial_pY"][1]
CE_param, BE_param = find_CE_BE_at_param(extension, param);

# one can now re-run the CE and BE plotting functions

# %% [markdown]
# # 5. Explore the bar extension result under alternative interval decompositions of `C_Y`
# * Up to this point, the bar extension result has been obtained for some fixed interval decomposition $\mathcal{D}:\mathbb{I}_{\text{BC}_k(Y^{\bullet})} \to H_k(Y^{\bullet})$. In particular, we used the default interval decomposition that is used by Eirene.
# * In this section, we present various functions that allow us to find the full bar extensions under all possible interval decompositions of $PH_k(Y^{\bullet})$. The goal of this section is to explore $S(\tau, Y^{\bullet})$ from Algorithm 3 of paper. We'll refer to this set as <b>alternative bar extensions</b> since these arise from alternative choices of the interval decompositions.
# * We present three different methods for exploring the collection of bar extensions $S(\tau, Y^{\bullet})$. The appropriate tool depends on the sizes of the barcodes of `C_auxiliary_filtration` and `C_Y`.
#
# 1. Find all alternative bar extensions for all parameters.
#     * This is recommended for data with small barcodes.
#     * This finds the full $S(\tau, Y^{\bullet}) = \{ S^{\mathcal{D} \circ L^{-1}}_{[y]} | \ell \in p_Y, [y] \in \mathfrak{E}_{\ell}, L \in L_Y \}$ in Algorithm 3 of paper.
# 2. Find alternative bar extensions at specific parameters.
#     * This is recommended for data with medium size barcodes.
#     * Given a parameter $\ell$, this method finds $S(\tau, Y^{\bullet}; \ell) = \{ S^{\mathcal{D} \circ L^{-1}}_{[y]} | [y] \in \mathfrak{E}_{\ell}, L \in L_Y \} $
# 3. Find alternative bar extensions of a specific bar extension.
#     * This is recommended for data with large size barcodes.
#     * Given a selected parameter $\ell$ and cycle extension $[y] \in \mathfrak{E}_{\ell}$, this method finds $\{S^{\mathcal{D} \circ L^{-1}}_{[y]} | L \in L_Y \}$.

# %% [markdown]
# In this notebook, we implement (1): Find all alternative bar extensions

# %%
# find all bar extensions at all parameters (for a FIXED interval decomposition of C_Y)
_, BE = find_CE_BE(extension)

# find all alternative bar extensions (under alternative interval decompositions of C_Y)
BE_alt = find_alt_BE(extension, BE);

# %% [markdown]
# Exploring the results: Given a parameter `param`, `BE_all[param]` returns all possible bar extensions at the given parameter.

# %%
# select parameter
param = extension["nontrivial_pY"][1]

BE_alt[param]
# Out:
# 8-element Array{Any,1}:
#  [5]
#  [2, 5]
#  [3, 5]
#  [4, 5]
#  [2, 3, 5]
#  [2, 4, 5]
#  [3, 4, 5]
#  [2, 3, 4, 5]

# %%
# plot one of the alternative bar extensions

# select an alternative bar extension
alt = BE_alt[param][2]
barcode_Y = barcode(extension["C_Y"], dim = dim)
p =plot_barcode(barcode_Y, selected_bars = alt, lw = 3,
                    epsilon = param, v_line = [param],
                    title = "alternative intervals")
plot(p)
# Out:
# <!DOCTYPE html>
# <html>
#     <head>
#         <title>Plots.jl</title>
#         <meta http-equiv="content-type" content="text/html; charset=UTF-8">
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#     </head>
#     <body>
#             <div id="553ab97d-3b0b-425f-8157-8e6e42f48526" style="width:600px;height:400px;"></div>
#     <script>
#     PLOT = document.getElementById('553ab97d-3b0b-425f-8157-8e6e42f48526');
#     Plotly.plot(PLOT, [
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 1",
#             "class 1"
#         ],
#         "x": [
#             0.32411292660404395,
#             0.35263527349737434
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y1",
#         "zmin": null,
#         "legendgroup": "y1",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             1.0,
#             1.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 2",
#             "class 2"
#         ],
#         "x": [
#             0.4538696366298648,
#             1.0277185186806626
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y2",
#         "zmin": null,
#         "legendgroup": "y2",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             2.0,
#             2.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 2",
#             "class 2"
#         ],
#         "x": [
#             1.0277185186806626,
#             1.9611529246595443
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y3",
#         "zmin": null,
#         "legendgroup": "y3",
#         "zmax": null,
#         "line": {
#             "color": "rgba(238, 18, 137, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             2.0,
#             2.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 3",
#             "class 3"
#         ],
#         "x": [
#             0.5729492961514668,
#             1.7512260110812434
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y4",
#         "zmin": null,
#         "legendgroup": "y4",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             3.0,
#             3.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 4",
#             "class 4"
#         ],
#         "x": [
#             0.8266400340678861,
#             1.975890293401152
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y5",
#         "zmin": null,
#         "legendgroup": "y5",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             4.0,
#             4.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 5",
#             "class 5"
#         ],
#         "x": [
#             1.0277185186806626,
#             1.0277185186806626
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y6",
#         "zmin": null,
#         "legendgroup": "y6",
#         "zmax": null,
#         "line": {
#             "color": "rgba(143, 143, 143, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             5.0,
#             5.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             "class 5",
#             "class 5"
#         ],
#         "x": [
#             1.0277185186806626,
#             1.9820530711539426
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y7",
#         "zmin": null,
#         "legendgroup": "y7",
#         "zmax": null,
#         "line": {
#             "color": "rgba(238, 18, 137, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             5.0,
#             5.0
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "x": [
#             1.0277185186806626,
#             1.0277185186806626
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y8",
#         "zmin": null,
#         "legendgroup": "y8",
#         "zmax": null,
#         "line": {
#             "color": "rgba(255, 0, 0, 1.000)",
#             "shape": "linear",
#             "dash": "dot",
#             "width": 1
#         },
#         "y": [
#             -701.0,
#             706.0
#         ],
#         "type": "scatter"
#     }
# ]
# , {
#     "showlegend": false,
#     "xaxis": {
#         "showticklabels": true,
#         "gridwidth": 0.5,
#         "tickvals": [
#             0.5,
#             1.0,
#             1.5,
#             2.0
#         ],
#         "visible": true,
#         "ticks": "inside",
#         "range": [
#             0.274374722267547,
#             2.0317912754904395
#         ],
#         "domain": [
#             0.006561679790026247,
#             0.9934383202099737
#         ],
#         "tickmode": "array",
#         "linecolor": "rgba(0, 0, 0, 1.000)",
#         "showgrid": true,
#         "title": "",
#         "mirror": true,
#         "tickangle": 0,
#         "showline": true,
#         "gridcolor": "rgba(0, 0, 0, 0.100)",
#         "titlefont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 15
#         },
#         "tickcolor": "rgb(0, 0, 0)",
#         "ticktext": [
#             "0.5",
#             "1.0",
#             "1.5",
#             "2.0"
#         ],
#         "zeroline": false,
#         "type": "-",
#         "tickfont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 11
#         },
#         "zerolinecolor": "rgba(0, 0, 0, 1.000)",
#         "anchor": "y1"
#     },
#     "paper_bgcolor": "rgba(255, 255, 255, 1.000)",
#     "annotations": [
#         {
#             "yanchor": "top",
#             "xanchor": "center",
#             "rotation": -0.0,
#             "y": 1.0,
#             "font": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "family": "sans-serif",
#                 "size": 20
#             },
#             "yref": "paper",
#             "showarrow": false,
#             "text": "alternative intervals",
#             "xref": "paper",
#             "x": 0.5
#         }
#     ],
#     "height": 400,
#     "margin": {
#         "l": 0,
#         "b": 20,
#         "r": 0,
#         "t": 20
#     },
#     "plot_bgcolor": "rgba(255, 255, 255, 1.000)",
#     "yaxis": {
#         "showticklabels": true,
#         "gridwidth": 0.5,
#         "tickvals": [],
#         "visibl
